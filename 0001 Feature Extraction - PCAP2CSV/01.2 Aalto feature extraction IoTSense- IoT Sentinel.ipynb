# %% [markdown]
# # This file extracts feature sets from pcap files.

# %% [markdown]
# ### You can access the  Aalto University IoT devices captures  data used in our study from the link below.
#
#
#
#
# [ Aalto University IoT devices captures ](https://research.aalto.fi/en/datasets/iot-devices-captures)

# %% [markdown]
# ------------------

# %% [markdown]
# ###  importing relevant libraries

# %%
from scapy.all import*
import math
import pandas as pd
import os
import numpy as np
import zipfile

# %%
def folder(f_name): #this function creates a folder named "attacks" in the program directory.
    try:
        if not os.path.exists(f_name):
            os.makedirs(f_name)
    except OSError:
        print ("The folder could not be created!")

# %%
path="captures_IoT_Sentinel.zip"
with zipfile.ZipFile(path, 'r') as zip_ref:
    zip_ref.extractall("./")
path="./captures_IoT-Sentinel\\"

# %% [markdown]
# ### Discovering pcap extension files under "pcaps" folder.

# %%
def find_the_way(path,file_format):
    files_add = []
    # r=root, d=directories, f = files
    for r, d, f in os.walk(path):
        for file in f:
            if file_format in file:
                files_add.append(os.path.join(r, file))  
    return files_add
files_add=find_the_way(path,'.pcap')
files_add
# Out:
# ['./captures_IoT-Sentinel\\Aria\\Setup-A-1-STA.pcap',
#  './captures_IoT-Sentinel\\Aria\\Setup-A-2-STA.pcap',
#  './captures_IoT-Sentinel\\Aria\\Setup-A-3-STA.pcap',
#  './captures_IoT-Sentinel\\Aria\\Setup-A-4-STA.pcap',
#  './captures_IoT-Sentinel\\Aria\\Setup-A-5-STA.pcap',
#  './captures_IoT-Sentinel\\Aria\\Setup-C-1-STA.pcap',
#  './captures_IoT-Sentinel\\Aria\\Setup-C-10-STA.pcap',
#  './captures_IoT-Sentinel\\Aria\\Setup-C-11-STA.pcap',
#  './captures_IoT-Sentinel\\Aria\\Setup-C-12-STA.pcap',
#  './captures_IoT-Sentinel\\Aria\\Setup-C-13-STA.pcap',
#  './captures_IoT-Sentinel\\Aria\\Setup-C-14-STA.pcap',
#  './captures_IoT-Sentinel\\Aria\\Setup-C-15-STA.pcap',
#  './captures_IoT-Sentinel\\Aria\\Setup-C-2-STA.pcap',
#  './captures_IoT-Sentinel\\Aria\\Setup-C-3-STA.pcap',
#  './captures_IoT-Sentinel\\Aria\\Setup-C-4-STA.pcap',
#  './captures_IoT-Sentinel\\Aria\\Setup-C-5-STA.pcap',
#  './captures_IoT-Sentinel\\Aria\\Setup-C-6-STA.pcap',
#  './captures_IoT-Sentinel\\Aria\\Setup-C-7-STA.pcap',
#  './captures_IoT-Sentinel\\Aria\\Setup-C-8-STA.pcap',
#  './captures_IoT-Sentinel\\Aria\\Setup-C-9-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkCam\\Setup-A-1-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkCam\\Setup-A-2-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkCam\\Setup-A-3-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkCam\\Setup-A-4-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkCam\\Setup-A-5-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkCam\\Setup-B-1-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkCam\\Setup-B-2-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkCam\\Setup-B-3-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkCam\\Setup-B-4-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkCam\\Setup-B-5-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkCam\\Setup-C-1-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkCam\\Setup-C-10-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkCam\\Setup-C-2-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkCam\\Setup-C-3-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkCam\\Setup-C-4-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkCam\\Setup-C-5-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkCam\\Setup-C-6-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkCam\\Setup-C-7-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkCam\\Setup-C-8-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkCam\\Setup-C-9-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkDayCam\\Setup-A-1-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkDayCam\\Setup-A-2-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkDayCam\\Setup-A-3-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkDayCam\\Setup-A-4-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkDayCam\\Setup-A-5-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkDayCam\\Setup-C-1-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkDayCam\\Setup-C-10-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkDayCam\\Setup-C-11-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkDayCam\\Setup-C-12-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkDayCam\\Setup-C-13-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkDayCam\\Setup-C-14-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkDayCam\\Setup-C-15-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkDayCam\\Setup-C-2-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkDayCam\\Setup-C-3-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkDayCam\\Setup-C-4-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkDayCam\\Setup-C-5-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkDayCam\\Setup-C-6-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkDayCam\\Setup-C-7-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkDayCam\\Setup-C-8-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkDayCam\\Setup-C-9-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkDoorSensor\\Setup-C-1-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkDoorSensor\\Setup-C-10-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkDoorSensor\\Setup-C-11-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkDoorSensor\\Setup-C-12-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkDoorSensor\\Setup-C-13-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkDoorSensor\\Setup-C-14-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkDoorSensor\\Setup-C-15-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkDoorSensor\\Setup-C-16-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkDoorSensor\\Setup-C-17-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkDoorSensor\\Setup-C-18-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkDoorSensor\\Setup-C-19-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkDoorSensor\\Setup-C-2-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkDoorSensor\\Setup-C-20-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkDoorSensor\\Setup-C-3-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkDoorSensor\\Setup-C-4-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkDoorSensor\\Setup-C-5-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkDoorSensor\\Setup-C-6-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkDoorSensor\\Setup-C-7-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkDoorSensor\\Setup-C-8-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkDoorSensor\\Setup-C-9-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkHomeHub\\Setup-A-1-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkHomeHub\\Setup-A-2-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkHomeHub\\Setup-A-3-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkHomeHub\\Setup-A-4-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkHomeHub\\Setup-A-5-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkHomeHub\\Setup-C-1-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkHomeHub\\Setup-C-10-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkHomeHub\\Setup-C-11-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkHomeHub\\Setup-C-12-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkHomeHub\\Setup-C-13-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkHomeHub\\Setup-C-14-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkHomeHub\\Setup-C-15-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkHomeHub\\Setup-C-2-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkHomeHub\\Setup-C-3-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkHomeHub\\Setup-C-4-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkHomeHub\\Setup-C-5-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkHomeHub\\Setup-C-6-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkHomeHub\\Setup-C-7-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkHomeHub\\Setup-C-8-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkHomeHub\\Setup-C-9-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSensor\\Setup-A-1-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSensor\\Setup-A-2-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSensor\\Setup-A-3-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSensor\\Setup-A-4-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSensor\\Setup-A-5-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSensor\\Setup-B-1-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSensor\\Setup-B-2-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSensor\\Setup-B-3-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSensor\\Setup-B-4-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSensor\\Setup-B-5-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSensor\\Setup-C-1-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSensor\\Setup-C-10-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSensor\\Setup-C-2-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSensor\\Setup-C-3-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSensor\\Setup-C-4-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSensor\\Setup-C-5-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSensor\\Setup-C-6-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSensor\\Setup-C-7-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSensor\\Setup-C-8-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSensor\\Setup-C-9-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSiren\\Setup-A-1-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSiren\\Setup-C-1-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSiren\\Setup-C-10-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSiren\\Setup-C-11-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSiren\\Setup-C-12-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSiren\\Setup-C-13-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSiren\\Setup-C-14-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSiren\\Setup-C-15-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSiren\\Setup-C-16-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSiren\\Setup-C-17-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSiren\\Setup-C-18-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSiren\\Setup-C-19-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSiren\\Setup-C-2-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSiren\\Setup-C-3-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSiren\\Setup-C-4-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSiren\\Setup-C-5-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSiren\\Setup-C-6-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSiren\\Setup-C-7-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSiren\\Setup-C-8-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSiren\\Setup-C-9-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSwitch\\Setup-A-1-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSwitch\\Setup-A-2-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSwitch\\Setup-A-3-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSwitch\\Setup-A-4-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSwitch\\Setup-A-5-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSwitch\\Setup-C-1-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSwitch\\Setup-C-10-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSwitch\\Setup-C-11-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSwitch\\Setup-C-12-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSwitch\\Setup-C-13-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSwitch\\Setup-C-14-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSwitch\\Setup-C-15-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSwitch\\Setup-C-2-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSwitch\\Setup-C-3-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSwitch\\Setup-C-4-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSwitch\\Setup-C-5-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSwitch\\Setup-C-6-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSwitch\\Setup-C-7-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSwitch\\Setup-C-8-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSwitch\\Setup-C-9-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkWaterSensor\\Setup-A-1-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkWaterSensor\\Setup-C-1-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkWaterSensor\\Setup-C-10-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkWaterSensor\\Setup-C-11-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkWaterSensor\\Setup-C-12-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkWaterSensor\\Setup-C-13-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkWaterSensor\\Setup-C-14-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkWaterSensor\\Setup-C-15-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkWaterSensor\\Setup-C-16-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkWaterSensor\\Setup-C-17-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkWaterSensor\\Setup-C-18-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkWaterSensor\\Setup-C-19-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkWaterSensor\\Setup-C-2-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkWaterSensor\\Setup-C-3-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkWaterSensor\\Setup-C-4-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkWaterSensor\\Setup-C-5-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkWaterSensor\\Setup-C-6-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkWaterSensor\\Setup-C-7-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkWaterSensor\\Setup-C-8-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkWaterSensor\\Setup-C-9-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxCam1\\Setup-A-1-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxCam1\\Setup-A-2-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxCam1\\Setup-A-3-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxCam1\\Setup-A-4-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxCam1\\Setup-A-5-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxCam1\\Setup-A-6-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxCam1\\Setup-A-7-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxCam1\\Setup-C-1-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxCam1\\Setup-C-2-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxCam1\\Setup-C-3-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxCam1\\Setup-C-4-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxCam1\\Setup-C-5-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxCam2\\Setup-A-1-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxCam2\\Setup-A-2-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxCam2\\Setup-A-3-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxCam2\\Setup-A-4-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxCam2\\Setup-C-1-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxCam2\\Setup-C-2-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxCam2\\Setup-C-3-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxCam2\\Setup-C-4-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxPlug1101W\\Setup-A-1-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxPlug1101W\\Setup-A-2-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxPlug1101W\\Setup-A-3-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxPlug1101W\\Setup-A-4-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxPlug1101W\\Setup-A-5-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxPlug1101W\\Setup-C-1-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxPlug1101W\\Setup-C-10-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxPlug1101W\\Setup-C-11-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxPlug1101W\\Setup-C-12-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxPlug1101W\\Setup-C-13-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxPlug1101W\\Setup-C-14-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxPlug1101W\\Setup-C-15-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxPlug1101W\\Setup-C-2-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxPlug1101W\\Setup-C-3-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxPlug1101W\\Setup-C-4-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxPlug1101W\\Setup-C-5-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxPlug1101W\\Setup-C-6-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxPlug1101W\\Setup-C-7-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxPlug1101W\\Setup-C-8-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxPlug1101W\\Setup-C-9-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxPlug2101W\\Setup-A-1-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxPlug2101W\\Setup-A-2-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxPlug2101W\\Setup-A-3-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxPlug2101W\\Setup-A-4-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxPlug2101W\\Setup-A-5-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxPlug2101W\\Setup-C-1-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxPlug2101W\\Setup-C-10-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxPlug2101W\\Setup-C-11-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxPlug2101W\\Setup-C-12-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxPlug2101W\\Setup-C-13-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxPlug2101W\\Setup-C-14-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxPlug2101W\\Setup-C-15-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxPlug2101W\\Setup-C-2-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxPlug2101W\\Setup-C-3-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxPlug2101W\\Setup-C-4-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxPlug2101W\\Setup-C-5-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxPlug2101W\\Setup-C-6-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxPlug2101W\\Setup-C-7-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxPlug2101W\\Setup-C-8-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxPlug2101W\\Setup-C-9-STA.pcap',
#  './captures_IoT-Sentinel\\EdnetCam1\\Setup-A-1-STA.pcap',
#  './captures_IoT-Sentinel\\EdnetCam1\\Setup-C-1-STA.pcap',
#  './captures_IoT-Sentinel\\EdnetCam1\\Setup-C-10-STA.pcap',
#  './captures_IoT-Sentinel\\EdnetCam1\\Setup-C-2-STA.pcap',
#  './captures_IoT-Sentinel\\EdnetCam1\\Setup-C-3-STA.pcap',
#  './captures_IoT-Sentinel\\EdnetCam1\\Setup-C-4-STA.pcap',
#  './captures_IoT-Sentinel\\EdnetCam1\\Setup-C-5-STA.pcap',
#  './captures_IoT-Sentinel\\EdnetCam1\\Setup-C-6-STA.pcap',
#  './captures_IoT-Sentinel\\EdnetCam1\\Setup-C-7-STA.pcap',
#  './captures_IoT-Sentinel\\EdnetCam1\\Setup-C-8-STA.pcap',
#  './captures_IoT-Sentinel\\EdnetCam1\\Setup-C-9-STA.pcap',
#  './captures_IoT-Sentinel\\EdnetCam2\\Setup-A-1-STA.pcap',
#  './captures_IoT-Sentinel\\EdnetCam2\\Setup-C-1-STA.pcap',
#  './captures_IoT-Sentinel\\EdnetCam2\\Setup-C-2-STA.pcap',
#  './captures_IoT-Sentinel\\EdnetCam2\\Setup-C-3-STA.pcap',
#  './captures_IoT-Sentinel\\EdnetCam2\\Setup-C-4-STA.pcap',
#  './captures_IoT-Sentinel\\EdnetCam2\\Setup-C-5-STA.pcap',
#  './captures_IoT-Sentinel\\EdnetCam2\\Setup-C-6-STA.pcap',
#  './captures_IoT-Sentinel\\EdnetCam2\\Setup-C-7-STA.pcap',
#  './captures_IoT-Sentinel\\EdnetCam2\\Setup-C-8-STA.pcap',
#  './captures_IoT-Sentinel\\EdnetGateway\\Setup-A-1-STA.pcap',
#  './captures_IoT-Sentinel\\EdnetGateway\\Setup-A-2-STA.pcap',
#  './captures_IoT-Sentinel\\EdnetGateway\\Setup-C-1-STA.pcap',
#  './captures_IoT-Sentinel\\EdnetGateway\\Setup-C-10-STA.pcap',
#  './captures_IoT-Sentinel\\EdnetGateway\\Setup-C-11-STA.pcap',
#  './captures_IoT-Sentinel\\EdnetGateway\\Setup-C-12-STA.pcap',
#  './captures_IoT-Sentinel\\EdnetGateway\\Setup-C-13-STA.pcap',
#  './captures_IoT-Sentinel\\EdnetGateway\\Setup-C-14-STA.pcap',
#  './captures_IoT-Sentinel\\EdnetGateway\\Setup-C-15-STA.pcap',
#  './captures_IoT-Sentinel\\EdnetGateway\\Setup-C-16-STA.pcap',
#  './captures_IoT-Sentinel\\EdnetGateway\\Setup-C-17-STA.pcap',
#  './captures_IoT-Sentinel\\EdnetGateway\\Setup-C-18-STA.pcap',
#  './captures_IoT-Sentinel\\EdnetGateway\\Setup-C-2-STA.pcap',
#  './captures_IoT-Sentinel\\EdnetGateway\\Setup-C-3-STA.pcap',
#  './captures_IoT-Sentinel\\EdnetGateway\\Setup-C-4-STA.pcap',
#  './captures_IoT-Sentinel\\EdnetGateway\\Setup-C-5-STA.pcap',
#  './captures_IoT-Sentinel\\EdnetGateway\\Setup-C-6-STA.pcap',
#  './captures_IoT-Sentinel\\EdnetGateway\\Setup-C-7-STA.pcap',
#  './captures_IoT-Sentinel\\EdnetGateway\\Setup-C-8-STA.pcap',
#  './captures_IoT-Sentinel\\EdnetGateway\\Setup-C-9-STA.pcap',
#  './captures_IoT-Sentinel\\HomeMaticPlug\\Setup-C-1-STA.pcap',
#  './captures_IoT-Sentinel\\HomeMaticPlug\\Setup-C-10-STA.pcap',
#  './captures_IoT-Sentinel\\HomeMaticPlug\\Setup-C-11-STA.pcap',
#  './captures_IoT-Sentinel\\HomeMaticPlug\\Setup-C-12-STA.pcap',
#  './captures_IoT-Sentinel\\HomeMaticPlug\\Setup-C-13-STA.pcap',
#  './captures_IoT-Sentinel\\HomeMaticPlug\\Setup-C-14-STA.pcap',
#  './captures_IoT-Sentinel\\HomeMaticPlug\\Setup-C-15-STA.pcap',
#  './captures_IoT-Sentinel\\HomeMaticPlug\\Setup-C-16-STA.pcap',
#  './captures_IoT-Sentinel\\HomeMaticPlug\\Setup-C-17-STA.pcap',
#  './captures_IoT-Sentinel\\HomeMaticPlug\\Setup-C-18-STA.pcap',
#  './captures_IoT-Sentinel\\HomeMaticPlug\\Setup-C-19-STA.pcap',
#  './captures_IoT-Sentinel\\HomeMaticPlug\\Setup-C-2-STA.pcap',
#  './captures_IoT-Sentinel\\HomeMaticPlug\\Setup-C-20-STA.pcap',
#  './captures_IoT-Sentinel\\HomeMaticPlug\\Setup-C-3-STA.pcap',
#  './captures_IoT-Sentinel\\HomeMaticPlug\\Setup-C-4-STA.pcap',
#  './captures_IoT-Sentinel\\HomeMaticPlug\\Setup-C-5-STA.pcap',
#  './captures_IoT-Sentinel\\HomeMaticPlug\\Setup-C-6-STA.pcap',
#  './captures_IoT-Sentinel\\HomeMaticPlug\\Setup-C-7-STA.pcap',
#  './captures_IoT-Sentinel\\HomeMaticPlug\\Setup-C-8-STA.pcap',
#  './captures_IoT-Sentinel\\HomeMaticPlug\\Setup-C-9-STA.pcap',
#  './captures_IoT-Sentinel\\HueBridge\\Setup-A-1-STA.pcap',
#  './captures_IoT-Sentinel\\HueBridge\\Setup-A-2-STA.pcap',
#  './captures_IoT-Sentinel\\HueBridge\\Setup-A-3-STA.pcap',
#  './captures_IoT-Sentinel\\HueBridge\\Setup-A-4-STA.pcap',
#  './captures_IoT-Sentinel\\HueBridge\\Setup-A-5-STA.pcap',
#  './captures_IoT-Sentinel\\HueBridge\\Setup-C-1-STA.pcap',
#  './captures_IoT-Sentinel\\HueBridge\\Setup-C-10-STA.pcap',
#  './captures_IoT-Sentinel\\HueBridge\\Setup-C-11-STA.pcap',
#  './captures_IoT-Sentinel\\HueBridge\\Setup-C-12-STA.pcap',
#  './captures_IoT-Sentinel\\HueBridge\\Setup-C-13-STA.pcap',
#  './captures_IoT-Sentinel\\HueBridge\\Setup-C-14-STA.pcap',
#  './captures_IoT-Sentinel\\HueBridge\\Setup-C-15-STA.pcap',
#  './captures_IoT-Sentinel\\HueBridge\\Setup-C-2-STA.pcap',
#  './captures_IoT-Sentinel\\HueBridge\\Setup-C-3-STA.pcap',
#  './captures_IoT-Sentinel\\HueBridge\\Setup-C-4-STA.pcap',
#  './captures_IoT-Sentinel\\HueBridge\\Setup-C-5-STA.pcap',
#  './captures_IoT-Sentinel\\HueBridge\\Setup-C-6-STA.pcap',
#  './captures_IoT-Sentinel\\HueBridge\\Setup-C-7-STA.pcap',
#  './captures_IoT-Sentinel\\HueBridge\\Setup-C-8-STA.pcap',
#  './captures_IoT-Sentinel\\HueBridge\\Setup-C-9-STA.pcap',
#  './captures_IoT-Sentinel\\HueSwitch\\Setup-A-1-STA.pcap',
#  './captures_IoT-Sentinel\\HueSwitch\\Setup-A-10-STA.pcap',
#  './captures_IoT-Sentinel\\HueSwitch\\Setup-A-2-STA.pcap',
#  './captures_IoT-Sentinel\\HueSwitch\\Setup-A-3-STA.pcap',
#  './captures_IoT-Sentinel\\HueSwitch\\Setup-A-4-STA.pcap',
#  './captures_IoT-Sentinel\\HueSwitch\\Setup-A-5-STA.pcap',
#  './captures_IoT-Sentinel\\HueSwitch\\Setup-A-6-STA.pcap',
#  './captures_IoT-Sentinel\\HueSwitch\\Setup-A-7-STA.pcap',
#  './captures_IoT-Sentinel\\HueSwitch\\Setup-A-8-STA.pcap',
#  './captures_IoT-Sentinel\\HueSwitch\\Setup-A-9-STA.pcap',
#  './captures_IoT-Sentinel\\HueSwitch\\Setup-C-1-STA.pcap',
#  './captures_IoT-Sentinel\\HueSwitch\\Setup-C-10-STA.pcap',
#  './captures_IoT-Sentinel\\HueSwitch\\Setup-C-2-STA.pcap',
#  './captures_IoT-Sentinel\\HueSwitch\\Setup-C-3-STA.pcap',
#  './captures_IoT-Sentinel\\HueSwitch\\Setup-C-4-STA.pcap',
#  './captures_IoT-Sentinel\\HueSwitch\\Setup-C-5-STA.pcap',
#  './captures_IoT-Sentinel\\HueSwitch\\Setup-C-6-STA.pcap',
#  './captures_IoT-Sentinel\\HueSwitch\\Setup-C-7-STA.pcap',
#  './captures_IoT-Sentinel\\HueSwitch\\Setup-C-8-STA.pcap',
#  './captures_IoT-Sentinel\\HueSwitch\\Setup-C-9-STA.pcap',
#  './captures_IoT-Sentinel\\iKettle2\\Setup-A-1-STA.pcap',
#  './captures_IoT-Sentinel\\iKettle2\\Setup-A-10-STA.pcap',
#  './captures_IoT-Sentinel\\iKettle2\\Setup-A-11-STA.pcap',
#  './captures_IoT-Sentinel\\iKettle2\\Setup-A-12-STA.pcap',
#  './captures_IoT-Sentinel\\iKettle2\\Setup-A-13-STA.pcap',
#  './captures_IoT-Sentinel\\iKettle2\\Setup-A-14-STA.pcap',
#  './captures_IoT-Sentinel\\iKettle2\\Setup-A-15-STA.pcap',
#  './captures_IoT-Sentinel\\iKettle2\\Setup-A-2-STA.pcap',
#  './captures_IoT-Sentinel\\iKettle2\\Setup-A-3-STA.pcap',
#  './captures_IoT-Sentinel\\iKettle2\\Setup-A-4-STA.pcap',
#  './captures_IoT-Sentinel\\iKettle2\\Setup-A-5-STA.pcap',
#  './captures_IoT-Sentinel\\iKettle2\\Setup-A-6-STA.pcap',
#  './captures_IoT-Sentinel\\iKettle2\\Setup-A-7-STA.pcap',
#  './captures_IoT-Sentinel\\iKettle2\\Setup-A-8-STA.pcap',
#  './captures_IoT-Sentinel\\iKettle2\\Setup-A-9-STA.pcap',
#  './captures_IoT-Sentinel\\iKettle2\\Setup-C-1-STA.pcap',
#  './captures_IoT-Sentinel\\iKettle2\\Setup-C-2-STA.pcap',
#  './captures_IoT-Sentinel\\iKettle2\\Setup-C-3-STA.pcap',
#  './captures_IoT-Sentinel\\iKettle2\\Setup-C-4-STA.pcap',
#  './captures_IoT-Sentinel\\iKettle2\\Setup-C-5-STA.pcap',
#  './captures_IoT-Sentinel\\Lightify\\Setup-C-1-STA.pcap',
#  './captures_IoT-Sentinel\\Lightify\\Setup-C-10-STA.pcap',
#  './captures_IoT-Sentinel\\Lightify\\Setup-C-11-STA.pcap',
#  './captures_IoT-Sentinel\\Lightify\\Setup-C-12-STA.pcap',
#  './captures_IoT-Sentinel\\Lightify\\Setup-C-13-STA.pcap',
#  './captures_IoT-Sentinel\\Lightify\\Setup-C-14-STA.pcap',
#  './captures_IoT-Sentinel\\Lightify\\Setup-C-15-STA.pcap',
#  './captures_IoT-Sentinel\\Lightify\\Setup-C-16-STA.pcap',
#  './captures_IoT-Sentinel\\Lightify\\Setup-C-17-STA.pcap',
#  './captures_IoT-Sentinel\\Lightify\\Setup-C-18-STA.pcap',
#  './captures_IoT-Sentinel\\Lightify\\Setup-C-19-STA.pcap',
#  './captures_IoT-Sentinel\\Lightify\\Setup-C-2-STA.pcap',
#  './captures_IoT-Sentinel\\Lightify\\Setup-C-20-STA.pcap',
#  './captures_IoT-Sentinel\\Lightify\\Setup-C-3-STA.pcap',
#  './captures_IoT-Sentinel\\Lightify\\Setup-C-4-STA.pcap',
#  './captures_IoT-Sentinel\\Lightify\\Setup-C-5-STA.pcap',
#  './captures_IoT-Sentinel\\Lightify\\Setup-C-6-STA.pcap',
#  './captures_IoT-Sentinel\\Lightify\\Setup-C-7-STA.pcap',
#  './captures_IoT-Sentinel\\Lightify\\Setup-C-8-STA.pcap',
#  './captures_IoT-Sentinel\\Lightify\\Setup-C-9-STA.pcap',
#  './captures_IoT-Sentinel\\MAXGateway\\Setup-A-1-STA.pcap',
#  './captures_IoT-Sentinel\\MAXGateway\\Setup-A-2-STA.pcap',
#  './captures_IoT-Sentinel\\MAXGateway\\Setup-A-3-STA.pcap',
#  './captures_IoT-Sentinel\\MAXGateway\\Setup-A-4-STA.pcap',
#  './captures_IoT-Sentinel\\MAXGateway\\Setup-A-5-STA.pcap',
#  './captures_IoT-Sentinel\\MAXGateway\\Setup-A-6-STA.pcap',
#  './captures_IoT-Sentinel\\MAXGateway\\Setup-A-7-STA.pcap',
#  './captures_IoT-Sentinel\\MAXGateway\\Setup-A-8-STA.pcap',
#  './captures_IoT-Sentinel\\MAXGateway\\Setup-A-9-STA.pcap',
#  './captures_IoT-Sentinel\\MAXGateway\\Setup-C-1-STA.pcap',
#  './captures_IoT-Sentinel\\MAXGateway\\Setup-C-10-STA.pcap',
#  './captures_IoT-Sentinel\\MAXGateway\\Setup-C-11-STA.pcap',
#  './captures_IoT-Sentinel\\MAXGateway\\Setup-C-2-STA.pcap',
#  './captures_IoT-Sentinel\\MAXGateway\\Setup-C-3-STA.pcap',
#  './captures_IoT-Sentinel\\MAXGateway\\Setup-C-4-STA.pcap',
#  './captures_IoT-Sentinel\\MAXGateway\\Setup-C-5-STA.pcap',
#  './captures_IoT-Sentinel\\MAXGateway\\Setup-C-6-STA.pcap',
#  './captures_IoT-Sentinel\\MAXGateway\\Setup-C-7-STA.pcap',
#  './captures_IoT-Sentinel\\MAXGateway\\Setup-C-8-STA.pcap',
#  './captures_IoT-Sentinel\\MAXGateway\\Setup-C-9-STA.pcap',
#  './captures_IoT-Sentinel\\SmarterCoffee\\Setup-A-1-STA.pcap',
#  './captures_IoT-Sentinel\\SmarterCoffee\\Setup-A-10-STA.pcap',
#  './captures_IoT-Sentinel\\SmarterCoffee\\Setup-A-11-STA.pcap',
#  './captures_IoT-Sentinel\\SmarterCoffee\\Setup-A-12-STA.pcap',
#  './captures_IoT-Sentinel\\SmarterCoffee\\Setup-A-13-STA.pcap',
#  './captures_IoT-Sentinel\\SmarterCoffee\\Setup-A-14-STA.pcap',
#  './captures_IoT-Sentinel\\SmarterCoffee\\Setup-A-15-STA.pcap',
#  './captures_IoT-Sentinel\\SmarterCoffee\\Setup-A-2-STA.pcap',
#  './captures_IoT-Sentinel\\SmarterCoffee\\Setup-A-3-STA.pcap',
#  './captures_IoT-Sentinel\\SmarterCoffee\\Setup-A-4-STA.pcap',
#  './captures_IoT-Sentinel\\SmarterCoffee\\Setup-A-5-STA.pcap',
#  './captures_IoT-Sentinel\\SmarterCoffee\\Setup-A-6-STA.pcap',
#  './captures_IoT-Sentinel\\SmarterCoffee\\Setup-A-7-STA.pcap',
#  './captures_IoT-Sentinel\\SmarterCoffee\\Setup-A-8-STA.pcap',
#  './captures_IoT-Sentinel\\SmarterCoffee\\Setup-A-9-STA.pcap',
#  './captures_IoT-Sentinel\\SmarterCoffee\\Setup-C-1-STA.pcap',
#  './captures_IoT-Sentinel\\SmarterCoffee\\Setup-C-2-STA.pcap',
#  './captures_IoT-Sentinel\\SmarterCoffee\\Setup-C-3-STA.pcap',
#  './captures_IoT-Sentinel\\SmarterCoffee\\Setup-C-4-STA.pcap',
#  './captures_IoT-Sentinel\\SmarterCoffee\\Setup-C-5-STA.pcap',
#  './captures_IoT-Sentinel\\TP-LinkPlugHS100\\Setup-A-1-STA.pcap',
#  './captures_IoT-Sentinel\\TP-LinkPlugHS100\\Setup-A-2-STA.pcap',
#  './captures_IoT-Sentinel\\TP-LinkPlugHS100\\Setup-A-3-STA.pcap',
#  './captures_IoT-Sentinel\\TP-LinkPlugHS100\\Setup-A-4-STA.pcap',
#  './captures_IoT-Sentinel\\TP-LinkPlugHS100\\Setup-A-5-STA.pcap',
#  './captures_IoT-Sentinel\\TP-LinkPlugHS100\\Setup-C-1-STA.pcap',
#  './captures_IoT-Sentinel\\TP-LinkPlugHS100\\Setup-C-10-STA.pcap',
#  './captures_IoT-Sentinel\\TP-LinkPlugHS100\\Setup-C-11-STA.pcap',
#  './captures_IoT-Sentinel\\TP-LinkPlugHS100\\Setup-C-12-STA.pcap',
#  './captures_IoT-Sentinel\\TP-LinkPlugHS100\\Setup-C-13-STA.pcap',
#  './captures_IoT-Sentinel\\TP-LinkPlugHS100\\Setup-C-14-STA.pcap',
#  './captures_IoT-Sentinel\\TP-LinkPlugHS100\\Setup-C-15-STA.pcap',
#  './captures_IoT-Sentinel\\TP-LinkPlugHS100\\Setup-C-2-STA.pcap',
#  './captures_IoT-Sentinel\\TP-LinkPlugHS100\\Setup-C-3-STA.pcap',
#  './captures_IoT-Sentinel\\TP-LinkPlugHS100\\Setup-C-4-STA.pcap',
#  './captures_IoT-Sentinel\\TP-LinkPlugHS100\\Setup-C-5-STA.pcap',
#  './captures_IoT-Sentinel\\TP-LinkPlugHS100\\Setup-C-6-STA.pcap',
#  './captures_IoT-Sentinel\\TP-LinkPlugHS100\\Setup-C-7-STA.pcap',
#  './captures_IoT-Sentinel\\TP-LinkPlugHS100\\Setup-C-8-STA.pcap',
#  './captures_IoT-Sentinel\\TP-LinkPlugHS100\\Setup-C-9-STA.pcap',
#  './captures_IoT-Sentinel\\TP-LinkPlugHS110\\Setup-A-1-STA.pcap',
#  './captures_IoT-Sentinel\\TP-LinkPlugHS110\\Setup-A-10-STA.pcap',
#  './captures_IoT-Sentinel\\TP-LinkPlugHS110\\Setup-A-2-STA.pcap',
#  './captures_IoT-Sentinel\\TP-LinkPlugHS110\\Setup-A-3-STA.pcap',
#  './captures_IoT-Sentinel\\TP-LinkPlugHS110\\Setup-A-4-STA.pcap',
#  './captures_IoT-Sentinel\\TP-LinkPlugHS110\\Setup-A-5-STA.pcap',
#  './captures_IoT-Sentinel\\TP-LinkPlugHS110\\Setup-A-6-STA.pcap',
#  './captures_IoT-Sentinel\\TP-LinkPlugHS110\\Setup-A-7-STA.pcap',
#  './captures_IoT-Sentinel\\TP-LinkPlugHS110\\Setup-A-8-STA.pcap',
#  './captures_IoT-Sentinel\\TP-LinkPlugHS110\\Setup-A-9-STA.pcap',
#  './captures_IoT-Sentinel\\TP-LinkPlugHS110\\Setup-C-1-STA.pcap',
#  './captures_IoT-Sentinel\\TP-LinkPlugHS110\\Setup-C-10-STA.pcap',
#  './captures_IoT-Sentinel\\TP-LinkPlugHS110\\Setup-C-2-STA.pcap',
#  './captures_IoT-Sentinel\\TP-LinkPlugHS110\\Setup-C-3-STA.pcap',
#  './captures_IoT-Sentinel\\TP-LinkPlugHS110\\Setup-C-4-STA.pcap',
#  './captures_IoT-Sentinel\\TP-LinkPlugHS110\\Setup-C-5-STA.pcap',
#  './captures_IoT-Sentinel\\TP-LinkPlugHS110\\Setup-C-6-STA.pcap',
#  './captures_IoT-Sentinel\\TP-LinkPlugHS110\\Setup-C-7-STA.pcap',
#  './captures_IoT-Sentinel\\TP-LinkPlugHS110\\Setup-C-8-STA.pcap',
#  './captures_IoT-Sentinel\\TP-LinkPlugHS110\\Setup-C-9-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoInsightSwitch\\Setup-A-1-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoInsightSwitch\\Setup-A-10-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoInsightSwitch\\Setup-A-11-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoInsightSwitch\\Setup-A-2-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoInsightSwitch\\Setup-A-3-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoInsightSwitch\\Setup-A-4-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoInsightSwitch\\Setup-A-5-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoInsightSwitch\\Setup-A-6-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoInsightSwitch\\Setup-A-7-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoInsightSwitch\\Setup-A-8-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoInsightSwitch\\Setup-A-9-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoInsightSwitch\\Setup-C-1-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoInsightSwitch\\Setup-C-2-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoInsightSwitch\\Setup-C-3-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoInsightSwitch\\Setup-C-4-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoInsightSwitch\\Setup-C-5-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoInsightSwitch\\Setup-C-6-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoInsightSwitch\\Setup-C-7-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoInsightSwitch\\Setup-C-8-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoInsightSwitch\\Setup-C-9-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoInsightSwitch2\\Setup-C-1-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoInsightSwitch2\\Setup-C-2-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoInsightSwitch2\\Setup-C-3-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoInsightSwitch2\\Setup-C-4-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoInsightSwitch2\\Setup-C-5-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoLink\\Setup-A-1-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoLink\\Setup-A-10-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoLink\\Setup-A-11-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoLink\\Setup-A-12-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoLink\\Setup-A-13-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoLink\\Setup-A-14-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoLink\\Setup-A-15-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoLink\\Setup-A-2-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoLink\\Setup-A-3-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoLink\\Setup-A-4-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoLink\\Setup-A-5-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoLink\\Setup-A-6-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoLink\\Setup-A-7-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoLink\\Setup-A-8-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoLink\\Setup-A-9-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoLink\\Setup-C-1-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoLink\\Setup-C-2-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoLink\\Setup-C-3-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoLink\\Setup-C-4-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoLink\\Setup-C-5-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoSwitch\\Setup-A-1-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoSwitch\\Setup-A-10-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoSwitch\\Setup-A-2-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoSwitch\\Setup-A-3-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoSwitch\\Setup-A-4-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoSwitch\\Setup-A-5-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoSwitch\\Setup-A-6-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoSwitch\\Setup-A-7-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoSwitch\\Setup-A-8-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoSwitch\\Setup-A-9-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoSwitch\\Setup-C-1-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoSwitch\\Setup-C-10-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoSwitch\\Setup-C-2-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoSwitch\\Setup-C-3-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoSwitch\\Setup-C-4-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoSwitch\\Setup-C-5-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoSwitch\\Setup-C-6-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoSwitch\\Setup-C-7-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoSwitch\\Setup-C-8-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoSwitch\\Setup-C-9-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoSwitch2\\Setup-C-1-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoSwitch2\\Setup-C-2-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoSwitch2\\Setup-C-3-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoSwitch2\\Setup-C-4-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoSwitch2\\Setup-C-5-STA.pcap',
#  './captures_IoT-Sentinel\\Withings\\Setup-A-1-STA.pcap',
#  './captures_IoT-Sentinel\\Withings\\Setup-C-1-STA.pcap',
#  './captures_IoT-Sentinel\\Withings\\Setup-C-10-STA.pcap',
#  './captures_IoT-Sentinel\\Withings\\Setup-C-11-STA.pcap',
#  './captures_IoT-Sentinel\\Withings\\Setup-C-12-STA.pcap',
#  './captures_IoT-Sentinel\\Withings\\Setup-C-13-STA.pcap',
#  './captures_IoT-Sentinel\\Withings\\Setup-C-14-STA.pcap',
#  './captures_IoT-Sentinel\\Withings\\Setup-C-15-STA.pcap',
#  './captures_IoT-Sentinel\\Withings\\Setup-C-16-STA.pcap',
#  './captures_IoT-Sentinel\\Withings\\Setup-C-17-STA.pcap',
#  './captures_IoT-Sentinel\\Withings\\Setup-C-18-STA.pcap',
#  './captures_IoT-Sentinel\\Withings\\Setup-C-19-STA.pcap',
#  './captures_IoT-Sentinel\\Withings\\Setup-C-2-STA.pcap',
#  './captures_IoT-Sentinel\\Withings\\Setup-C-3-STA.pcap',
#  './captures_IoT-Sentinel\\Withings\\Setup-C-4-STA.pcap',
#  './captures_IoT-Sentinel\\Withings\\Setup-C-5-STA.pcap',
#  './captures_IoT-Sentinel\\Withings\\Setup-C-6-STA.pcap',
#  './captures_IoT-Sentinel\\Withings\\Setup-C-7-STA.pcap',
#  './captures_IoT-Sentinel\\Withings\\Setup-C-8-STA.pcap',
#  './captures_IoT-Sentinel\\Withings\\Setup-C-9-STA.pcap']

# %%
train=[]
test=[]

for ii, i in enumerate(files_add):
    print(ii,i)
    if ii%5==0:
        test.append(i)
    else:
        train.append(i)
# Out:
# 0 ./captures_IoT-Sentinel\Aria\Setup-A-1-STA.pcap
# 1 ./captures_IoT-Sentinel\Aria\Setup-A-2-STA.pcap
# 2 ./captures_IoT-Sentinel\Aria\Setup-A-3-STA.pcap
# 3 ./captures_IoT-Sentinel\Aria\Setup-A-4-STA.pcap
# 4 ./captures_IoT-Sentinel\Aria\Setup-A-5-STA.pcap
# 5 ./captures_IoT-Sentinel\Aria\Setup-C-1-STA.pcap
# 6 ./captures_IoT-Sentinel\Aria\Setup-C-10-STA.pcap
# 7 ./captures_IoT-Sentinel\Aria\Setup-C-11-STA.pcap
# 8 ./captures_IoT-Sentinel\Aria\Setup-C-12-STA.pcap
# 9 ./captures_IoT-Sentinel\Aria\Setup-C-13-STA.pcap
# 10 ./captures_IoT-Sentinel\Aria\Setup-C-14-STA.pcap
# 11 ./captures_IoT-Sentinel\Aria\Setup-C-15-STA.pcap
# 12 ./captures_IoT-Sentinel\Aria\Setup-C-2-STA.pcap
# 13 ./captures_IoT-Sentinel\Aria\Setup-C-3-STA.pcap
# 14 ./captures_IoT-Sentinel\Aria\Setup-C-4-STA.pcap
# 15 ./captures_IoT-Sentinel\Aria\Setup-C-5-STA.pcap
# 16 ./captures_IoT-Sentinel\Aria\Setup-C-6-STA.pcap
# 17 ./captures_IoT-Sentinel\Aria\Setup-C-7-STA.pcap
# 18 ./captures_IoT-Sentinel\Aria\Setup-C-8-STA.pcap
# 19 ./captures_IoT-Sentinel\Aria\Setup-C-9-STA.pcap
# 20 ./captures_IoT-Sentinel\D-LinkCam\Setup-A-1-STA.pcap
# 21 ./captures_IoT-Sentinel\D-LinkCam\Setup-A-2-STA.pcap
# 22 ./captures_IoT-Sentinel\D-LinkCam\Setup-A-3-STA.pcap
# 23 ./captures_IoT-Sentinel\D-LinkCam\Setup-A-4-STA.pcap
# 24 ./captures_IoT-Sentinel\D-LinkCam\Setup-A-5-STA.pcap
# 25 ./captures_IoT-Sentinel\D-LinkCam\Setup-B-1-STA.pcap
# 26 ./captures_IoT-Sentinel\D-LinkCam\Setup-B-2-STA.pcap
# 27 ./captures_IoT-Sentinel\D-LinkCam\Setup-B-3-STA.pcap
# 28 ./captures_IoT-Sentinel\D-LinkCam\Setup-B-4-STA.pcap
# 29 ./captures_IoT-Sentinel\D-LinkCam\Setup-B-5-STA.pcap
# 30 ./captures_IoT-Sentinel\D-LinkCam\Setup-C-1-STA.pcap
# 31 ./captures_IoT-Sentinel\D-LinkCam\Setup-C-10-STA.pcap
# 32 ./captures_IoT-Sentinel\D-LinkCam\Setup-C-2-STA.pcap
# 33 ./captures_IoT-Sentinel\D-LinkCam\Setup-C-3-STA.pcap
# 34 ./captures_IoT-Sentinel\D-LinkCam\Setup-C-4-STA.pcap
# 35 ./captures_IoT-Sentinel\D-LinkCam\Setup-C-5-STA.pcap
# 36 ./captures_IoT-Sentinel\D-LinkCam\Setup-C-6-STA.pcap
# 37 ./captures_IoT-Sentinel\D-LinkCam\Setup-C-7-STA.pcap
# 38 ./captures_IoT-Sentinel\D-LinkCam\Setup-C-8-STA.pcap
# 39 ./captures_IoT-Sentinel\D-LinkCam\Setup-C-9-STA.pcap
# 40 ./captures_IoT-Sentinel\D-LinkDayCam\Setup-A-1-STA.pcap
# 41 ./captures_IoT-Sentinel\D-LinkDayCam\Setup-A-2-STA.pcap
# 42 ./captures_IoT-Sentinel\D-LinkDayCam\Setup-A-3-STA.pcap
# 43 ./captures_IoT-Sentinel\D-LinkDayCam\Setup-A-4-STA.pcap
# 44 ./captures_IoT-Sentinel\D-LinkDayCam\Setup-A-5-STA.pcap
# 45 ./captures_IoT-Sentinel\D-LinkDayCam\Setup-C-1-STA.pcap
# 46 ./captures_IoT-Sentinel\D-LinkDayCam\Setup-C-10-STA.pcap
# 47 ./captures_IoT-Sentinel\D-LinkDayCam\Setup-C-11-STA.pcap
# 48 ./captures_IoT-Sentinel\D-LinkDayCam\Setup-C-12-STA.pcap
# 49 ./captures_IoT-Sentinel\D-LinkDayCam\Setup-C-13-STA.pcap
# 50 ./captures_IoT-Sentinel\D-LinkDayCam\Setup-C-14-STA.pcap
# 51 ./captures_IoT-Sentinel\D-LinkDayCam\Setup-C-15-STA.pcap
# 52 ./captures_IoT-Sentinel\D-LinkDayCam\Setup-C-2-STA.pcap
# 53 ./captures_IoT-Sentinel\D-LinkDayCam\Setup-C-3-STA.pcap
# 54 ./captures_IoT-Sentinel\D-LinkDayCam\Setup-C-4-STA.pcap
# 55 ./captures_IoT-Sentinel\D-LinkDayCam\Setup-C-5-STA.pcap
# 56 ./captures_IoT-Sentinel\D-LinkDayCam\Setup-C-6-STA.pcap
# 57 ./captures_IoT-Sentinel\D-LinkDayCam\Setup-C-7-STA.pcap
# 58 ./captures_IoT-Sentinel\D-LinkDayCam\Setup-C-8-STA.pcap
# 59 ./captures_IoT-Sentinel\D-LinkDayCam\Setup-C-9-STA.pcap
# 60 ./captures_IoT-Sentinel\D-LinkDoorSensor\Setup-C-1-STA.pcap
# 61 ./captures_IoT-Sentinel\D-LinkDoorSensor\Setup-C-10-STA.pcap
# 62 ./captures_IoT-Sentinel\D-LinkDoorSensor\Setup-C-11-STA.pcap
# 63 ./captures_IoT-Sentinel\D-LinkDoorSensor\Setup-C-12-STA.pcap
# 64 ./captures_IoT-Sentinel\D-LinkDoorSensor\Setup-C-13-STA.pcap
# 65 ./captures_IoT-Sentinel\D-LinkDoorSensor\Setup-C-14-STA.pcap
# 66 ./captures_IoT-Sentinel\D-LinkDoorSensor\Setup-C-15-STA.pcap
# 67 ./captures_IoT-Sentinel\D-LinkDoorSensor\Setup-C-16-STA.pcap
# 68 ./captures_IoT-Sentinel\D-LinkDoorSensor\Setup-C-17-STA.pcap
# 69 ./captures_IoT-Sentinel\D-LinkDoorSensor\Setup-C-18-STA.pcap
# 70 ./captures_IoT-Sentinel\D-LinkDoorSensor\Setup-C-19-STA.pcap
# 71 ./captures_IoT-Sentinel\D-LinkDoorSensor\Setup-C-2-STA.pcap
# 72 ./captures_IoT-Sentinel\D-LinkDoorSensor\Setup-C-20-STA.pcap
# 73 ./captures_IoT-Sentinel\D-LinkDoorSensor\Setup-C-3-STA.pcap
# 74 ./captures_IoT-Sentinel\D-LinkDoorSensor\Setup-C-4-STA.pcap
# 75 ./captures_IoT-Sentinel\D-LinkDoorSensor\Setup-C-5-STA.pcap
# 76 ./captures_IoT-Sentinel\D-LinkDoorSensor\Setup-C-6-STA.pcap
# 77 ./captures_IoT-Sentinel\D-LinkDoorSensor\Setup-C-7-STA.pcap
# 78 ./captures_IoT-Sentinel\D-LinkDoorSensor\Setup-C-8-STA.pcap
# 79 ./captures_IoT-Sentinel\D-LinkDoorSensor\Setup-C-9-STA.pcap
# 80 ./captures_IoT-Sentinel\D-LinkHomeHub\Setup-A-1-STA.pcap
# 81 ./captures_IoT-Sentinel\D-LinkHomeHub\Setup-A-2-STA.pcap
# 82 ./captures_IoT-Sentinel\D-LinkHomeHub\Setup-A-3-STA.pcap
# 83 ./captures_IoT-Sentinel\D-LinkHomeHub\Setup-A-4-STA.pcap
# 84 ./captures_IoT-Sentinel\D-LinkHomeHub\Setup-A-5-STA.pcap
# 85 ./captures_IoT-Sentinel\D-LinkHomeHub\Setup-C-1-STA.pcap
# 86 ./captures_IoT-Sentinel\D-LinkHomeHub\Setup-C-10-STA.pcap
# 87 ./captures_IoT-Sentinel\D-LinkHomeHub\Setup-C-11-STA.pcap
# 88 ./captures_IoT-Sentinel\D-LinkHomeHub\Setup-C-12-STA.pcap
# 89 ./captures_IoT-Sentinel\D-LinkHomeHub\Setup-C-13-STA.pcap
# 90 ./captures_IoT-Sentinel\D-LinkHomeHub\Setup-C-14-STA.pcap
# 91 ./captures_IoT-Sentinel\D-LinkHomeHub\Setup-C-15-STA.pcap
# 92 ./captures_IoT-Sentinel\D-LinkHomeHub\Setup-C-2-STA.pcap
# 93 ./captures_IoT-Sentinel\D-LinkHomeHub\Setup-C-3-STA.pcap
# 94 ./captures_IoT-Sentinel\D-LinkHomeHub\Setup-C-4-STA.pcap
# 95 ./captures_IoT-Sentinel\D-LinkHomeHub\Setup-C-5-STA.pcap
# 96 ./captures_IoT-Sentinel\D-LinkHomeHub\Setup-C-6-STA.pcap
# 97 ./captures_IoT-Sentinel\D-LinkHomeHub\Setup-C-7-STA.pcap
# 98 ./captures_IoT-Sentinel\D-LinkHomeHub\Setup-C-8-STA.pcap
# 99 ./captures_IoT-Sentinel\D-LinkHomeHub\Setup-C-9-STA.pcap
# 100 ./captures_IoT-Sentinel\D-LinkSensor\Setup-A-1-STA.pcap
# 101 ./captures_IoT-Sentinel\D-LinkSensor\Setup-A-2-STA.pcap
# 102 ./captures_IoT-Sentinel\D-LinkSensor\Setup-A-3-STA.pcap
# 103 ./captures_IoT-Sentinel\D-LinkSensor\Setup-A-4-STA.pcap
# 104 ./captures_IoT-Sentinel\D-LinkSensor\Setup-A-5-STA.pcap
# 105 ./captures_IoT-Sentinel\D-LinkSensor\Setup-B-1-STA.pcap
# 106 ./captures_IoT-Sentinel\D-LinkSensor\Setup-B-2-STA.pcap
# 107 ./captures_IoT-Sentinel\D-LinkSensor\Setup-B-3-STA.pcap
# 108 ./captures_IoT-Sentinel\D-LinkSensor\Setup-B-4-STA.pcap
# 109 ./captures_IoT-Sentinel\D-LinkSensor\Setup-B-5-STA.pcap
# 110 ./captures_IoT-Sentinel\D-LinkSensor\Setup-C-1-STA.pcap
# 111 ./captures_IoT-Sentinel\D-LinkSensor\Setup-C-10-STA.pcap
# 112 ./captures_IoT-Sentinel\D-LinkSensor\Setup-C-2-STA.pcap
# 113 ./captures_IoT-Sentinel\D-LinkSensor\Setup-C-3-STA.pcap
# 114 ./captures_IoT-Sentinel\D-LinkSensor\Setup-C-4-STA.pcap
# 115 ./captures_IoT-Sentinel\D-LinkSensor\Setup-C-5-STA.pcap
# 116 ./captures_IoT-Sentinel\D-LinkSensor\Setup-C-6-STA.pcap
# 117 ./captures_IoT-Sentinel\D-LinkSensor\Setup-C-7-STA.pcap
# 118 ./captures_IoT-Sentinel\D-LinkSensor\Setup-C-8-STA.pcap
# 119 ./captures_IoT-Sentinel\D-LinkSensor\Setup-C-9-STA.pcap
# 120 ./captures_IoT-Sentinel\D-LinkSiren\Setup-A-1-STA.pcap
# 121 ./captures_IoT-Sentinel\D-LinkSiren\Setup-C-1-STA.pcap
# 122 ./captures_IoT-Sentinel\D-LinkSiren\Setup-C-10-STA.pcap
# 123 ./captures_IoT-Sentinel\D-LinkSiren\Setup-C-11-STA.pcap
# 124 ./captures_IoT-Sentinel\D-LinkSiren\Setup-C-12-STA.pcap
# 125 ./captures_IoT-Sentinel\D-LinkSiren\Setup-C-13-STA.pcap
# 126 ./captures_IoT-Sentinel\D-LinkSiren\Setup-C-14-STA.pcap
# 127 ./captures_IoT-Sentinel\D-LinkSiren\Setup-C-15-STA.pcap
# 128 ./captures_IoT-Sentinel\D-LinkSiren\Setup-C-16-STA.pcap
# 129 ./captures_IoT-Sentinel\D-LinkSiren\Setup-C-17-STA.pcap
# 130 ./captures_IoT-Sentinel\D-LinkSiren\Setup-C-18-STA.pcap
# 131 ./captures_IoT-Sentinel\D-LinkSiren\Setup-C-19-STA.pcap
# 132 ./captures_IoT-Sentinel\D-LinkSiren\Setup-C-2-STA.pcap
# 133 ./captures_IoT-Sentinel\D-LinkSiren\Setup-C-3-STA.pcap
# 134 ./captures_IoT-Sentinel\D-LinkSiren\Setup-C-4-STA.pcap
# 135 ./captures_IoT-Sentinel\D-LinkSiren\Setup-C-5-STA.pcap
# 136 ./captures_IoT-Sentinel\D-LinkSiren\Setup-C-6-STA.pcap
# 137 ./captures_IoT-Sentinel\D-LinkSiren\Setup-C-7-STA.pcap
# 138 ./captures_IoT-Sentinel\D-LinkSiren\Setup-C-8-STA.pcap
# 139 ./captures_IoT-Sentinel\D-LinkSiren\Setup-C-9-STA.pcap
# 140 ./captures_IoT-Sentinel\D-LinkSwitch\Setup-A-1-STA.pcap
# 141 ./captures_IoT-Sentinel\D-LinkSwitch\Setup-A-2-STA.pcap
# 142 ./captures_IoT-Sentinel\D-LinkSwitch\Setup-A-3-STA.pcap
# 143 ./captures_IoT-Sentinel\D-LinkSwitch\Setup-A-4-STA.pcap
# 144 ./captures_IoT-Sentinel\D-LinkSwitch\Setup-A-5-STA.pcap
# 145 ./captures_IoT-Sentinel\D-LinkSwitch\Setup-C-1-STA.pcap
# 146 ./captures_IoT-Sentinel\D-LinkSwitch\Setup-C-10-STA.pcap
# 147 ./captures_IoT-Sentinel\D-LinkSwitch\Setup-C-11-STA.pcap
# 148 ./captures_IoT-Sentinel\D-LinkSwitch\Setup-C-12-STA.pcap
# 149 ./captures_IoT-Sentinel\D-LinkSwitch\Setup-C-13-STA.pcap
# 150 ./captures_IoT-Sentinel\D-LinkSwitch\Setup-C-14-STA.pcap
# 151 ./captures_IoT-Sentinel\D-LinkSwitch\Setup-C-15-STA.pcap
# 152 ./captures_IoT-Sentinel\D-LinkSwitch\Setup-C-2-STA.pcap
# 153 ./captures_IoT-Sentinel\D-LinkSwitch\Setup-C-3-STA.pcap
# 154 ./captures_IoT-Sentinel\D-LinkSwitch\Setup-C-4-STA.pcap
# 155 ./captures_IoT-Sentinel\D-LinkSwitch\Setup-C-5-STA.pcap
# 156 ./captures_IoT-Sentinel\D-LinkSwitch\Setup-C-6-STA.pcap
# 157 ./captures_IoT-Sentinel\D-LinkSwitch\Setup-C-7-STA.pcap
# 158 ./captures_IoT-Sentinel\D-LinkSwitch\Setup-C-8-STA.pcap
# 159 ./captures_IoT-Sentinel\D-LinkSwitch\Setup-C-9-STA.pcap
# 160 ./captures_IoT-Sentinel\D-LinkWaterSensor\Setup-A-1-STA.pcap
# 161 ./captures_IoT-Sentinel\D-LinkWaterSensor\Setup-C-1-STA.pcap
# 162 ./captures_IoT-Sentinel\D-LinkWaterSensor\Setup-C-10-STA.pcap
# 163 ./captures_IoT-Sentinel\D-LinkWaterSensor\Setup-C-11-STA.pcap
# 164 ./captures_IoT-Sentinel\D-LinkWaterSensor\Setup-C-12-STA.pcap
# 165 ./captures_IoT-Sentinel\D-LinkWaterSensor\Setup-C-13-STA.pcap
# 166 ./captures_IoT-Sentinel\D-LinkWaterSensor\Setup-C-14-STA.pcap
# 167 ./captures_IoT-Sentinel\D-LinkWaterSensor\Setup-C-15-STA.pcap
# 168 ./captures_IoT-Sentinel\D-LinkWaterSensor\Setup-C-16-STA.pcap
# 169 ./captures_IoT-Sentinel\D-LinkWaterSensor\Setup-C-17-STA.pcap
# 170 ./captures_IoT-Sentinel\D-LinkWaterSensor\Setup-C-18-STA.pcap
# 171 ./captures_IoT-Sentinel\D-LinkWaterSensor\Setup-C-19-STA.pcap
# 172 ./captures_IoT-Sentinel\D-LinkWaterSensor\Setup-C-2-STA.pcap
# 173 ./captures_IoT-Sentinel\D-LinkWaterSensor\Setup-C-3-STA.pcap
# 174 ./captures_IoT-Sentinel\D-LinkWaterSensor\Setup-C-4-STA.pcap
# 175 ./captures_IoT-Sentinel\D-LinkWaterSensor\Setup-C-5-STA.pcap
# 176 ./captures_IoT-Sentinel\D-LinkWaterSensor\Setup-C-6-STA.pcap
# 177 ./captures_IoT-Sentinel\D-LinkWaterSensor\Setup-C-7-STA.pcap
# 178 ./captures_IoT-Sentinel\D-LinkWaterSensor\Setup-C-8-STA.pcap
# 179 ./captures_IoT-Sentinel\D-LinkWaterSensor\Setup-C-9-STA.pcap
# 180 ./captures_IoT-Sentinel\EdimaxCam1\Setup-A-1-STA.pcap
# 181 ./captures_IoT-Sentinel\EdimaxCam1\Setup-A-2-STA.pcap
# 182 ./captures_IoT-Sentinel\EdimaxCam1\Setup-A-3-STA.pcap
# 183 ./captures_IoT-Sentinel\EdimaxCam1\Setup-A-4-STA.pcap
# 184 ./captures_IoT-Sentinel\EdimaxCam1\Setup-A-5-STA.pcap
# 185 ./captures_IoT-Sentinel\EdimaxCam1\Setup-A-6-STA.pcap
# 186 ./captures_IoT-Sentinel\EdimaxCam1\Setup-A-7-STA.pcap
# 187 ./captures_IoT-Sentinel\EdimaxCam1\Setup-C-1-STA.pcap
# 188 ./captures_IoT-Sentinel\EdimaxCam1\Setup-C-2-STA.pcap
# 189 ./captures_IoT-Sentinel\EdimaxCam1\Setup-C-3-STA.pcap
# 190 ./captures_IoT-Sentinel\EdimaxCam1\Setup-C-4-STA.pcap
# 191 ./captures_IoT-Sentinel\EdimaxCam1\Setup-C-5-STA.pcap
# 192 ./captures_IoT-Sentinel\EdimaxCam2\Setup-A-1-STA.pcap
# 193 ./captures_IoT-Sentinel\EdimaxCam2\Setup-A-2-STA.pcap
# 194 ./captures_IoT-Sentinel\EdimaxCam2\Setup-A-3-STA.pcap
# 195 ./captures_IoT-Sentinel\EdimaxCam2\Setup-A-4-STA.pcap
# 196 ./captures_IoT-Sentinel\EdimaxCam2\Setup-C-1-STA.pcap
# 197 ./captures_IoT-Sentinel\EdimaxCam2\Setup-C-2-STA.pcap
# 198 ./captures_IoT-Sentinel\EdimaxCam2\Setup-C-3-STA.pcap
# 199 ./captures_IoT-Sentinel\EdimaxCam2\Setup-C-4-STA.pcap
# 200 ./captures_IoT-Sentinel\EdimaxPlug1101W\Setup-A-1-STA.pcap
# 201 ./captures_IoT-Sentinel\EdimaxPlug1101W\Setup-A-2-STA.pcap
# 202 ./captures_IoT-Sentinel\EdimaxPlug1101W\Setup-A-3-STA.pcap
# 203 ./captures_IoT-Sentinel\EdimaxPlug1101W\Setup-A-4-STA.pcap
# 204 ./captures_IoT-Sentinel\EdimaxPlug1101W\Setup-A-5-STA.pcap
# 205 ./captures_IoT-Sentinel\EdimaxPlug1101W\Setup-C-1-STA.pcap
# 206 ./captures_IoT-Sentinel\EdimaxPlug1101W\Setup-C-10-STA.pcap
# 207 ./captures_IoT-Sentinel\EdimaxPlug1101W\Setup-C-11-STA.pcap
# 208 ./captures_IoT-Sentinel\EdimaxPlug1101W\Setup-C-12-STA.pcap
# 209 ./captures_IoT-Sentinel\EdimaxPlug1101W\Setup-C-13-STA.pcap
# 210 ./captures_IoT-Sentinel\EdimaxPlug1101W\Setup-C-14-STA.pcap
# 211 ./captures_IoT-Sentinel\EdimaxPlug1101W\Setup-C-15-STA.pcap
# 212 ./captures_IoT-Sentinel\EdimaxPlug1101W\Setup-C-2-STA.pcap
# 213 ./captures_IoT-Sentinel\EdimaxPlug1101W\Setup-C-3-STA.pcap
# 214 ./captures_IoT-Sentinel\EdimaxPlug1101W\Setup-C-4-STA.pcap
# 215 ./captures_IoT-Sentinel\EdimaxPlug1101W\Setup-C-5-STA.pcap
# 216 ./captures_IoT-Sentinel\EdimaxPlug1101W\Setup-C-6-STA.pcap
# 217 ./captures_IoT-Sentinel\EdimaxPlug1101W\Setup-C-7-STA.pcap
# 218 ./captures_IoT-Sentinel\EdimaxPlug1101W\Setup-C-8-STA.pcap
# 219 ./captures_IoT-Sentinel\EdimaxPlug1101W\Setup-C-9-STA.pcap
# 220 ./captures_IoT-Sentinel\EdimaxPlug2101W\Setup-A-1-STA.pcap
# 221 ./captures_IoT-Sentinel\EdimaxPlug2101W\Setup-A-2-STA.pcap
# 222 ./captures_IoT-Sentinel\EdimaxPlug2101W\Setup-A-3-STA.pcap
# 223 ./captures_IoT-Sentinel\EdimaxPlug2101W\Setup-A-4-STA.pcap
# 224 ./captures_IoT-Sentinel\EdimaxPlug2101W\Setup-A-5-STA.pcap
# 225 ./captures_IoT-Sentinel\EdimaxPlug2101W\Setup-C-1-STA.pcap
# 226 ./captures_IoT-Sentinel\EdimaxPlug2101W\Setup-C-10-STA.pcap
# 227 ./captures_IoT-Sentinel\EdimaxPlug2101W\Setup-C-11-STA.pcap
# 228 ./captures_IoT-Sentinel\EdimaxPlug2101W\Setup-C-12-STA.pcap
# 229 ./captures_IoT-Sentinel\EdimaxPlug2101W\Setup-C-13-STA.pcap
# 230 ./captures_IoT-Sentinel\EdimaxPlug2101W\Setup-C-14-STA.pcap
# 231 ./captures_IoT-Sentinel\EdimaxPlug2101W\Setup-C-15-STA.pcap
# 232 ./captures_IoT-Sentinel\EdimaxPlug2101W\Setup-C-2-STA.pcap
# 233 ./captures_IoT-Sentinel\EdimaxPlug2101W\Setup-C-3-STA.pcap
# 234 ./captures_IoT-Sentinel\EdimaxPlug2101W\Setup-C-4-STA.pcap
# 235 ./captures_IoT-Sentinel\EdimaxPlug2101W\Setup-C-5-STA.pcap
# 236 ./captures_IoT-Sentinel\EdimaxPlug2101W\Setup-C-6-STA.pcap
# 237 ./captures_IoT-Sentinel\EdimaxPlug2101W\Setup-C-7-STA.pcap
# 238 ./captures_IoT-Sentinel\EdimaxPlug2101W\Setup-C-8-STA.pcap
# 239 ./captures_IoT-Sentinel\EdimaxPlug2101W\Setup-C-9-STA.pcap
# 240 ./captures_IoT-Sentinel\EdnetCam1\Setup-A-1-STA.pcap
# 241 ./captures_IoT-Sentinel\EdnetCam1\Setup-C-1-STA.pcap
# 242 ./captures_IoT-Sentinel\EdnetCam1\Setup-C-10-STA.pcap
# 243 ./captures_IoT-Sentinel\EdnetCam1\Setup-C-2-STA.pcap
# 244 ./captures_IoT-Sentinel\EdnetCam1\Setup-C-3-STA.pcap
# 245 ./captures_IoT-Sentinel\EdnetCam1\Setup-C-4-STA.pcap
# 246 ./captures_IoT-Sentinel\EdnetCam1\Setup-C-5-STA.pcap
# 247 ./captures_IoT-Sentinel\EdnetCam1\Setup-C-6-STA.pcap
# 248 ./captures_IoT-Sentinel\EdnetCam1\Setup-C-7-STA.pcap
# 249 ./captures_IoT-Sentinel\EdnetCam1\Setup-C-8-STA.pcap
# 250 ./captures_IoT-Sentinel\EdnetCam1\Setup-C-9-STA.pcap
# 251 ./captures_IoT-Sentinel\EdnetCam2\Setup-A-1-STA.pcap
# 252 ./captures_IoT-Sentinel\EdnetCam2\Setup-C-1-STA.pcap
# 253 ./captures_IoT-Sentinel\EdnetCam2\Setup-C-2-STA.pcap
# 254 ./captures_IoT-Sentinel\EdnetCam2\Setup-C-3-STA.pcap
# 255 ./captures_IoT-Sentinel\EdnetCam2\Setup-C-4-STA.pcap
# 256 ./captures_IoT-Sentinel\EdnetCam2\Setup-C-5-STA.pcap
# 257 ./captures_IoT-Sentinel\EdnetCam2\Setup-C-6-STA.pcap
# 258 ./captures_IoT-Sentinel\EdnetCam2\Setup-C-7-STA.pcap
# 259 ./captures_IoT-Sentinel\EdnetCam2\Setup-C-8-STA.pcap
# 260 ./captures_IoT-Sentinel\EdnetGateway\Setup-A-1-STA.pcap
# 261 ./captures_IoT-Sentinel\EdnetGateway\Setup-A-2-STA.pcap
# 262 ./captures_IoT-Sentinel\EdnetGateway\Setup-C-1-STA.pcap
# 263 ./captures_IoT-Sentinel\EdnetGateway\Setup-C-10-STA.pcap
# 264 ./captures_IoT-Sentinel\EdnetGateway\Setup-C-11-STA.pcap
# 265 ./captures_IoT-Sentinel\EdnetGateway\Setup-C-12-STA.pcap
# 266 ./captures_IoT-Sentinel\EdnetGateway\Setup-C-13-STA.pcap
# 267 ./captures_IoT-Sentinel\EdnetGateway\Setup-C-14-STA.pcap
# 268 ./captures_IoT-Sentinel\EdnetGateway\Setup-C-15-STA.pcap
# 269 ./captures_IoT-Sentinel\EdnetGateway\Setup-C-16-STA.pcap
# 270 ./captures_IoT-Sentinel\EdnetGateway\Setup-C-17-STA.pcap
# 271 ./captures_IoT-Sentinel\EdnetGateway\Setup-C-18-STA.pcap
# 272 ./captures_IoT-Sentinel\EdnetGateway\Setup-C-2-STA.pcap
# 273 ./captures_IoT-Sentinel\EdnetGateway\Setup-C-3-STA.pcap
# 274 ./captures_IoT-Sentinel\EdnetGateway\Setup-C-4-STA.pcap
# 275 ./captures_IoT-Sentinel\EdnetGateway\Setup-C-5-STA.pcap
# 276 ./captures_IoT-Sentinel\EdnetGateway\Setup-C-6-STA.pcap
# 277 ./captures_IoT-Sentinel\EdnetGateway\Setup-C-7-STA.pcap
# 278 ./captures_IoT-Sentinel\EdnetGateway\Setup-C-8-STA.pcap
# 279 ./captures_IoT-Sentinel\EdnetGateway\Setup-C-9-STA.pcap
# 280 ./captures_IoT-Sentinel\HomeMaticPlug\Setup-C-1-STA.pcap
# 281 ./captures_IoT-Sentinel\HomeMaticPlug\Setup-C-10-STA.pcap
# 282 ./captures_IoT-Sentinel\HomeMaticPlug\Setup-C-11-STA.pcap
# 283 ./captures_IoT-Sentinel\HomeMaticPlug\Setup-C-12-STA.pcap
# 284 ./captures_IoT-Sentinel\HomeMaticPlug\Setup-C-13-STA.pcap
# 285 ./captures_IoT-Sentinel\HomeMaticPlug\Setup-C-14-STA.pcap
# 286 ./captures_IoT-Sentinel\HomeMaticPlug\Setup-C-15-STA.pcap
# 287 ./captures_IoT-Sentinel\HomeMaticPlug\Setup-C-16-STA.pcap
# 288 ./captures_IoT-Sentinel\HomeMaticPlug\Setup-C-17-STA.pcap
# 289 ./captures_IoT-Sentinel\HomeMaticPlug\Setup-C-18-STA.pcap
# 290 ./captures_IoT-Sentinel\HomeMaticPlug\Setup-C-19-STA.pcap
# 291 ./captures_IoT-Sentinel\HomeMaticPlug\Setup-C-2-STA.pcap
# 292 ./captures_IoT-Sentinel\HomeMaticPlug\Setup-C-20-STA.pcap
# 293 ./captures_IoT-Sentinel\HomeMaticPlug\Setup-C-3-STA.pcap
# 294 ./captures_IoT-Sentinel\HomeMaticPlug\Setup-C-4-STA.pcap
# 295 ./captures_IoT-Sentinel\HomeMaticPlug\Setup-C-5-STA.pcap
# 296 ./captures_IoT-Sentinel\HomeMaticPlug\Setup-C-6-STA.pcap
# 297 ./captures_IoT-Sentinel\HomeMaticPlug\Setup-C-7-STA.pcap
# 298 ./captures_IoT-Sentinel\HomeMaticPlug\Setup-C-8-STA.pcap
# 299 ./captures_IoT-Sentinel\HomeMaticPlug\Setup-C-9-STA.pcap
# 300 ./captures_IoT-Sentinel\HueBridge\Setup-A-1-STA.pcap
# 301 ./captures_IoT-Sentinel\HueBridge\Setup-A-2-STA.pcap
# 302 ./captures_IoT-Sentinel\HueBridge\Setup-A-3-STA.pcap
# 303 ./captures_IoT-Sentinel\HueBridge\Setup-A-4-STA.pcap
# 304 ./captures_IoT-Sentinel\HueBridge\Setup-A-5-STA.pcap
# 305 ./captures_IoT-Sentinel\HueBridge\Setup-C-1-STA.pcap
# 306 ./captures_IoT-Sentinel\HueBridge\Setup-C-10-STA.pcap
# 307 ./captures_IoT-Sentinel\HueBridge\Setup-C-11-STA.pcap
# 308 ./captures_IoT-Sentinel\HueBridge\Setup-C-12-STA.pcap
# 309 ./captures_IoT-Sentinel\HueBridge\Setup-C-13-STA.pcap
# 310 ./captures_IoT-Sentinel\HueBridge\Setup-C-14-STA.pcap
# 311 ./captures_IoT-Sentinel\HueBridge\Setup-C-15-STA.pcap
# 312 ./captures_IoT-Sentinel\HueBridge\Setup-C-2-STA.pcap
# 313 ./captures_IoT-Sentinel\HueBridge\Setup-C-3-STA.pcap
# 314 ./captures_IoT-Sentinel\HueBridge\Setup-C-4-STA.pcap
# 315 ./captures_IoT-Sentinel\HueBridge\Setup-C-5-STA.pcap
# 316 ./captures_IoT-Sentinel\HueBridge\Setup-C-6-STA.pcap
# 317 ./captures_IoT-Sentinel\HueBridge\Setup-C-7-STA.pcap
# 318 ./captures_IoT-Sentinel\HueBridge\Setup-C-8-STA.pcap
# 319 ./captures_IoT-Sentinel\HueBridge\Setup-C-9-STA.pcap
# 320 ./captures_IoT-Sentinel\HueSwitch\Setup-A-1-STA.pcap
# 321 ./captures_IoT-Sentinel\HueSwitch\Setup-A-10-STA.pcap
# 322 ./captures_IoT-Sentinel\HueSwitch\Setup-A-2-STA.pcap
# 323 ./captures_IoT-Sentinel\HueSwitch\Setup-A-3-STA.pcap
# 324 ./captures_IoT-Sentinel\HueSwitch\Setup-A-4-STA.pcap
# 325 ./captures_IoT-Sentinel\HueSwitch\Setup-A-5-STA.pcap
# 326 ./captures_IoT-Sentinel\HueSwitch\Setup-A-6-STA.pcap
# 327 ./captures_IoT-Sentinel\HueSwitch\Setup-A-7-STA.pcap
# 328 ./captures_IoT-Sentinel\HueSwitch\Setup-A-8-STA.pcap
# 329 ./captures_IoT-Sentinel\HueSwitch\Setup-A-9-STA.pcap
# 330 ./captures_IoT-Sentinel\HueSwitch\Setup-C-1-STA.pcap
# 331 ./captures_IoT-Sentinel\HueSwitch\Setup-C-10-STA.pcap
# 332 ./captures_IoT-Sentinel\HueSwitch\Setup-C-2-STA.pcap
# 333 ./captures_IoT-Sentinel\HueSwitch\Setup-C-3-STA.pcap
# 334 ./captures_IoT-Sentinel\HueSwitch\Setup-C-4-STA.pcap
# 335 ./captures_IoT-Sentinel\HueSwitch\Setup-C-5-STA.pcap
# 336 ./captures_IoT-Sentinel\HueSwitch\Setup-C-6-STA.pcap
# 337 ./captures_IoT-Sentinel\HueSwitch\Setup-C-7-STA.pcap
# 338 ./captures_IoT-Sentinel\HueSwitch\Setup-C-8-STA.pcap
# 339 ./captures_IoT-Sentinel\HueSwitch\Setup-C-9-STA.pcap
# 340 ./captures_IoT-Sentinel\iKettle2\Setup-A-1-STA.pcap
# 341 ./captures_IoT-Sentinel\iKettle2\Setup-A-10-STA.pcap
# 342 ./captures_IoT-Sentinel\iKettle2\Setup-A-11-STA.pcap
# 343 ./captures_IoT-Sentinel\iKettle2\Setup-A-12-STA.pcap
# 344 ./captures_IoT-Sentinel\iKettle2\Setup-A-13-STA.pcap
# 345 ./captures_IoT-Sentinel\iKettle2\Setup-A-14-STA.pcap
# 346 ./captures_IoT-Sentinel\iKettle2\Setup-A-15-STA.pcap
# 347 ./captures_IoT-Sentinel\iKettle2\Setup-A-2-STA.pcap
# 348 ./captures_IoT-Sentinel\iKettle2\Setup-A-3-STA.pcap
# 349 ./captures_IoT-Sentinel\iKettle2\Setup-A-4-STA.pcap
# 350 ./captures_IoT-Sentinel\iKettle2\Setup-A-5-STA.pcap
# 351 ./captures_IoT-Sentinel\iKettle2\Setup-A-6-STA.pcap
# 352 ./captures_IoT-Sentinel\iKettle2\Setup-A-7-STA.pcap
# 353 ./captures_IoT-Sentinel\iKettle2\Setup-A-8-STA.pcap
# 354 ./captures_IoT-Sentinel\iKettle2\Setup-A-9-STA.pcap
# 355 ./captures_IoT-Sentinel\iKettle2\Setup-C-1-STA.pcap
# 356 ./captures_IoT-Sentinel\iKettle2\Setup-C-2-STA.pcap
# 357 ./captures_IoT-Sentinel\iKettle2\Setup-C-3-STA.pcap
# 358 ./captures_IoT-Sentinel\iKettle2\Setup-C-4-STA.pcap
# 359 ./captures_IoT-Sentinel\iKettle2\Setup-C-5-STA.pcap
# 360 ./captures_IoT-Sentinel\Lightify\Setup-C-1-STA.pcap
# 361 ./captures_IoT-Sentinel\Lightify\Setup-C-10-STA.pcap
# 362 ./captures_IoT-Sentinel\Lightify\Setup-C-11-STA.pcap
# 363 ./captures_IoT-Sentinel\Lightify\Setup-C-12-STA.pcap
# 364 ./captures_IoT-Sentinel\Lightify\Setup-C-13-STA.pcap
# 365 ./captures_IoT-Sentinel\Lightify\Setup-C-14-STA.pcap
# 366 ./captures_IoT-Sentinel\Lightify\Setup-C-15-STA.pcap
# 367 ./captures_IoT-Sentinel\Lightify\Setup-C-16-STA.pcap
# 368 ./captures_IoT-Sentinel\Lightify\Setup-C-17-STA.pcap
# 369 ./captures_IoT-Sentinel\Lightify\Setup-C-18-STA.pcap
# 370 ./captures_IoT-Sentinel\Lightify\Setup-C-19-STA.pcap
# 371 ./captures_IoT-Sentinel\Lightify\Setup-C-2-STA.pcap
# 372 ./captures_IoT-Sentinel\Lightify\Setup-C-20-STA.pcap
# 373 ./captures_IoT-Sentinel\Lightify\Setup-C-3-STA.pcap
# 374 ./captures_IoT-Sentinel\Lightify\Setup-C-4-STA.pcap
# 375 ./captures_IoT-Sentinel\Lightify\Setup-C-5-STA.pcap
# 376 ./captures_IoT-Sentinel\Lightify\Setup-C-6-STA.pcap
# 377 ./captures_IoT-Sentinel\Lightify\Setup-C-7-STA.pcap
# 378 ./captures_IoT-Sentinel\Lightify\Setup-C-8-STA.pcap
# 379 ./captures_IoT-Sentinel\Lightify\Setup-C-9-STA.pcap
# 380 ./captures_IoT-Sentinel\MAXGateway\Setup-A-1-STA.pcap
# 381 ./captures_IoT-Sentinel\MAXGateway\Setup-A-2-STA.pcap
# 382 ./captures_IoT-Sentinel\MAXGateway\Setup-A-3-STA.pcap
# 383 ./captures_IoT-Sentinel\MAXGateway\Setup-A-4-STA.pcap
# 384 ./captures_IoT-Sentinel\MAXGateway\Setup-A-5-STA.pcap
# 385 ./captures_IoT-Sentinel\MAXGateway\Setup-A-6-STA.pcap
# 386 ./captures_IoT-Sentinel\MAXGateway\Setup-A-7-STA.pcap
# 387 ./captures_IoT-Sentinel\MAXGateway\Setup-A-8-STA.pcap
# 388 ./captures_IoT-Sentinel\MAXGateway\Setup-A-9-STA.pcap
# 389 ./captures_IoT-Sentinel\MAXGateway\Setup-C-1-STA.pcap
# 390 ./captures_IoT-Sentinel\MAXGateway\Setup-C-10-STA.pcap
# 391 ./captures_IoT-Sentinel\MAXGateway\Setup-C-11-STA.pcap
# 392 ./captures_IoT-Sentinel\MAXGateway\Setup-C-2-STA.pcap
# 393 ./captures_IoT-Sentinel\MAXGateway\Setup-C-3-STA.pcap
# 394 ./captures_IoT-Sentinel\MAXGateway\Setup-C-4-STA.pcap
# 395 ./captures_IoT-Sentinel\MAXGateway\Setup-C-5-STA.pcap
# 396 ./captures_IoT-Sentinel\MAXGateway\Setup-C-6-STA.pcap
# 397 ./captures_IoT-Sentinel\MAXGateway\Setup-C-7-STA.pcap
# 398 ./captures_IoT-Sentinel\MAXGateway\Setup-C-8-STA.pcap
# 399 ./captures_IoT-Sentinel\MAXGateway\Setup-C-9-STA.pcap
# 400 ./captures_IoT-Sentinel\SmarterCoffee\Setup-A-1-STA.pcap
# 401 ./captures_IoT-Sentinel\SmarterCoffee\Setup-A-10-STA.pcap
# 402 ./captures_IoT-Sentinel\SmarterCoffee\Setup-A-11-STA.pcap
# 403 ./captures_IoT-Sentinel\SmarterCoffee\Setup-A-12-STA.pcap
# 404 ./captures_IoT-Sentinel\SmarterCoffee\Setup-A-13-STA.pcap
# 405 ./captures_IoT-Sentinel\SmarterCoffee\Setup-A-14-STA.pcap
# 406 ./captures_IoT-Sentinel\SmarterCoffee\Setup-A-15-STA.pcap
# 407 ./captures_IoT-Sentinel\SmarterCoffee\Setup-A-2-STA.pcap
# 408 ./captures_IoT-Sentinel\SmarterCoffee\Setup-A-3-STA.pcap
# 409 ./captures_IoT-Sentinel\SmarterCoffee\Setup-A-4-STA.pcap
# 410 ./captures_IoT-Sentinel\SmarterCoffee\Setup-A-5-STA.pcap
# 411 ./captures_IoT-Sentinel\SmarterCoffee\Setup-A-6-STA.pcap
# 412 ./captures_IoT-Sentinel\SmarterCoffee\Setup-A-7-STA.pcap
# 413 ./captures_IoT-Sentinel\SmarterCoffee\Setup-A-8-STA.pcap
# 414 ./captures_IoT-Sentinel\SmarterCoffee\Setup-A-9-STA.pcap
# 415 ./captures_IoT-Sentinel\SmarterCoffee\Setup-C-1-STA.pcap
# 416 ./captures_IoT-Sentinel\SmarterCoffee\Setup-C-2-STA.pcap
# 417 ./captures_IoT-Sentinel\SmarterCoffee\Setup-C-3-STA.pcap
# 418 ./captures_IoT-Sentinel\SmarterCoffee\Setup-C-4-STA.pcap
# 419 ./captures_IoT-Sentinel\SmarterCoffee\Setup-C-5-STA.pcap
# 420 ./captures_IoT-Sentinel\TP-LinkPlugHS100\Setup-A-1-STA.pcap
# 421 ./captures_IoT-Sentinel\TP-LinkPlugHS100\Setup-A-2-STA.pcap
# 422 ./captures_IoT-Sentinel\TP-LinkPlugHS100\Setup-A-3-STA.pcap
# 423 ./captures_IoT-Sentinel\TP-LinkPlugHS100\Setup-A-4-STA.pcap
# 424 ./captures_IoT-Sentinel\TP-LinkPlugHS100\Setup-A-5-STA.pcap
# 425 ./captures_IoT-Sentinel\TP-LinkPlugHS100\Setup-C-1-STA.pcap
# 426 ./captures_IoT-Sentinel\TP-LinkPlugHS100\Setup-C-10-STA.pcap
# 427 ./captures_IoT-Sentinel\TP-LinkPlugHS100\Setup-C-11-STA.pcap
# 428 ./captures_IoT-Sentinel\TP-LinkPlugHS100\Setup-C-12-STA.pcap
# 429 ./captures_IoT-Sentinel\TP-LinkPlugHS100\Setup-C-13-STA.pcap
# 430 ./captures_IoT-Sentinel\TP-LinkPlugHS100\Setup-C-14-STA.pcap
# 431 ./captures_IoT-Sentinel\TP-LinkPlugHS100\Setup-C-15-STA.pcap
# 432 ./captures_IoT-Sentinel\TP-LinkPlugHS100\Setup-C-2-STA.pcap
# 433 ./captures_IoT-Sentinel\TP-LinkPlugHS100\Setup-C-3-STA.pcap
# 434 ./captures_IoT-Sentinel\TP-LinkPlugHS100\Setup-C-4-STA.pcap
# 435 ./captures_IoT-Sentinel\TP-LinkPlugHS100\Setup-C-5-STA.pcap
# 436 ./captures_IoT-Sentinel\TP-LinkPlugHS100\Setup-C-6-STA.pcap
# 437 ./captures_IoT-Sentinel\TP-LinkPlugHS100\Setup-C-7-STA.pcap
# 438 ./captures_IoT-Sentinel\TP-LinkPlugHS100\Setup-C-8-STA.pcap
# 439 ./captures_IoT-Sentinel\TP-LinkPlugHS100\Setup-C-9-STA.pcap
# 440 ./captures_IoT-Sentinel\TP-LinkPlugHS110\Setup-A-1-STA.pcap
# 441 ./captures_IoT-Sentinel\TP-LinkPlugHS110\Setup-A-10-STA.pcap
# 442 ./captures_IoT-Sentinel\TP-LinkPlugHS110\Setup-A-2-STA.pcap
# 443 ./captures_IoT-Sentinel\TP-LinkPlugHS110\Setup-A-3-STA.pcap
# 444 ./captures_IoT-Sentinel\TP-LinkPlugHS110\Setup-A-4-STA.pcap
# 445 ./captures_IoT-Sentinel\TP-LinkPlugHS110\Setup-A-5-STA.pcap
# 446 ./captures_IoT-Sentinel\TP-LinkPlugHS110\Setup-A-6-STA.pcap
# 447 ./captures_IoT-Sentinel\TP-LinkPlugHS110\Setup-A-7-STA.pcap
# 448 ./captures_IoT-Sentinel\TP-LinkPlugHS110\Setup-A-8-STA.pcap
# 449 ./captures_IoT-Sentinel\TP-LinkPlugHS110\Setup-A-9-STA.pcap
# 450 ./captures_IoT-Sentinel\TP-LinkPlugHS110\Setup-C-1-STA.pcap
# 451 ./captures_IoT-Sentinel\TP-LinkPlugHS110\Setup-C-10-STA.pcap
# 452 ./captures_IoT-Sentinel\TP-LinkPlugHS110\Setup-C-2-STA.pcap
# 453 ./captures_IoT-Sentinel\TP-LinkPlugHS110\Setup-C-3-STA.pcap
# 454 ./captures_IoT-Sentinel\TP-LinkPlugHS110\Setup-C-4-STA.pcap
# 455 ./captures_IoT-Sentinel\TP-LinkPlugHS110\Setup-C-5-STA.pcap
# 456 ./captures_IoT-Sentinel\TP-LinkPlugHS110\Setup-C-6-STA.pcap
# 457 ./captures_IoT-Sentinel\TP-LinkPlugHS110\Setup-C-7-STA.pcap
# 458 ./captures_IoT-Sentinel\TP-LinkPlugHS110\Setup-C-8-STA.pcap
# 459 ./captures_IoT-Sentinel\TP-LinkPlugHS110\Setup-C-9-STA.pcap
# 460 ./captures_IoT-Sentinel\WeMoInsightSwitch\Setup-A-1-STA.pcap
# 461 ./captures_IoT-Sentinel\WeMoInsightSwitch\Setup-A-10-STA.pcap
# 462 ./captures_IoT-Sentinel\WeMoInsightSwitch\Setup-A-11-STA.pcap
# 463 ./captures_IoT-Sentinel\WeMoInsightSwitch\Setup-A-2-STA.pcap
# 464 ./captures_IoT-Sentinel\WeMoInsightSwitch\Setup-A-3-STA.pcap
# 465 ./captures_IoT-Sentinel\WeMoInsightSwitch\Setup-A-4-STA.pcap
# 466 ./captures_IoT-Sentinel\WeMoInsightSwitch\Setup-A-5-STA.pcap
# 467 ./captures_IoT-Sentinel\WeMoInsightSwitch\Setup-A-6-STA.pcap
# 468 ./captures_IoT-Sentinel\WeMoInsightSwitch\Setup-A-7-STA.pcap
# 469 ./captures_IoT-Sentinel\WeMoInsightSwitch\Setup-A-8-STA.pcap
# 470 ./captures_IoT-Sentinel\WeMoInsightSwitch\Setup-A-9-STA.pcap
# 471 ./captures_IoT-Sentinel\WeMoInsightSwitch\Setup-C-1-STA.pcap
# 472 ./captures_IoT-Sentinel\WeMoInsightSwitch\Setup-C-2-STA.pcap
# 473 ./captures_IoT-Sentinel\WeMoInsightSwitch\Setup-C-3-STA.pcap
# 474 ./captures_IoT-Sentinel\WeMoInsightSwitch\Setup-C-4-STA.pcap
# 475 ./captures_IoT-Sentinel\WeMoInsightSwitch\Setup-C-5-STA.pcap
# 476 ./captures_IoT-Sentinel\WeMoInsightSwitch\Setup-C-6-STA.pcap
# 477 ./captures_IoT-Sentinel\WeMoInsightSwitch\Setup-C-7-STA.pcap
# 478 ./captures_IoT-Sentinel\WeMoInsightSwitch\Setup-C-8-STA.pcap
# 479 ./captures_IoT-Sentinel\WeMoInsightSwitch\Setup-C-9-STA.pcap
# 480 ./captures_IoT-Sentinel\WeMoInsightSwitch2\Setup-C-1-STA.pcap
# 481 ./captures_IoT-Sentinel\WeMoInsightSwitch2\Setup-C-2-STA.pcap
# 482 ./captures_IoT-Sentinel\WeMoInsightSwitch2\Setup-C-3-STA.pcap
# 483 ./captures_IoT-Sentinel\WeMoInsightSwitch2\Setup-C-4-STA.pcap
# 484 ./captures_IoT-Sentinel\WeMoInsightSwitch2\Setup-C-5-STA.pcap
# 485 ./captures_IoT-Sentinel\WeMoLink\Setup-A-1-STA.pcap
# 486 ./captures_IoT-Sentinel\WeMoLink\Setup-A-10-STA.pcap
# 487 ./captures_IoT-Sentinel\WeMoLink\Setup-A-11-STA.pcap
# 488 ./captures_IoT-Sentinel\WeMoLink\Setup-A-12-STA.pcap
# 489 ./captures_IoT-Sentinel\WeMoLink\Setup-A-13-STA.pcap
# 490 ./captures_IoT-Sentinel\WeMoLink\Setup-A-14-STA.pcap
# 491 ./captures_IoT-Sentinel\WeMoLink\Setup-A-15-STA.pcap
# 492 ./captures_IoT-Sentinel\WeMoLink\Setup-A-2-STA.pcap
# 493 ./captures_IoT-Sentinel\WeMoLink\Setup-A-3-STA.pcap
# 494 ./captures_IoT-Sentinel\WeMoLink\Setup-A-4-STA.pcap
# 495 ./captures_IoT-Sentinel\WeMoLink\Setup-A-5-STA.pcap
# 496 ./captures_IoT-Sentinel\WeMoLink\Setup-A-6-STA.pcap
# 497 ./captures_IoT-Sentinel\WeMoLink\Setup-A-7-STA.pcap
# 498 ./captures_IoT-Sentinel\WeMoLink\Setup-A-8-STA.pcap
# 499 ./captures_IoT-Sentinel\WeMoLink\Setup-A-9-STA.pcap
# 500 ./captures_IoT-Sentinel\WeMoLink\Setup-C-1-STA.pcap
# 501 ./captures_IoT-Sentinel\WeMoLink\Setup-C-2-STA.pcap
# 502 ./captures_IoT-Sentinel\WeMoLink\Setup-C-3-STA.pcap
# 503 ./captures_IoT-Sentinel\WeMoLink\Setup-C-4-STA.pcap
# 504 ./captures_IoT-Sentinel\WeMoLink\Setup-C-5-STA.pcap
# 505 ./captures_IoT-Sentinel\WeMoSwitch\Setup-A-1-STA.pcap
# 506 ./captures_IoT-Sentinel\WeMoSwitch\Setup-A-10-STA.pcap
# 507 ./captures_IoT-Sentinel\WeMoSwitch\Setup-A-2-STA.pcap
# 508 ./captures_IoT-Sentinel\WeMoSwitch\Setup-A-3-STA.pcap
# 509 ./captures_IoT-Sentinel\WeMoSwitch\Setup-A-4-STA.pcap
# 510 ./captures_IoT-Sentinel\WeMoSwitch\Setup-A-5-STA.pcap
# 511 ./captures_IoT-Sentinel\WeMoSwitch\Setup-A-6-STA.pcap
# 512 ./captures_IoT-Sentinel\WeMoSwitch\Setup-A-7-STA.pcap
# 513 ./captures_IoT-Sentinel\WeMoSwitch\Setup-A-8-STA.pcap
# 514 ./captures_IoT-Sentinel\WeMoSwitch\Setup-A-9-STA.pcap
# 515 ./captures_IoT-Sentinel\WeMoSwitch\Setup-C-1-STA.pcap
# 516 ./captures_IoT-Sentinel\WeMoSwitch\Setup-C-10-STA.pcap
# 517 ./captures_IoT-Sentinel\WeMoSwitch\Setup-C-2-STA.pcap
# 518 ./captures_IoT-Sentinel\WeMoSwitch\Setup-C-3-STA.pcap
# 519 ./captures_IoT-Sentinel\WeMoSwitch\Setup-C-4-STA.pcap
# 520 ./captures_IoT-Sentinel\WeMoSwitch\Setup-C-5-STA.pcap
# 521 ./captures_IoT-Sentinel\WeMoSwitch\Setup-C-6-STA.pcap
# 522 ./captures_IoT-Sentinel\WeMoSwitch\Setup-C-7-STA.pcap
# 523 ./captures_IoT-Sentinel\WeMoSwitch\Setup-C-8-STA.pcap
# 524 ./captures_IoT-Sentinel\WeMoSwitch\Setup-C-9-STA.pcap
# 525 ./captures_IoT-Sentinel\WeMoSwitch2\Setup-C-1-STA.pcap
# 526 ./captures_IoT-Sentinel\WeMoSwitch2\Setup-C-2-STA.pcap
# 527 ./captures_IoT-Sentinel\WeMoSwitch2\Setup-C-3-STA.pcap
# 528 ./captures_IoT-Sentinel\WeMoSwitch2\Setup-C-4-STA.pcap
# 529 ./captures_IoT-Sentinel\WeMoSwitch2\Setup-C-5-STA.pcap
# 530 ./captures_IoT-Sentinel\Withings\Setup-A-1-STA.pcap
# 531 ./captures_IoT-Sentinel\Withings\Setup-C-1-STA.pcap
# 532 ./captures_IoT-Sentinel\Withings\Setup-C-10-STA.pcap
# 533 ./captures_IoT-Sentinel\Withings\Setup-C-11-STA.pcap
# 534 ./captures_IoT-Sentinel\Withings\Setup-C-12-STA.pcap
# 535 ./captures_IoT-Sentinel\Withings\Setup-C-13-STA.pcap
# 536 ./captures_IoT-Sentinel\Withings\Setup-C-14-STA.pcap
# 537 ./captures_IoT-Sentinel\Withings\Setup-C-15-STA.pcap
# 538 ./captures_IoT-Sentinel\Withings\Setup-C-16-STA.pcap
# 539 ./captures_IoT-Sentinel\Withings\Setup-C-17-STA.pcap
# 540 ./captures_IoT-Sentinel\Withings\Setup-C-18-STA.pcap
# 541 ./captures_IoT-Sentinel\Withings\Setup-C-19-STA.pcap
# 542 ./captures_IoT-Sentinel\Withings\Setup-C-2-STA.pcap
# 543 ./captures_IoT-Sentinel\Withings\Setup-C-3-STA.pcap
# 544 ./captures_IoT-Sentinel\Withings\Setup-C-4-STA.pcap
# 545 ./captures_IoT-Sentinel\Withings\Setup-C-5-STA.pcap
# 546 ./captures_IoT-Sentinel\Withings\Setup-C-6-STA.pcap
# 547 ./captures_IoT-Sentinel\Withings\Setup-C-7-STA.pcap
# 548 ./captures_IoT-Sentinel\Withings\Setup-C-8-STA.pcap
# 549 ./captures_IoT-Sentinel\Withings\Setup-C-9-STA.pcap

# %% [markdown]
# ### Port numbers are classified in this part as:
#
# | Port Numbers | Equivalents |
# | :------ | :------ |
# |No port| 0|
# |Well known ports (between 0 and 1023) |1|
# |Rregistered ports (between 1024 and 49151)  |2|
# |Dynamic ports (between  49152 and 65535) |3|
# # ↓

# %%
def port_class(port):
    if 0 <= port <= 1023:
        return 1
    elif  1024 <= port <= 49151 :
        return 2
    elif 49152 <=port <= 65535 :
        return 3
    else:
        return 0

# %% [markdown]
# ### List of pcap files to be processed

# %%
files_add
# Out:
# ['./captures_IoT-Sentinel\\Aria\\Setup-A-1-STA.pcap',
#  './captures_IoT-Sentinel\\Aria\\Setup-A-2-STA.pcap',
#  './captures_IoT-Sentinel\\Aria\\Setup-A-3-STA.pcap',
#  './captures_IoT-Sentinel\\Aria\\Setup-A-4-STA.pcap',
#  './captures_IoT-Sentinel\\Aria\\Setup-A-5-STA.pcap',
#  './captures_IoT-Sentinel\\Aria\\Setup-C-1-STA.pcap',
#  './captures_IoT-Sentinel\\Aria\\Setup-C-10-STA.pcap',
#  './captures_IoT-Sentinel\\Aria\\Setup-C-11-STA.pcap',
#  './captures_IoT-Sentinel\\Aria\\Setup-C-12-STA.pcap',
#  './captures_IoT-Sentinel\\Aria\\Setup-C-13-STA.pcap',
#  './captures_IoT-Sentinel\\Aria\\Setup-C-14-STA.pcap',
#  './captures_IoT-Sentinel\\Aria\\Setup-C-15-STA.pcap',
#  './captures_IoT-Sentinel\\Aria\\Setup-C-2-STA.pcap',
#  './captures_IoT-Sentinel\\Aria\\Setup-C-3-STA.pcap',
#  './captures_IoT-Sentinel\\Aria\\Setup-C-4-STA.pcap',
#  './captures_IoT-Sentinel\\Aria\\Setup-C-5-STA.pcap',
#  './captures_IoT-Sentinel\\Aria\\Setup-C-6-STA.pcap',
#  './captures_IoT-Sentinel\\Aria\\Setup-C-7-STA.pcap',
#  './captures_IoT-Sentinel\\Aria\\Setup-C-8-STA.pcap',
#  './captures_IoT-Sentinel\\Aria\\Setup-C-9-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkCam\\Setup-A-1-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkCam\\Setup-A-2-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkCam\\Setup-A-3-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkCam\\Setup-A-4-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkCam\\Setup-A-5-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkCam\\Setup-B-1-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkCam\\Setup-B-2-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkCam\\Setup-B-3-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkCam\\Setup-B-4-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkCam\\Setup-B-5-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkCam\\Setup-C-1-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkCam\\Setup-C-10-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkCam\\Setup-C-2-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkCam\\Setup-C-3-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkCam\\Setup-C-4-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkCam\\Setup-C-5-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkCam\\Setup-C-6-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkCam\\Setup-C-7-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkCam\\Setup-C-8-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkCam\\Setup-C-9-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkDayCam\\Setup-A-1-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkDayCam\\Setup-A-2-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkDayCam\\Setup-A-3-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkDayCam\\Setup-A-4-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkDayCam\\Setup-A-5-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkDayCam\\Setup-C-1-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkDayCam\\Setup-C-10-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkDayCam\\Setup-C-11-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkDayCam\\Setup-C-12-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkDayCam\\Setup-C-13-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkDayCam\\Setup-C-14-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkDayCam\\Setup-C-15-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkDayCam\\Setup-C-2-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkDayCam\\Setup-C-3-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkDayCam\\Setup-C-4-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkDayCam\\Setup-C-5-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkDayCam\\Setup-C-6-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkDayCam\\Setup-C-7-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkDayCam\\Setup-C-8-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkDayCam\\Setup-C-9-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkDoorSensor\\Setup-C-1-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkDoorSensor\\Setup-C-10-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkDoorSensor\\Setup-C-11-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkDoorSensor\\Setup-C-12-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkDoorSensor\\Setup-C-13-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkDoorSensor\\Setup-C-14-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkDoorSensor\\Setup-C-15-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkDoorSensor\\Setup-C-16-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkDoorSensor\\Setup-C-17-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkDoorSensor\\Setup-C-18-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkDoorSensor\\Setup-C-19-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkDoorSensor\\Setup-C-2-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkDoorSensor\\Setup-C-20-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkDoorSensor\\Setup-C-3-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkDoorSensor\\Setup-C-4-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkDoorSensor\\Setup-C-5-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkDoorSensor\\Setup-C-6-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkDoorSensor\\Setup-C-7-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkDoorSensor\\Setup-C-8-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkDoorSensor\\Setup-C-9-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkHomeHub\\Setup-A-1-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkHomeHub\\Setup-A-2-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkHomeHub\\Setup-A-3-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkHomeHub\\Setup-A-4-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkHomeHub\\Setup-A-5-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkHomeHub\\Setup-C-1-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkHomeHub\\Setup-C-10-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkHomeHub\\Setup-C-11-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkHomeHub\\Setup-C-12-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkHomeHub\\Setup-C-13-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkHomeHub\\Setup-C-14-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkHomeHub\\Setup-C-15-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkHomeHub\\Setup-C-2-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkHomeHub\\Setup-C-3-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkHomeHub\\Setup-C-4-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkHomeHub\\Setup-C-5-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkHomeHub\\Setup-C-6-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkHomeHub\\Setup-C-7-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkHomeHub\\Setup-C-8-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkHomeHub\\Setup-C-9-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSensor\\Setup-A-1-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSensor\\Setup-A-2-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSensor\\Setup-A-3-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSensor\\Setup-A-4-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSensor\\Setup-A-5-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSensor\\Setup-B-1-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSensor\\Setup-B-2-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSensor\\Setup-B-3-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSensor\\Setup-B-4-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSensor\\Setup-B-5-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSensor\\Setup-C-1-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSensor\\Setup-C-10-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSensor\\Setup-C-2-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSensor\\Setup-C-3-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSensor\\Setup-C-4-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSensor\\Setup-C-5-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSensor\\Setup-C-6-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSensor\\Setup-C-7-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSensor\\Setup-C-8-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSensor\\Setup-C-9-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSiren\\Setup-A-1-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSiren\\Setup-C-1-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSiren\\Setup-C-10-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSiren\\Setup-C-11-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSiren\\Setup-C-12-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSiren\\Setup-C-13-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSiren\\Setup-C-14-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSiren\\Setup-C-15-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSiren\\Setup-C-16-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSiren\\Setup-C-17-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSiren\\Setup-C-18-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSiren\\Setup-C-19-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSiren\\Setup-C-2-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSiren\\Setup-C-3-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSiren\\Setup-C-4-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSiren\\Setup-C-5-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSiren\\Setup-C-6-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSiren\\Setup-C-7-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSiren\\Setup-C-8-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSiren\\Setup-C-9-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSwitch\\Setup-A-1-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSwitch\\Setup-A-2-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSwitch\\Setup-A-3-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSwitch\\Setup-A-4-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSwitch\\Setup-A-5-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSwitch\\Setup-C-1-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSwitch\\Setup-C-10-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSwitch\\Setup-C-11-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSwitch\\Setup-C-12-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSwitch\\Setup-C-13-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSwitch\\Setup-C-14-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSwitch\\Setup-C-15-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSwitch\\Setup-C-2-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSwitch\\Setup-C-3-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSwitch\\Setup-C-4-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSwitch\\Setup-C-5-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSwitch\\Setup-C-6-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSwitch\\Setup-C-7-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSwitch\\Setup-C-8-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkSwitch\\Setup-C-9-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkWaterSensor\\Setup-A-1-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkWaterSensor\\Setup-C-1-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkWaterSensor\\Setup-C-10-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkWaterSensor\\Setup-C-11-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkWaterSensor\\Setup-C-12-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkWaterSensor\\Setup-C-13-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkWaterSensor\\Setup-C-14-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkWaterSensor\\Setup-C-15-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkWaterSensor\\Setup-C-16-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkWaterSensor\\Setup-C-17-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkWaterSensor\\Setup-C-18-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkWaterSensor\\Setup-C-19-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkWaterSensor\\Setup-C-2-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkWaterSensor\\Setup-C-3-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkWaterSensor\\Setup-C-4-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkWaterSensor\\Setup-C-5-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkWaterSensor\\Setup-C-6-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkWaterSensor\\Setup-C-7-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkWaterSensor\\Setup-C-8-STA.pcap',
#  './captures_IoT-Sentinel\\D-LinkWaterSensor\\Setup-C-9-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxCam1\\Setup-A-1-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxCam1\\Setup-A-2-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxCam1\\Setup-A-3-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxCam1\\Setup-A-4-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxCam1\\Setup-A-5-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxCam1\\Setup-A-6-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxCam1\\Setup-A-7-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxCam1\\Setup-C-1-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxCam1\\Setup-C-2-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxCam1\\Setup-C-3-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxCam1\\Setup-C-4-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxCam1\\Setup-C-5-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxCam2\\Setup-A-1-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxCam2\\Setup-A-2-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxCam2\\Setup-A-3-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxCam2\\Setup-A-4-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxCam2\\Setup-C-1-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxCam2\\Setup-C-2-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxCam2\\Setup-C-3-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxCam2\\Setup-C-4-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxPlug1101W\\Setup-A-1-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxPlug1101W\\Setup-A-2-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxPlug1101W\\Setup-A-3-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxPlug1101W\\Setup-A-4-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxPlug1101W\\Setup-A-5-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxPlug1101W\\Setup-C-1-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxPlug1101W\\Setup-C-10-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxPlug1101W\\Setup-C-11-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxPlug1101W\\Setup-C-12-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxPlug1101W\\Setup-C-13-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxPlug1101W\\Setup-C-14-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxPlug1101W\\Setup-C-15-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxPlug1101W\\Setup-C-2-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxPlug1101W\\Setup-C-3-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxPlug1101W\\Setup-C-4-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxPlug1101W\\Setup-C-5-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxPlug1101W\\Setup-C-6-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxPlug1101W\\Setup-C-7-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxPlug1101W\\Setup-C-8-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxPlug1101W\\Setup-C-9-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxPlug2101W\\Setup-A-1-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxPlug2101W\\Setup-A-2-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxPlug2101W\\Setup-A-3-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxPlug2101W\\Setup-A-4-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxPlug2101W\\Setup-A-5-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxPlug2101W\\Setup-C-1-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxPlug2101W\\Setup-C-10-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxPlug2101W\\Setup-C-11-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxPlug2101W\\Setup-C-12-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxPlug2101W\\Setup-C-13-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxPlug2101W\\Setup-C-14-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxPlug2101W\\Setup-C-15-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxPlug2101W\\Setup-C-2-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxPlug2101W\\Setup-C-3-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxPlug2101W\\Setup-C-4-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxPlug2101W\\Setup-C-5-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxPlug2101W\\Setup-C-6-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxPlug2101W\\Setup-C-7-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxPlug2101W\\Setup-C-8-STA.pcap',
#  './captures_IoT-Sentinel\\EdimaxPlug2101W\\Setup-C-9-STA.pcap',
#  './captures_IoT-Sentinel\\EdnetCam1\\Setup-A-1-STA.pcap',
#  './captures_IoT-Sentinel\\EdnetCam1\\Setup-C-1-STA.pcap',
#  './captures_IoT-Sentinel\\EdnetCam1\\Setup-C-10-STA.pcap',
#  './captures_IoT-Sentinel\\EdnetCam1\\Setup-C-2-STA.pcap',
#  './captures_IoT-Sentinel\\EdnetCam1\\Setup-C-3-STA.pcap',
#  './captures_IoT-Sentinel\\EdnetCam1\\Setup-C-4-STA.pcap',
#  './captures_IoT-Sentinel\\EdnetCam1\\Setup-C-5-STA.pcap',
#  './captures_IoT-Sentinel\\EdnetCam1\\Setup-C-6-STA.pcap',
#  './captures_IoT-Sentinel\\EdnetCam1\\Setup-C-7-STA.pcap',
#  './captures_IoT-Sentinel\\EdnetCam1\\Setup-C-8-STA.pcap',
#  './captures_IoT-Sentinel\\EdnetCam1\\Setup-C-9-STA.pcap',
#  './captures_IoT-Sentinel\\EdnetCam2\\Setup-A-1-STA.pcap',
#  './captures_IoT-Sentinel\\EdnetCam2\\Setup-C-1-STA.pcap',
#  './captures_IoT-Sentinel\\EdnetCam2\\Setup-C-2-STA.pcap',
#  './captures_IoT-Sentinel\\EdnetCam2\\Setup-C-3-STA.pcap',
#  './captures_IoT-Sentinel\\EdnetCam2\\Setup-C-4-STA.pcap',
#  './captures_IoT-Sentinel\\EdnetCam2\\Setup-C-5-STA.pcap',
#  './captures_IoT-Sentinel\\EdnetCam2\\Setup-C-6-STA.pcap',
#  './captures_IoT-Sentinel\\EdnetCam2\\Setup-C-7-STA.pcap',
#  './captures_IoT-Sentinel\\EdnetCam2\\Setup-C-8-STA.pcap',
#  './captures_IoT-Sentinel\\EdnetGateway\\Setup-A-1-STA.pcap',
#  './captures_IoT-Sentinel\\EdnetGateway\\Setup-A-2-STA.pcap',
#  './captures_IoT-Sentinel\\EdnetGateway\\Setup-C-1-STA.pcap',
#  './captures_IoT-Sentinel\\EdnetGateway\\Setup-C-10-STA.pcap',
#  './captures_IoT-Sentinel\\EdnetGateway\\Setup-C-11-STA.pcap',
#  './captures_IoT-Sentinel\\EdnetGateway\\Setup-C-12-STA.pcap',
#  './captures_IoT-Sentinel\\EdnetGateway\\Setup-C-13-STA.pcap',
#  './captures_IoT-Sentinel\\EdnetGateway\\Setup-C-14-STA.pcap',
#  './captures_IoT-Sentinel\\EdnetGateway\\Setup-C-15-STA.pcap',
#  './captures_IoT-Sentinel\\EdnetGateway\\Setup-C-16-STA.pcap',
#  './captures_IoT-Sentinel\\EdnetGateway\\Setup-C-17-STA.pcap',
#  './captures_IoT-Sentinel\\EdnetGateway\\Setup-C-18-STA.pcap',
#  './captures_IoT-Sentinel\\EdnetGateway\\Setup-C-2-STA.pcap',
#  './captures_IoT-Sentinel\\EdnetGateway\\Setup-C-3-STA.pcap',
#  './captures_IoT-Sentinel\\EdnetGateway\\Setup-C-4-STA.pcap',
#  './captures_IoT-Sentinel\\EdnetGateway\\Setup-C-5-STA.pcap',
#  './captures_IoT-Sentinel\\EdnetGateway\\Setup-C-6-STA.pcap',
#  './captures_IoT-Sentinel\\EdnetGateway\\Setup-C-7-STA.pcap',
#  './captures_IoT-Sentinel\\EdnetGateway\\Setup-C-8-STA.pcap',
#  './captures_IoT-Sentinel\\EdnetGateway\\Setup-C-9-STA.pcap',
#  './captures_IoT-Sentinel\\HomeMaticPlug\\Setup-C-1-STA.pcap',
#  './captures_IoT-Sentinel\\HomeMaticPlug\\Setup-C-10-STA.pcap',
#  './captures_IoT-Sentinel\\HomeMaticPlug\\Setup-C-11-STA.pcap',
#  './captures_IoT-Sentinel\\HomeMaticPlug\\Setup-C-12-STA.pcap',
#  './captures_IoT-Sentinel\\HomeMaticPlug\\Setup-C-13-STA.pcap',
#  './captures_IoT-Sentinel\\HomeMaticPlug\\Setup-C-14-STA.pcap',
#  './captures_IoT-Sentinel\\HomeMaticPlug\\Setup-C-15-STA.pcap',
#  './captures_IoT-Sentinel\\HomeMaticPlug\\Setup-C-16-STA.pcap',
#  './captures_IoT-Sentinel\\HomeMaticPlug\\Setup-C-17-STA.pcap',
#  './captures_IoT-Sentinel\\HomeMaticPlug\\Setup-C-18-STA.pcap',
#  './captures_IoT-Sentinel\\HomeMaticPlug\\Setup-C-19-STA.pcap',
#  './captures_IoT-Sentinel\\HomeMaticPlug\\Setup-C-2-STA.pcap',
#  './captures_IoT-Sentinel\\HomeMaticPlug\\Setup-C-20-STA.pcap',
#  './captures_IoT-Sentinel\\HomeMaticPlug\\Setup-C-3-STA.pcap',
#  './captures_IoT-Sentinel\\HomeMaticPlug\\Setup-C-4-STA.pcap',
#  './captures_IoT-Sentinel\\HomeMaticPlug\\Setup-C-5-STA.pcap',
#  './captures_IoT-Sentinel\\HomeMaticPlug\\Setup-C-6-STA.pcap',
#  './captures_IoT-Sentinel\\HomeMaticPlug\\Setup-C-7-STA.pcap',
#  './captures_IoT-Sentinel\\HomeMaticPlug\\Setup-C-8-STA.pcap',
#  './captures_IoT-Sentinel\\HomeMaticPlug\\Setup-C-9-STA.pcap',
#  './captures_IoT-Sentinel\\HueBridge\\Setup-A-1-STA.pcap',
#  './captures_IoT-Sentinel\\HueBridge\\Setup-A-2-STA.pcap',
#  './captures_IoT-Sentinel\\HueBridge\\Setup-A-3-STA.pcap',
#  './captures_IoT-Sentinel\\HueBridge\\Setup-A-4-STA.pcap',
#  './captures_IoT-Sentinel\\HueBridge\\Setup-A-5-STA.pcap',
#  './captures_IoT-Sentinel\\HueBridge\\Setup-C-1-STA.pcap',
#  './captures_IoT-Sentinel\\HueBridge\\Setup-C-10-STA.pcap',
#  './captures_IoT-Sentinel\\HueBridge\\Setup-C-11-STA.pcap',
#  './captures_IoT-Sentinel\\HueBridge\\Setup-C-12-STA.pcap',
#  './captures_IoT-Sentinel\\HueBridge\\Setup-C-13-STA.pcap',
#  './captures_IoT-Sentinel\\HueBridge\\Setup-C-14-STA.pcap',
#  './captures_IoT-Sentinel\\HueBridge\\Setup-C-15-STA.pcap',
#  './captures_IoT-Sentinel\\HueBridge\\Setup-C-2-STA.pcap',
#  './captures_IoT-Sentinel\\HueBridge\\Setup-C-3-STA.pcap',
#  './captures_IoT-Sentinel\\HueBridge\\Setup-C-4-STA.pcap',
#  './captures_IoT-Sentinel\\HueBridge\\Setup-C-5-STA.pcap',
#  './captures_IoT-Sentinel\\HueBridge\\Setup-C-6-STA.pcap',
#  './captures_IoT-Sentinel\\HueBridge\\Setup-C-7-STA.pcap',
#  './captures_IoT-Sentinel\\HueBridge\\Setup-C-8-STA.pcap',
#  './captures_IoT-Sentinel\\HueBridge\\Setup-C-9-STA.pcap',
#  './captures_IoT-Sentinel\\HueSwitch\\Setup-A-1-STA.pcap',
#  './captures_IoT-Sentinel\\HueSwitch\\Setup-A-10-STA.pcap',
#  './captures_IoT-Sentinel\\HueSwitch\\Setup-A-2-STA.pcap',
#  './captures_IoT-Sentinel\\HueSwitch\\Setup-A-3-STA.pcap',
#  './captures_IoT-Sentinel\\HueSwitch\\Setup-A-4-STA.pcap',
#  './captures_IoT-Sentinel\\HueSwitch\\Setup-A-5-STA.pcap',
#  './captures_IoT-Sentinel\\HueSwitch\\Setup-A-6-STA.pcap',
#  './captures_IoT-Sentinel\\HueSwitch\\Setup-A-7-STA.pcap',
#  './captures_IoT-Sentinel\\HueSwitch\\Setup-A-8-STA.pcap',
#  './captures_IoT-Sentinel\\HueSwitch\\Setup-A-9-STA.pcap',
#  './captures_IoT-Sentinel\\HueSwitch\\Setup-C-1-STA.pcap',
#  './captures_IoT-Sentinel\\HueSwitch\\Setup-C-10-STA.pcap',
#  './captures_IoT-Sentinel\\HueSwitch\\Setup-C-2-STA.pcap',
#  './captures_IoT-Sentinel\\HueSwitch\\Setup-C-3-STA.pcap',
#  './captures_IoT-Sentinel\\HueSwitch\\Setup-C-4-STA.pcap',
#  './captures_IoT-Sentinel\\HueSwitch\\Setup-C-5-STA.pcap',
#  './captures_IoT-Sentinel\\HueSwitch\\Setup-C-6-STA.pcap',
#  './captures_IoT-Sentinel\\HueSwitch\\Setup-C-7-STA.pcap',
#  './captures_IoT-Sentinel\\HueSwitch\\Setup-C-8-STA.pcap',
#  './captures_IoT-Sentinel\\HueSwitch\\Setup-C-9-STA.pcap',
#  './captures_IoT-Sentinel\\iKettle2\\Setup-A-1-STA.pcap',
#  './captures_IoT-Sentinel\\iKettle2\\Setup-A-10-STA.pcap',
#  './captures_IoT-Sentinel\\iKettle2\\Setup-A-11-STA.pcap',
#  './captures_IoT-Sentinel\\iKettle2\\Setup-A-12-STA.pcap',
#  './captures_IoT-Sentinel\\iKettle2\\Setup-A-13-STA.pcap',
#  './captures_IoT-Sentinel\\iKettle2\\Setup-A-14-STA.pcap',
#  './captures_IoT-Sentinel\\iKettle2\\Setup-A-15-STA.pcap',
#  './captures_IoT-Sentinel\\iKettle2\\Setup-A-2-STA.pcap',
#  './captures_IoT-Sentinel\\iKettle2\\Setup-A-3-STA.pcap',
#  './captures_IoT-Sentinel\\iKettle2\\Setup-A-4-STA.pcap',
#  './captures_IoT-Sentinel\\iKettle2\\Setup-A-5-STA.pcap',
#  './captures_IoT-Sentinel\\iKettle2\\Setup-A-6-STA.pcap',
#  './captures_IoT-Sentinel\\iKettle2\\Setup-A-7-STA.pcap',
#  './captures_IoT-Sentinel\\iKettle2\\Setup-A-8-STA.pcap',
#  './captures_IoT-Sentinel\\iKettle2\\Setup-A-9-STA.pcap',
#  './captures_IoT-Sentinel\\iKettle2\\Setup-C-1-STA.pcap',
#  './captures_IoT-Sentinel\\iKettle2\\Setup-C-2-STA.pcap',
#  './captures_IoT-Sentinel\\iKettle2\\Setup-C-3-STA.pcap',
#  './captures_IoT-Sentinel\\iKettle2\\Setup-C-4-STA.pcap',
#  './captures_IoT-Sentinel\\iKettle2\\Setup-C-5-STA.pcap',
#  './captures_IoT-Sentinel\\Lightify\\Setup-C-1-STA.pcap',
#  './captures_IoT-Sentinel\\Lightify\\Setup-C-10-STA.pcap',
#  './captures_IoT-Sentinel\\Lightify\\Setup-C-11-STA.pcap',
#  './captures_IoT-Sentinel\\Lightify\\Setup-C-12-STA.pcap',
#  './captures_IoT-Sentinel\\Lightify\\Setup-C-13-STA.pcap',
#  './captures_IoT-Sentinel\\Lightify\\Setup-C-14-STA.pcap',
#  './captures_IoT-Sentinel\\Lightify\\Setup-C-15-STA.pcap',
#  './captures_IoT-Sentinel\\Lightify\\Setup-C-16-STA.pcap',
#  './captures_IoT-Sentinel\\Lightify\\Setup-C-17-STA.pcap',
#  './captures_IoT-Sentinel\\Lightify\\Setup-C-18-STA.pcap',
#  './captures_IoT-Sentinel\\Lightify\\Setup-C-19-STA.pcap',
#  './captures_IoT-Sentinel\\Lightify\\Setup-C-2-STA.pcap',
#  './captures_IoT-Sentinel\\Lightify\\Setup-C-20-STA.pcap',
#  './captures_IoT-Sentinel\\Lightify\\Setup-C-3-STA.pcap',
#  './captures_IoT-Sentinel\\Lightify\\Setup-C-4-STA.pcap',
#  './captures_IoT-Sentinel\\Lightify\\Setup-C-5-STA.pcap',
#  './captures_IoT-Sentinel\\Lightify\\Setup-C-6-STA.pcap',
#  './captures_IoT-Sentinel\\Lightify\\Setup-C-7-STA.pcap',
#  './captures_IoT-Sentinel\\Lightify\\Setup-C-8-STA.pcap',
#  './captures_IoT-Sentinel\\Lightify\\Setup-C-9-STA.pcap',
#  './captures_IoT-Sentinel\\MAXGateway\\Setup-A-1-STA.pcap',
#  './captures_IoT-Sentinel\\MAXGateway\\Setup-A-2-STA.pcap',
#  './captures_IoT-Sentinel\\MAXGateway\\Setup-A-3-STA.pcap',
#  './captures_IoT-Sentinel\\MAXGateway\\Setup-A-4-STA.pcap',
#  './captures_IoT-Sentinel\\MAXGateway\\Setup-A-5-STA.pcap',
#  './captures_IoT-Sentinel\\MAXGateway\\Setup-A-6-STA.pcap',
#  './captures_IoT-Sentinel\\MAXGateway\\Setup-A-7-STA.pcap',
#  './captures_IoT-Sentinel\\MAXGateway\\Setup-A-8-STA.pcap',
#  './captures_IoT-Sentinel\\MAXGateway\\Setup-A-9-STA.pcap',
#  './captures_IoT-Sentinel\\MAXGateway\\Setup-C-1-STA.pcap',
#  './captures_IoT-Sentinel\\MAXGateway\\Setup-C-10-STA.pcap',
#  './captures_IoT-Sentinel\\MAXGateway\\Setup-C-11-STA.pcap',
#  './captures_IoT-Sentinel\\MAXGateway\\Setup-C-2-STA.pcap',
#  './captures_IoT-Sentinel\\MAXGateway\\Setup-C-3-STA.pcap',
#  './captures_IoT-Sentinel\\MAXGateway\\Setup-C-4-STA.pcap',
#  './captures_IoT-Sentinel\\MAXGateway\\Setup-C-5-STA.pcap',
#  './captures_IoT-Sentinel\\MAXGateway\\Setup-C-6-STA.pcap',
#  './captures_IoT-Sentinel\\MAXGateway\\Setup-C-7-STA.pcap',
#  './captures_IoT-Sentinel\\MAXGateway\\Setup-C-8-STA.pcap',
#  './captures_IoT-Sentinel\\MAXGateway\\Setup-C-9-STA.pcap',
#  './captures_IoT-Sentinel\\SmarterCoffee\\Setup-A-1-STA.pcap',
#  './captures_IoT-Sentinel\\SmarterCoffee\\Setup-A-10-STA.pcap',
#  './captures_IoT-Sentinel\\SmarterCoffee\\Setup-A-11-STA.pcap',
#  './captures_IoT-Sentinel\\SmarterCoffee\\Setup-A-12-STA.pcap',
#  './captures_IoT-Sentinel\\SmarterCoffee\\Setup-A-13-STA.pcap',
#  './captures_IoT-Sentinel\\SmarterCoffee\\Setup-A-14-STA.pcap',
#  './captures_IoT-Sentinel\\SmarterCoffee\\Setup-A-15-STA.pcap',
#  './captures_IoT-Sentinel\\SmarterCoffee\\Setup-A-2-STA.pcap',
#  './captures_IoT-Sentinel\\SmarterCoffee\\Setup-A-3-STA.pcap',
#  './captures_IoT-Sentinel\\SmarterCoffee\\Setup-A-4-STA.pcap',
#  './captures_IoT-Sentinel\\SmarterCoffee\\Setup-A-5-STA.pcap',
#  './captures_IoT-Sentinel\\SmarterCoffee\\Setup-A-6-STA.pcap',
#  './captures_IoT-Sentinel\\SmarterCoffee\\Setup-A-7-STA.pcap',
#  './captures_IoT-Sentinel\\SmarterCoffee\\Setup-A-8-STA.pcap',
#  './captures_IoT-Sentinel\\SmarterCoffee\\Setup-A-9-STA.pcap',
#  './captures_IoT-Sentinel\\SmarterCoffee\\Setup-C-1-STA.pcap',
#  './captures_IoT-Sentinel\\SmarterCoffee\\Setup-C-2-STA.pcap',
#  './captures_IoT-Sentinel\\SmarterCoffee\\Setup-C-3-STA.pcap',
#  './captures_IoT-Sentinel\\SmarterCoffee\\Setup-C-4-STA.pcap',
#  './captures_IoT-Sentinel\\SmarterCoffee\\Setup-C-5-STA.pcap',
#  './captures_IoT-Sentinel\\TP-LinkPlugHS100\\Setup-A-1-STA.pcap',
#  './captures_IoT-Sentinel\\TP-LinkPlugHS100\\Setup-A-2-STA.pcap',
#  './captures_IoT-Sentinel\\TP-LinkPlugHS100\\Setup-A-3-STA.pcap',
#  './captures_IoT-Sentinel\\TP-LinkPlugHS100\\Setup-A-4-STA.pcap',
#  './captures_IoT-Sentinel\\TP-LinkPlugHS100\\Setup-A-5-STA.pcap',
#  './captures_IoT-Sentinel\\TP-LinkPlugHS100\\Setup-C-1-STA.pcap',
#  './captures_IoT-Sentinel\\TP-LinkPlugHS100\\Setup-C-10-STA.pcap',
#  './captures_IoT-Sentinel\\TP-LinkPlugHS100\\Setup-C-11-STA.pcap',
#  './captures_IoT-Sentinel\\TP-LinkPlugHS100\\Setup-C-12-STA.pcap',
#  './captures_IoT-Sentinel\\TP-LinkPlugHS100\\Setup-C-13-STA.pcap',
#  './captures_IoT-Sentinel\\TP-LinkPlugHS100\\Setup-C-14-STA.pcap',
#  './captures_IoT-Sentinel\\TP-LinkPlugHS100\\Setup-C-15-STA.pcap',
#  './captures_IoT-Sentinel\\TP-LinkPlugHS100\\Setup-C-2-STA.pcap',
#  './captures_IoT-Sentinel\\TP-LinkPlugHS100\\Setup-C-3-STA.pcap',
#  './captures_IoT-Sentinel\\TP-LinkPlugHS100\\Setup-C-4-STA.pcap',
#  './captures_IoT-Sentinel\\TP-LinkPlugHS100\\Setup-C-5-STA.pcap',
#  './captures_IoT-Sentinel\\TP-LinkPlugHS100\\Setup-C-6-STA.pcap',
#  './captures_IoT-Sentinel\\TP-LinkPlugHS100\\Setup-C-7-STA.pcap',
#  './captures_IoT-Sentinel\\TP-LinkPlugHS100\\Setup-C-8-STA.pcap',
#  './captures_IoT-Sentinel\\TP-LinkPlugHS100\\Setup-C-9-STA.pcap',
#  './captures_IoT-Sentinel\\TP-LinkPlugHS110\\Setup-A-1-STA.pcap',
#  './captures_IoT-Sentinel\\TP-LinkPlugHS110\\Setup-A-10-STA.pcap',
#  './captures_IoT-Sentinel\\TP-LinkPlugHS110\\Setup-A-2-STA.pcap',
#  './captures_IoT-Sentinel\\TP-LinkPlugHS110\\Setup-A-3-STA.pcap',
#  './captures_IoT-Sentinel\\TP-LinkPlugHS110\\Setup-A-4-STA.pcap',
#  './captures_IoT-Sentinel\\TP-LinkPlugHS110\\Setup-A-5-STA.pcap',
#  './captures_IoT-Sentinel\\TP-LinkPlugHS110\\Setup-A-6-STA.pcap',
#  './captures_IoT-Sentinel\\TP-LinkPlugHS110\\Setup-A-7-STA.pcap',
#  './captures_IoT-Sentinel\\TP-LinkPlugHS110\\Setup-A-8-STA.pcap',
#  './captures_IoT-Sentinel\\TP-LinkPlugHS110\\Setup-A-9-STA.pcap',
#  './captures_IoT-Sentinel\\TP-LinkPlugHS110\\Setup-C-1-STA.pcap',
#  './captures_IoT-Sentinel\\TP-LinkPlugHS110\\Setup-C-10-STA.pcap',
#  './captures_IoT-Sentinel\\TP-LinkPlugHS110\\Setup-C-2-STA.pcap',
#  './captures_IoT-Sentinel\\TP-LinkPlugHS110\\Setup-C-3-STA.pcap',
#  './captures_IoT-Sentinel\\TP-LinkPlugHS110\\Setup-C-4-STA.pcap',
#  './captures_IoT-Sentinel\\TP-LinkPlugHS110\\Setup-C-5-STA.pcap',
#  './captures_IoT-Sentinel\\TP-LinkPlugHS110\\Setup-C-6-STA.pcap',
#  './captures_IoT-Sentinel\\TP-LinkPlugHS110\\Setup-C-7-STA.pcap',
#  './captures_IoT-Sentinel\\TP-LinkPlugHS110\\Setup-C-8-STA.pcap',
#  './captures_IoT-Sentinel\\TP-LinkPlugHS110\\Setup-C-9-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoInsightSwitch\\Setup-A-1-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoInsightSwitch\\Setup-A-10-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoInsightSwitch\\Setup-A-11-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoInsightSwitch\\Setup-A-2-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoInsightSwitch\\Setup-A-3-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoInsightSwitch\\Setup-A-4-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoInsightSwitch\\Setup-A-5-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoInsightSwitch\\Setup-A-6-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoInsightSwitch\\Setup-A-7-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoInsightSwitch\\Setup-A-8-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoInsightSwitch\\Setup-A-9-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoInsightSwitch\\Setup-C-1-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoInsightSwitch\\Setup-C-2-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoInsightSwitch\\Setup-C-3-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoInsightSwitch\\Setup-C-4-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoInsightSwitch\\Setup-C-5-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoInsightSwitch\\Setup-C-6-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoInsightSwitch\\Setup-C-7-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoInsightSwitch\\Setup-C-8-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoInsightSwitch\\Setup-C-9-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoInsightSwitch2\\Setup-C-1-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoInsightSwitch2\\Setup-C-2-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoInsightSwitch2\\Setup-C-3-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoInsightSwitch2\\Setup-C-4-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoInsightSwitch2\\Setup-C-5-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoLink\\Setup-A-1-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoLink\\Setup-A-10-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoLink\\Setup-A-11-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoLink\\Setup-A-12-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoLink\\Setup-A-13-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoLink\\Setup-A-14-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoLink\\Setup-A-15-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoLink\\Setup-A-2-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoLink\\Setup-A-3-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoLink\\Setup-A-4-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoLink\\Setup-A-5-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoLink\\Setup-A-6-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoLink\\Setup-A-7-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoLink\\Setup-A-8-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoLink\\Setup-A-9-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoLink\\Setup-C-1-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoLink\\Setup-C-2-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoLink\\Setup-C-3-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoLink\\Setup-C-4-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoLink\\Setup-C-5-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoSwitch\\Setup-A-1-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoSwitch\\Setup-A-10-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoSwitch\\Setup-A-2-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoSwitch\\Setup-A-3-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoSwitch\\Setup-A-4-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoSwitch\\Setup-A-5-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoSwitch\\Setup-A-6-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoSwitch\\Setup-A-7-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoSwitch\\Setup-A-8-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoSwitch\\Setup-A-9-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoSwitch\\Setup-C-1-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoSwitch\\Setup-C-10-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoSwitch\\Setup-C-2-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoSwitch\\Setup-C-3-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoSwitch\\Setup-C-4-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoSwitch\\Setup-C-5-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoSwitch\\Setup-C-6-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoSwitch\\Setup-C-7-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoSwitch\\Setup-C-8-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoSwitch\\Setup-C-9-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoSwitch2\\Setup-C-1-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoSwitch2\\Setup-C-2-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoSwitch2\\Setup-C-3-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoSwitch2\\Setup-C-4-STA.pcap',
#  './captures_IoT-Sentinel\\WeMoSwitch2\\Setup-C-5-STA.pcap',
#  './captures_IoT-Sentinel\\Withings\\Setup-A-1-STA.pcap',
#  './captures_IoT-Sentinel\\Withings\\Setup-C-1-STA.pcap',
#  './captures_IoT-Sentinel\\Withings\\Setup-C-10-STA.pcap',
#  './captures_IoT-Sentinel\\Withings\\Setup-C-11-STA.pcap',
#  './captures_IoT-Sentinel\\Withings\\Setup-C-12-STA.pcap',
#  './captures_IoT-Sentinel\\Withings\\Setup-C-13-STA.pcap',
#  './captures_IoT-Sentinel\\Withings\\Setup-C-14-STA.pcap',
#  './captures_IoT-Sentinel\\Withings\\Setup-C-15-STA.pcap',
#  './captures_IoT-Sentinel\\Withings\\Setup-C-16-STA.pcap',
#  './captures_IoT-Sentinel\\Withings\\Setup-C-17-STA.pcap',
#  './captures_IoT-Sentinel\\Withings\\Setup-C-18-STA.pcap',
#  './captures_IoT-Sentinel\\Withings\\Setup-C-19-STA.pcap',
#  './captures_IoT-Sentinel\\Withings\\Setup-C-2-STA.pcap',
#  './captures_IoT-Sentinel\\Withings\\Setup-C-3-STA.pcap',
#  './captures_IoT-Sentinel\\Withings\\Setup-C-4-STA.pcap',
#  './captures_IoT-Sentinel\\Withings\\Setup-C-5-STA.pcap',
#  './captures_IoT-Sentinel\\Withings\\Setup-C-6-STA.pcap',
#  './captures_IoT-Sentinel\\Withings\\Setup-C-7-STA.pcap',
#  './captures_IoT-Sentinel\\Withings\\Setup-C-8-STA.pcap',
#  './captures_IoT-Sentinel\\Withings\\Setup-C-9-STA.pcap']

# %% [markdown]
# ### The dictionary to be used for MAC address and device matching.
# #### Datasets, their MAC addresses and Devices are given separately.

# %%
MAC_list={
# UNSW IEEE TMC 2018 Data MAC and Device names
"d0:52:a8:00:67:5e":"Smart Things",
"44:65:0d:56:cc:d3":"Amazon Echo",
"70:ee:50:18:34:43":"Netatmo Welcome",
"f4:f2:6d:93:51:f1":"TP-Link Day Night Cloud camera",
"00:16:6c:ab:6b:88":"Samsung SmartCam",
"30:8c:fb:2f:e4:b2":"Dropcam",
"00:62:6e:51:27:2e":"Insteon Camera",
"e8:ab:fa:19:de:4f":"unknown maybe cam",
"00:24:e4:11:18:a8":"Withings Smart Baby Monitor",
"ec:1a:59:79:f4:89":"Belkin Wemo switch",
"50:c7:bf:00:56:39":"TP-Link Smart plug",
"74:c6:3b:29:d7:1d":"iHome",
"ec:1a:59:83:28:11":"Belkin wemo motion sensor",
"18:b4:30:25:be:e4":"NEST Protect smoke alarm",
"70:ee:50:03:b8:ac":"Netatmo weather station",
"00:24:e4:1b:6f:96":"Withings Smart scale",
"74:6a:89:00:2e:25":"Blipcare Blood Pressure meter",
"00:24:e4:20:28:c6":"Withings Aura smart sleep sensor",
"d0:73:d5:01:83:08":"Light Bulbs LiFX Smart Bulb",
"18:b7:9e:02:20:44":"Triby Speaker",
"e0:76:d0:33:bb:85":"PIX-STAR Photo-frame",
"70:5a:0f:e4:9b:c0":"HP Printer",
"08:21:ef:3b:fc:e3":"Samsung Galaxy Tab",
"30:8c:fb:b6:ea:45":"Nest Dropcam",
"40:f3:08:ff:1e:da":"Android Phone",
"74:2f:68:81:69:42":"Laptop",
"ac:bc:32:d4:6f:2f":"MacBook",
"b4:ce:f6:a7:a3:c2":"Android Phone",
"d0:a6:37:df:a1:e1":"IPhone",
"f4:5c:89:93:cc:85":"MacBook/Iphone",
"14:cc:20:51:33:ea":"TPLink Router Bridge LAN (Gateway)",
# Yourthings Data MAC and Device names
'00:01:c0:18:7f:9b': 'Gateway',
 '00:04:4b:55:f6:4f': 'nVidiaShield',
 '00:12:16:ab:c0:22': 'ChineseWebcam',
 '00:17:88:21:f7:e4': 'PhilipsHUEHub',
 '00:1d:c9:23:f6:00': 'RingDoorbell',
 '00:21:cc:4d:59:35': 'Wink2Hub',
 '00:24:e4:2b:a5:34': 'WithingsHome',
 '00:7e:56:77:35:4d': 'KoogeekLightbulb',
 '08:05:81:ee:06:46': 'Roku4',
 '08:86:3b:6f:7a:15': 'BelkinWeMoMotionSensor',
 '08:86:3b:70:d7:39': 'BelkinWeMoSwitch',
 '0c:47:c9:4e:fe:5b': 'AmazonFireTV',
 '10:ce:a9:eb:5a:8a': 'BoseSoundTouch10',
 '18:b4:30:31:04:b9': 'NestProtect',
 '18:b4:30:40:1e:c5': 'NestGuard',
 '18:b4:30:58:3d:6c': 'NestCamera',
 '18:b4:30:8c:03:e4': 'NestCamIQ',
 '20:df:b9:20:87:39': 'GoogleHomeMini',
 '30:52:cb:a3:4f:5f': 'RokuTV',
 '3c:f7:a4:f2:15:87': 'iPhone',
 '40:9f:38:92:40:13': 'Roomba',
 '44:73:d6:01:3d:fd': 'LogitechLogiCircle',
 '48:d6:d5:98:53:84': 'GoogleHome',
 '50:c7:bf:92:a6:4a': 'TP-LinkSmartWiFiLEDBulb',
 '54:4a:16:f9:54:18': 'InsteonHub',
 '5c:aa:fd:6c:e0:d4': 'Sonos',
 '64:52:99:97:f8:40': 'ChamberlainmyQGarageOpener',
 '74:c2:46:1b:8e:e2': 'AmazonEchoGen1',
 '7c:64:56:60:71:74': 'SamsungSmartTV',
 '7c:70:bc:5d:09:d1': 'Canary',
 '94:10:3e:5c:2e:31': 'BelkinWeMoCrockpot',
 '94:10:3e:cc:67:95': 'BelkinWeMoLink',
 '94:4a:0c:08:7e:72': 'MiCasaVerdeVeraLite',
 'a4:f1:e8:8d:b0:9e': 'AndroidTablet',
 'ac:3f:a4:70:4a:d6': 'PiperNV',
 'b0:4e:26:20:15:8a': 'TP-LinkWiFiPlug',
 'b0:7f:b9:a6:47:4d': 'NetgearArloCamera',
 'b0:c5:54:03:c7:09': 'D-LinkDCS-5009LCamera',
 'b4:79:a7:22:f9:fc': 'WinkHub',
 'c0:56:27:53:09:6d': 'BelkinNetcam',
 'c8:db:26:02:bb:bb': 'LogitechHarmonyHub',
 'cc:b8:a8:ad:4d:04': 'AugustDoorbellCam',
 'd0:03:4b:39:12:e3': 'AppleTV(4thGen)',
 'd0:52:a8:63:47:9e': 'SamsungSmartThingsHub',
 'd0:73:d5:12:84:d1': 'LIFXVirtualBulb',
 'd4:90:9c:cc:62:42': 'AppleHomePod',
 'd8:f7:10:c2:29:be': 'HarmonKardonInvoke',
 'e4:71:85:25:ce:ec': 'SecurifiAlmond',
 'e8:b2:ac:af:62:0f': 'iPad',
 'f4:5e:ab:5e:c0:23': 'CasetaWirelessHub',
 'f4:f2:6d:ce:9a:5d': 'GoogleOnHub',
# IoT devices captures MAC and Device names
'00:17:88:24:76:ff': 'Hue-Device',
 '00:1a:22:03:cb:be': 'MAXGateway',
 '00:1a:22:05:c4:2e': 'HomeMaticPlug',
 '00:24:e4:24:80:2a': 'Withings',
 '00:b5:6d:06:08:ba': 'unknown',
 '1c:5f:2b:aa:fd:4e': 'D-LinkDevice',
 '20:f8:5e:ca:91:52': 'Aria',
 '24:77:03:7c:ea:dc': 'unknown',
 '28:b2:bd:c3:41:79': 'unknown',
 '38:0b:40:ef:85:41': 'unknown',

 '50:c7:bf:00:c7:03': 'TP-LinkPlugHS110',
 '50:c7:bf:00:fc:a3': 'TP-LinkPlugHS100',
 '3c:49:37:03:17:db': 'EdnetCam',
 '3c:49:37:03:17:f0': 'EdnetCam',
 '5c:cf:7f:06:d9:02': 'iKettle2',
 '5c:cf:7f:07:ae:fb': 'SmarterCoffee',
 '6c:72:20:c5:17:5a': 'D-LinkWaterSensor',
 '74:da:38:23:22:7b': 'EdimaxPlug2101W',
 '74:da:38:4a:76:49': 'EdimaxPlug1101W',
 '74:da:38:80:79:fc': 'EdimaxCam',
 '74:da:38:80:7a:08': 'EdimaxCam',
 '84:18:26:7b:5f:6b': 'Lightify',
 '90:8d:78:a8:e1:43': 'D-LinkSensor',
 '90:8d:78:a9:3d:6f': 'D-LinkSwitch',
 '90:8d:78:dd:0d:60': 'D-LinkSiren',
 '94:10:3e:34:0c:b5': 'WeMoSwitch',
 '94:10:3e:35:01:c1': 'WeMoSwitch',
 '94:10:3e:41:c2:05': 'WeMoInsightSwitch',
 '94:10:3e:42:80:69': 'WeMoInsightSwitch',
 '94:10:3e:cd:37:65': 'WeMoLink',
 'ac:cf:23:62:3c:6e': 'EdnetGateway',
 'b0:c5:54:1c:71:85': 'D-LinkDayCam',
 'b0:c5:54:25:5b:0e': 'D-LinkCam',
 'bc:f5:ac:f4:c0:9d': 'unknown'}

# %% [markdown]
# ### Calculating the payload entropy value.
#
#
# # ↓

# %%
def pre_entropy(payload):
    
    characters=[]
    for i in payload:
            characters.append(i)
    return shannon(characters)


def shannon(data):
    freq_dict={} 
    for i in data:
        if i in freq_dict:
            freq_dict[i] += 1
        else:
            freq_dict[i] = 1    
    entropy = 0.0
    logarithm_base = 2
    payload_size = len(data) #
    for key in freq_dict.keys():
        frequency = float(freq_dict[key])/payload_size
        if frequency > 0: 
            entropy = entropy + frequency * math.log(frequency, logarithm_base)
    return -entropy

# %%
import time 
dataset_name=["Train.csv", "Test.csv"]
for numero,dataset in enumerate ([train,test]):
    count=0
    ths = open(dataset_name[numero], "w")
    header="ARP,LLC,EAPOL,IP,ICMP,ICMP6,TCP,UDP,TCP_w_size,HTTP,HTTPS,DHCP,BOOTP,SSDP,DNS,MDNS,NTP,IP_padding,IP_add_count,IP_ralert,Portcl_src,Portcl_dst,Pck_size,Pck_rawdata,payload_l,Entropy,Label,MAC,Folder,Session\n"
    ths.write(header)  
    dst_ip_list={}


    files_add=dataset
    for i in files_add:
        filename=str(i)
        filename=filename.replace("\\","/")
        #x = filename.rfind("/")
        filename=filename.split("/")
        print(filename)


        for ii in MAC_list:
            dst_ip_list[ii]=[]
       


        pkt = rdpcap(i)
        print("\n\n"+"========"+ i[8:]+"========"+"\n" )
        print(pkt)
        for jj,j in enumerate(pkt):       
            ip_add_count=0
            layer_2_arp = 0
            layer_2_llc = 0

            layer_3_eapol = 0        
            layer_3_ip = 0
            layer_3_icmp = 0
            layer_3_icmp6 = 0



            layer_4_tcp = 0
            layer_4_udp = 0
            layer_4_tcp_ws=0


            layer_7_http = 0
            layer_7_https = 0
            layer_7_dhcp = 0
            layer_7_bootp = 0
            layer_7_ssdp = 0
            layer_7_dns = 0
            layer_7_mdns = 0
            layer_7_ntp = 0

            ip_padding = 0
            ip_ralert = 0


            port_class_src = 0
            port_class_dst = 0

            pck_size = 0
            pck_rawdata = 0
            entropy=0


            layer_4_payload_l=0




            try:
                pck_size=j.len
            except:pass

            try:
                if j[IP]:
                    layer_3_ip = 1     
                temp=str(j[IP].dst)
                if temp not in dst_ip_list[j.src]:
                    dst_ip_list[j.src].append(temp)
                ip_add_count=len(dst_ip_list[j.src])
                port_class_src = port_class(j[IP].sport)
                port_class_dst = port_class(j[IP].dport)

            except:pass 

            temp=str(j.show)
            if "ICMPv6" in temp:
                layer_3_icmp6 = 1

            try:
                if j[IP].ihl >5:
                    if IPOption_Router_Alert(j):
                        pad=str(IPOption_Router_Alert(j).show)
                        if "Padding" in pad:
                            ip_padding=1
                        ip_ralert = 1     
            except:pass 

            if j.haslayer(ICMP):
                layer_3_icmp = 1  


            if j.haslayer(Raw):
                pck_rawdata = 1   

            if j.haslayer(UDP):

                layer_4_udp = 1
                if j[UDP].sport==68 or j[UDP].sport==67:
                    layer_7_dhcp = 1
                    layer_7_bootp = 1
                if j[UDP].sport==53 or j[UDP].dport==53:
                    layer_7_dns = 1      
                if j[UDP].sport==5353 or j[UDP].dport==5353:
                    layer_7_mdns = 1                    
                if j[UDP].sport==1900 or j[UDP].dport==1900:
                    layer_7_ssdp = 1                    
                if j[UDP].sport==123 or j[UDP].dport==123:
                    layer_7_ntp = 1                    

            try:
                if j[UDP].payload:
                    layer_4_payload_l=len(j[UDP].payload)
            except:pass  



            if j.haslayer(TCP):
                layer_4_tcp = 1
                layer_4_tcp_ws=j[TCP].window
                if j[TCP].sport==80 or j[TCP].dport==80:
                    layer_7_http = 1      
                if j[TCP].sport==443 or j[TCP].dport==443:
                    layer_7_https = 1  
                try:
                    if j[TCP].payload:
                        layer_4_payload_l=len(j[TCP].payload)
                except:pass  

            if j.haslayer(ARP):
                layer_2_arp = 1                                 

            if j.haslayer(LLC):
                layer_2_llc = 1                             

            if j.haslayer(EAPOL):        
                layer_3_eapol = 1                                 
            try:
                entropy=pre_entropy(j[Raw].original)
            except:pass
            label=MAC_list[j.src]
            line=[layer_2_arp, layer_2_llc, layer_3_eapol, layer_3_ip, layer_3_icmp, layer_3_icmp6, layer_4_tcp, layer_4_udp, layer_4_tcp_ws, layer_7_http, layer_7_https, layer_7_dhcp, layer_7_bootp, layer_7_ssdp, layer_7_dns, layer_7_mdns, layer_7_ntp, ip_padding, ip_add_count, ip_ralert, port_class_src, port_class_dst, pck_size, pck_rawdata,layer_4_payload_l,entropy, label,j.src,filename[2],filename[3][:-5]]  
            line=str(line).replace("[","")
            line=str(line).replace("]","")
            line=str(line).replace(", ",",")
            line=str(line).replace("\'","")
            Mac=j.src


            if label=="unknown" and j.dst in ['3c:49:37:03:17:db', '3c:49:37:03:17:f0', '5c:cf:7f:06:d9:02', '5c:cf:7f:07:ae:fb'] :
                label=MAC_list[j.dst] # çift yön eklemesi
                Mac=j.dst


            if label!="unknown":
                ths.write(str(line)+"\n")  

    ths.close()
# Out:
# ['.', 'captures_IoT-Sentinel', 'Aria', 'Setup-A-2-STA.pcap']
#
#
# ========es_IoT-Sentinel\Aria\Setup-A-2-STA.pcap========
#
# <Setup-A-2-STA.pcap: TCP:30 UDP:6 ICMP:0 Other:7>
# ['.', 'captures_IoT-Sentinel', 'Aria', 'Setup-A-3-STA.pcap']
#
#
# ========es_IoT-Sentinel\Aria\Setup-A-3-STA.pcap========
#
# <Setup-A-3-STA.pcap: TCP:30 UDP:10 ICMP:0 Other:8>
# ['.', 'captures_IoT-Sentinel', 'Aria', 'Setup-A-4-STA.pcap']
#
#
# ========es_IoT-Sentinel\Aria\Setup-A-4-STA.pcap========
#
# <Setup-A-4-STA.pcap: TCP:30 UDP:10 ICMP:0 Other:8>
# ['.', 'captures_IoT-Sentinel', 'Aria', 'Setup-A-5-STA.pcap']
#
#
# ========es_IoT-Sentinel\Aria\Setup-A-5-STA.pcap========
#
# <Setup-A-5-STA.pcap: TCP:30 UDP:10 ICMP:0 Other:8>
# ['.', 'captures_IoT-Sentinel', 'Aria', 'Setup-C-10-STA.pcap']
#
#
# ========es_IoT-Sentinel\Aria\Setup-C-10-STA.pcap========
#
# <Setup-C-10-STA.pcap: TCP:30 UDP:10 ICMP:0 Other:8>
# ['.', 'captures_IoT-Sentinel', 'Aria', 'Setup-C-11-STA.pcap']
#
#
# ========es_IoT-Sentinel\Aria\Setup-C-11-STA.pcap========
#
# <Setup-C-11-STA.pcap: TCP:30 UDP:10 ICMP:0 Other:8>
# ['.', 'captures_IoT-Sentinel', 'Aria', 'Setup-C-12-STA.pcap']
#
#
# ========es_IoT-Sentinel\Aria\Setup-C-12-STA.pcap========
#
# <Setup-C-12-STA.pcap: TCP:30 UDP:10 ICMP:0 Other:8>
# ['.', 'captures_IoT-Sentinel', 'Aria', 'Setup-C-13-STA.pcap']
#
#
# ========es_IoT-Sentinel\Aria\Setup-C-13-STA.pcap========
#
# <Setup-C-13-STA.pcap: TCP:30 UDP:10 ICMP:0 Other:8>
# ['.', 'captures_IoT-Sentinel', 'Aria', 'Setup-C-15-STA.pcap']
#
#
# ========es_IoT-Sentinel\Aria\Setup-C-15-STA.pcap========
#
# <Setup-C-15-STA.pcap: TCP:30 UDP:10 ICMP:0 Other:8>
# ['.', 'captures_IoT-Sentinel', 'Aria', 'Setup-C-2-STA.pcap']
#
#
# ========es_IoT-Sentinel\Aria\Setup-C-2-STA.pcap========
#
# <Setup-C-2-STA.pcap: TCP:30 UDP:10 ICMP:0 Other:8>
# ['.', 'captures_IoT-Sentinel', 'Aria', 'Setup-C-3-STA.pcap']
#
#
# ========es_IoT-Sentinel\Aria\Setup-C-3-STA.pcap========
#
# <Setup-C-3-STA.pcap: TCP:33 UDP:10 ICMP:0 Other:8>
# ['.', 'captures_IoT-Sentinel', 'Aria', 'Setup-C-4-STA.pcap']
#
#
# ========es_IoT-Sentinel\Aria\Setup-C-4-STA.pcap========
#
# <Setup-C-4-STA.pcap: TCP:30 UDP:10 ICMP:0 Other:8>
# ['.', 'captures_IoT-Sentinel', 'Aria', 'Setup-C-6-STA.pcap']
#
#
# ========es_IoT-Sentinel\Aria\Setup-C-6-STA.pcap========
#
# <Setup-C-6-STA.pcap: TCP:30 UDP:10 ICMP:1 Other:8>
# ['.', 'captures_IoT-Sentinel', 'Aria', 'Setup-C-7-STA.pcap']
#
#
# ========es_IoT-Sentinel\Aria\Setup-C-7-STA.pcap========
#
# <Setup-C-7-STA.pcap: TCP:30 UDP:10 ICMP:0 Other:8>
# ['.', 'captures_IoT-Sentinel', 'Aria', 'Setup-C-8-STA.pcap']
#
#
# ========es_IoT-Sentinel\Aria\Setup-C-8-STA.pcap========
#
# <Setup-C-8-STA.pcap: TCP:30 UDP:10 ICMP:0 Other:8>
# ['.', 'captures_IoT-Sentinel', 'Aria', 'Setup-C-9-STA.pcap']
#
#
# ========es_IoT-Sentinel\Aria\Setup-C-9-STA.pcap========
#
# <Setup-C-9-STA.pcap: TCP:30 UDP:10 ICMP:0 Other:8>
# ['.', 'captures_IoT-Sentinel', 'D-LinkCam', 'Setup-A-2-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkCam\Setup-A-2-STA.pcap========
#
# <Setup-A-2-STA.pcap: TCP:206 UDP:385 ICMP:1 Other:50>
# ['.', 'captures_IoT-Sentinel', 'D-LinkCam', 'Setup-A-3-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkCam\Setup-A-3-STA.pcap========
#
# <Setup-A-3-STA.pcap: TCP:199 UDP:377 ICMP:1 Other:52>
# ['.', 'captures_IoT-Sentinel', 'D-LinkCam', 'Setup-A-4-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkCam\Setup-A-4-STA.pcap========
#
# <Setup-A-4-STA.pcap: TCP:179 UDP:389 ICMP:0 Other:52>
# ['.', 'captures_IoT-Sentinel', 'D-LinkCam', 'Setup-A-5-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkCam\Setup-A-5-STA.pcap========
#
# <Setup-A-5-STA.pcap: TCP:209 UDP:387 ICMP:0 Other:56>
# ['.', 'captures_IoT-Sentinel', 'D-LinkCam', 'Setup-B-2-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkCam\Setup-B-2-STA.pcap========
#
# <Setup-B-2-STA.pcap: TCP:72 UDP:177 ICMP:0 Other:27>
# ['.', 'captures_IoT-Sentinel', 'D-LinkCam', 'Setup-B-3-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkCam\Setup-B-3-STA.pcap========
#
# <Setup-B-3-STA.pcap: TCP:77 UDP:181 ICMP:1 Other:27>
# ['.', 'captures_IoT-Sentinel', 'D-LinkCam', 'Setup-B-4-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkCam\Setup-B-4-STA.pcap========
#
# <Setup-B-4-STA.pcap: TCP:72 UDP:176 ICMP:1 Other:29>
# ['.', 'captures_IoT-Sentinel', 'D-LinkCam', 'Setup-B-5-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkCam\Setup-B-5-STA.pcap========
#
# <Setup-B-5-STA.pcap: TCP:72 UDP:181 ICMP:1 Other:24>
# ['.', 'captures_IoT-Sentinel', 'D-LinkCam', 'Setup-C-10-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkCam\Setup-C-10-STA.pcap========
#
# <Setup-C-10-STA.pcap: TCP:75 UDP:177 ICMP:1 Other:29>
# ['.', 'captures_IoT-Sentinel', 'D-LinkCam', 'Setup-C-2-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkCam\Setup-C-2-STA.pcap========
#
# <Setup-C-2-STA.pcap: TCP:78 UDP:203 ICMP:1 Other:26>
# ['.', 'captures_IoT-Sentinel', 'D-LinkCam', 'Setup-C-3-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkCam\Setup-C-3-STA.pcap========
#
# <Setup-C-3-STA.pcap: TCP:76 UDP:187 ICMP:1 Other:24>
# ['.', 'captures_IoT-Sentinel', 'D-LinkCam', 'Setup-C-4-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkCam\Setup-C-4-STA.pcap========
#
# <Setup-C-4-STA.pcap: TCP:78 UDP:190 ICMP:1 Other:25>
# ['.', 'captures_IoT-Sentinel', 'D-LinkCam', 'Setup-C-6-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkCam\Setup-C-6-STA.pcap========
#
# <Setup-C-6-STA.pcap: TCP:73 UDP:202 ICMP:1 Other:28>
# ['.', 'captures_IoT-Sentinel', 'D-LinkCam', 'Setup-C-7-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkCam\Setup-C-7-STA.pcap========
#
# <Setup-C-7-STA.pcap: TCP:53 UDP:189 ICMP:1 Other:26>
# ['.', 'captures_IoT-Sentinel', 'D-LinkCam', 'Setup-C-8-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkCam\Setup-C-8-STA.pcap========
#
# <Setup-C-8-STA.pcap: TCP:76 UDP:179 ICMP:1 Other:23>
# ['.', 'captures_IoT-Sentinel', 'D-LinkCam', 'Setup-C-9-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkCam\Setup-C-9-STA.pcap========
#
# <Setup-C-9-STA.pcap: TCP:75 UDP:192 ICMP:1 Other:27>
# ['.', 'captures_IoT-Sentinel', 'D-LinkDayCam', 'Setup-A-2-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkDayCam\Setup-A-2-STA.pcap========
#
# <Setup-A-2-STA.pcap: TCP:0 UDP:43 ICMP:0 Other:18>
# ['.', 'captures_IoT-Sentinel', 'D-LinkDayCam', 'Setup-A-3-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkDayCam\Setup-A-3-STA.pcap========
#
# <Setup-A-3-STA.pcap: TCP:0 UDP:43 ICMP:0 Other:18>
# ['.', 'captures_IoT-Sentinel', 'D-LinkDayCam', 'Setup-A-4-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkDayCam\Setup-A-4-STA.pcap========
#
# <Setup-A-4-STA.pcap: TCP:0 UDP:43 ICMP:0 Other:18>
# ['.', 'captures_IoT-Sentinel', 'D-LinkDayCam', 'Setup-A-5-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkDayCam\Setup-A-5-STA.pcap========
#
# <Setup-A-5-STA.pcap: TCP:0 UDP:43 ICMP:0 Other:19>
# ['.', 'captures_IoT-Sentinel', 'D-LinkDayCam', 'Setup-C-10-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkDayCam\Setup-C-10-STA.pcap========
#
# <Setup-C-10-STA.pcap: TCP:0 UDP:42 ICMP:0 Other:23>
# ['.', 'captures_IoT-Sentinel', 'D-LinkDayCam', 'Setup-C-11-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkDayCam\Setup-C-11-STA.pcap========
#
# <Setup-C-11-STA.pcap: TCP:0 UDP:44 ICMP:0 Other:16>
# ['.', 'captures_IoT-Sentinel', 'D-LinkDayCam', 'Setup-C-12-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkDayCam\Setup-C-12-STA.pcap========
#
# <Setup-C-12-STA.pcap: TCP:0 UDP:44 ICMP:0 Other:17>
# ['.', 'captures_IoT-Sentinel', 'D-LinkDayCam', 'Setup-C-13-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkDayCam\Setup-C-13-STA.pcap========
#
# <Setup-C-13-STA.pcap: TCP:0 UDP:42 ICMP:0 Other:18>
# ['.', 'captures_IoT-Sentinel', 'D-LinkDayCam', 'Setup-C-15-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkDayCam\Setup-C-15-STA.pcap========
#
# <Setup-C-15-STA.pcap: TCP:0 UDP:44 ICMP:0 Other:17>
# ['.', 'captures_IoT-Sentinel', 'D-LinkDayCam', 'Setup-C-2-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkDayCam\Setup-C-2-STA.pcap========
#
# <Setup-C-2-STA.pcap: TCP:0 UDP:43 ICMP:0 Other:22>
# ['.', 'captures_IoT-Sentinel', 'D-LinkDayCam', 'Setup-C-3-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkDayCam\Setup-C-3-STA.pcap========
#
# <Setup-C-3-STA.pcap: TCP:0 UDP:43 ICMP:0 Other:23>
# ['.', 'captures_IoT-Sentinel', 'D-LinkDayCam', 'Setup-C-4-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkDayCam\Setup-C-4-STA.pcap========
#
# <Setup-C-4-STA.pcap: TCP:0 UDP:43 ICMP:0 Other:20>
# ['.', 'captures_IoT-Sentinel', 'D-LinkDayCam', 'Setup-C-6-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkDayCam\Setup-C-6-STA.pcap========
#
# <Setup-C-6-STA.pcap: TCP:0 UDP:43 ICMP:0 Other:17>
# ['.', 'captures_IoT-Sentinel', 'D-LinkDayCam', 'Setup-C-7-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkDayCam\Setup-C-7-STA.pcap========
#
# <Setup-C-7-STA.pcap: TCP:0 UDP:43 ICMP:0 Other:17>
# ['.', 'captures_IoT-Sentinel', 'D-LinkDayCam', 'Setup-C-8-STA.pcap']
# ========es_IoT-Sentinel\D-LinkDayCam\Setup-C-8-STA.pcap========
#
# <Setup-C-8-STA.pcap: TCP:0 UDP:43 ICMP:0 Other:17>
# ['.', 'captures_IoT-Sentinel', 'D-LinkDayCam', 'Setup-C-9-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkDayCam\Setup-C-9-STA.pcap========
#
# <Setup-C-9-STA.pcap: TCP:0 UDP:44 ICMP:0 Other:17>
# ['.', 'captures_IoT-Sentinel', 'D-LinkDoorSensor', 'Setup-C-10-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkDoorSensor\Setup-C-10-STA.pcap========
#
# <Setup-C-10-STA.pcap: TCP:168 UDP:2 ICMP:0 Other:6>
# ['.', 'captures_IoT-Sentinel', 'D-LinkDoorSensor', 'Setup-C-11-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkDoorSensor\Setup-C-11-STA.pcap========
#
# <Setup-C-11-STA.pcap: TCP:143 UDP:2 ICMP:0 Other:8>
# ['.', 'captures_IoT-Sentinel', 'D-LinkDoorSensor', 'Setup-C-12-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkDoorSensor\Setup-C-12-STA.pcap========
#
# <Setup-C-12-STA.pcap: TCP:211 UDP:0 ICMP:0 Other:8>
# ['.', 'captures_IoT-Sentinel', 'D-LinkDoorSensor', 'Setup-C-13-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkDoorSensor\Setup-C-13-STA.pcap========
#
# <Setup-C-13-STA.pcap: TCP:149 UDP:0 ICMP:0 Other:4>
# ['.', 'captures_IoT-Sentinel', 'D-LinkDoorSensor', 'Setup-C-15-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkDoorSensor\Setup-C-15-STA.pcap========
#
# <Setup-C-15-STA.pcap: TCP:192 UDP:0 ICMP:0 Other:4>
# ['.', 'captures_IoT-Sentinel', 'D-LinkDoorSensor', 'Setup-C-16-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkDoorSensor\Setup-C-16-STA.pcap========
#
# <Setup-C-16-STA.pcap: TCP:185 UDP:0 ICMP:0 Other:6>
# ['.', 'captures_IoT-Sentinel', 'D-LinkDoorSensor', 'Setup-C-17-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkDoorSensor\Setup-C-17-STA.pcap========
#
# <Setup-C-17-STA.pcap: TCP:217 UDP:2 ICMP:0 Other:8>
# ['.', 'captures_IoT-Sentinel', 'D-LinkDoorSensor', 'Setup-C-18-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkDoorSensor\Setup-C-18-STA.pcap========
#
# <Setup-C-18-STA.pcap: TCP:279 UDP:7 ICMP:0 Other:6>
# ['.', 'captures_IoT-Sentinel', 'D-LinkDoorSensor', 'Setup-C-2-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkDoorSensor\Setup-C-2-STA.pcap========
#
# <Setup-C-2-STA.pcap: TCP:136 UDP:8 ICMP:0 Other:8>
# ['.', 'captures_IoT-Sentinel', 'D-LinkDoorSensor', 'Setup-C-20-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkDoorSensor\Setup-C-20-STA.pcap========
#
# <Setup-C-20-STA.pcap: TCP:171 UDP:0 ICMP:0 Other:8>
# ['.', 'captures_IoT-Sentinel', 'D-LinkDoorSensor', 'Setup-C-3-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkDoorSensor\Setup-C-3-STA.pcap========
#
# <Setup-C-3-STA.pcap: TCP:168 UDP:2 ICMP:0 Other:8>
# ['.', 'captures_IoT-Sentinel', 'D-LinkDoorSensor', 'Setup-C-4-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkDoorSensor\Setup-C-4-STA.pcap========
#
# <Setup-C-4-STA.pcap: TCP:160 UDP:0 ICMP:0 Other:4>
# ['.', 'captures_IoT-Sentinel', 'D-LinkDoorSensor', 'Setup-C-6-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkDoorSensor\Setup-C-6-STA.pcap========
#
# <Setup-C-6-STA.pcap: TCP:203 UDP:8 ICMP:0 Other:6>
# ['.', 'captures_IoT-Sentinel', 'D-LinkDoorSensor', 'Setup-C-7-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkDoorSensor\Setup-C-7-STA.pcap========
#
# <Setup-C-7-STA.pcap: TCP:230 UDP:2 ICMP:0 Other:8>
# ['.', 'captures_IoT-Sentinel', 'D-LinkDoorSensor', 'Setup-C-8-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkDoorSensor\Setup-C-8-STA.pcap========
#
# <Setup-C-8-STA.pcap: TCP:177 UDP:0 ICMP:0 Other:8>
# ['.', 'captures_IoT-Sentinel', 'D-LinkDoorSensor', 'Setup-C-9-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkDoorSensor\Setup-C-9-STA.pcap========
#
# <Setup-C-9-STA.pcap: TCP:150 UDP:0 ICMP:0 Other:5>
# ['.', 'captures_IoT-Sentinel', 'D-LinkHomeHub', 'Setup-A-2-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkHomeHub\Setup-A-2-STA.pcap========
#
# <Setup-A-2-STA.pcap: TCP:581 UDP:106 ICMP:0 Other:21>
# ['.', 'captures_IoT-Sentinel', 'D-LinkHomeHub', 'Setup-A-3-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkHomeHub\Setup-A-3-STA.pcap========
#
# <Setup-A-3-STA.pcap: TCP:582 UDP:110 ICMP:0 Other:24>
# ['.', 'captures_IoT-Sentinel', 'D-LinkHomeHub', 'Setup-A-4-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkHomeHub\Setup-A-4-STA.pcap========
#
# <Setup-A-4-STA.pcap: TCP:581 UDP:104 ICMP:0 Other:22>
# ['.', 'captures_IoT-Sentinel', 'D-LinkHomeHub', 'Setup-A-5-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkHomeHub\Setup-A-5-STA.pcap========
#
# <Setup-A-5-STA.pcap: TCP:589 UDP:107 ICMP:0 Other:28>
# ['.', 'captures_IoT-Sentinel', 'D-LinkHomeHub', 'Setup-C-10-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkHomeHub\Setup-C-10-STA.pcap========
#
# <Setup-C-10-STA.pcap: TCP:616 UDP:169 ICMP:0 Other:42>
# ['.', 'captures_IoT-Sentinel', 'D-LinkHomeHub', 'Setup-C-11-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkHomeHub\Setup-C-11-STA.pcap========
#
# <Setup-C-11-STA.pcap: TCP:624 UDP:170 ICMP:0 Other:41>
# ['.', 'captures_IoT-Sentinel', 'D-LinkHomeHub', 'Setup-C-12-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkHomeHub\Setup-C-12-STA.pcap========
#
# <Setup-C-12-STA.pcap: TCP:619 UDP:177 ICMP:0 Other:47>
# ['.', 'captures_IoT-Sentinel', 'D-LinkHomeHub', 'Setup-C-13-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkHomeHub\Setup-C-13-STA.pcap========
#
# <Setup-C-13-STA.pcap: TCP:611 UDP:173 ICMP:0 Other:40>
# ['.', 'captures_IoT-Sentinel', 'D-LinkHomeHub', 'Setup-C-15-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkHomeHub\Setup-C-15-STA.pcap========
#
# <Setup-C-15-STA.pcap: TCP:612 UDP:172 ICMP:0 Other:45>
# ['.', 'captures_IoT-Sentinel', 'D-LinkHomeHub', 'Setup-C-2-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkHomeHub\Setup-C-2-STA.pcap========
#
# <Setup-C-2-STA.pcap: TCP:701 UDP:166 ICMP:0 Other:43>
# ['.', 'captures_IoT-Sentinel', 'D-LinkHomeHub', 'Setup-C-3-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkHomeHub\Setup-C-3-STA.pcap========
#
# <Setup-C-3-STA.pcap: TCP:707 UDP:170 ICMP:0 Other:47>
# ['.', 'captures_IoT-Sentinel', 'D-LinkHomeHub', 'Setup-C-4-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkHomeHub\Setup-C-4-STA.pcap========
#
# <Setup-C-4-STA.pcap: TCP:703 UDP:169 ICMP:0 Other:43>
# ['.', 'captures_IoT-Sentinel', 'D-LinkHomeHub', 'Setup-C-6-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkHomeHub\Setup-C-6-STA.pcap========
#
# <Setup-C-6-STA.pcap: TCP:509 UDP:106 ICMP:0 Other:21>
# ['.', 'captures_IoT-Sentinel', 'D-LinkHomeHub', 'Setup-C-7-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkHomeHub\Setup-C-7-STA.pcap========
#
# <Setup-C-7-STA.pcap: TCP:514 UDP:105 ICMP:0 Other:22>
# ['.', 'captures_IoT-Sentinel', 'D-LinkHomeHub', 'Setup-C-8-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkHomeHub\Setup-C-8-STA.pcap========
#
# <Setup-C-8-STA.pcap: TCP:614 UDP:176 ICMP:0 Other:49>
# ['.', 'captures_IoT-Sentinel', 'D-LinkHomeHub', 'Setup-C-9-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkHomeHub\Setup-C-9-STA.pcap========
#
# <Setup-C-9-STA.pcap: TCP:610 UDP:171 ICMP:0 Other:42>
# ['.', 'captures_IoT-Sentinel', 'D-LinkSensor', 'Setup-A-2-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkSensor\Setup-A-2-STA.pcap========
#
# <Setup-A-2-STA.pcap: TCP:546 UDP:108 ICMP:0 Other:17>
# ['.', 'captures_IoT-Sentinel', 'D-LinkSensor', 'Setup-A-3-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkSensor\Setup-A-3-STA.pcap========
#
# <Setup-A-3-STA.pcap: TCP:535 UDP:118 ICMP:0 Other:22>
# ['.', 'captures_IoT-Sentinel', 'D-LinkSensor', 'Setup-A-4-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkSensor\Setup-A-4-STA.pcap========
#
# <Setup-A-4-STA.pcap: TCP:534 UDP:112 ICMP:0 Other:15>
# ['.', 'captures_IoT-Sentinel', 'D-LinkSensor', 'Setup-A-5-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkSensor\Setup-A-5-STA.pcap========
#
# <Setup-A-5-STA.pcap: TCP:537 UDP:110 ICMP:0 Other:16>
# ['.', 'captures_IoT-Sentinel', 'D-LinkSensor', 'Setup-B-2-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkSensor\Setup-B-2-STA.pcap========
#
# <Setup-B-2-STA.pcap: TCP:506 UDP:115 ICMP:0 Other:18>
# ['.', 'captures_IoT-Sentinel', 'D-LinkSensor', 'Setup-B-3-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkSensor\Setup-B-3-STA.pcap========
#
# <Setup-B-3-STA.pcap: TCP:528 UDP:126 ICMP:0 Other:18>
# ['.', 'captures_IoT-Sentinel', 'D-LinkSensor', 'Setup-B-4-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkSensor\Setup-B-4-STA.pcap========
#
# <Setup-B-4-STA.pcap: TCP:528 UDP:110 ICMP:0 Other:15>
# ['.', 'captures_IoT-Sentinel', 'D-LinkSensor', 'Setup-B-5-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkSensor\Setup-B-5-STA.pcap========
#
# <Setup-B-5-STA.pcap: TCP:531 UDP:121 ICMP:0 Other:31>
# ['.', 'captures_IoT-Sentinel', 'D-LinkSensor', 'Setup-C-10-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkSensor\Setup-C-10-STA.pcap========
#
# <Setup-C-10-STA.pcap: TCP:473 UDP:128 ICMP:0 Other:29>
# ['.', 'captures_IoT-Sentinel', 'D-LinkSensor', 'Setup-C-2-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkSensor\Setup-C-2-STA.pcap========
#
# <Setup-C-2-STA.pcap: TCP:469 UDP:112 ICMP:1 Other:17>
# ['.', 'captures_IoT-Sentinel', 'D-LinkSensor', 'Setup-C-3-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkSensor\Setup-C-3-STA.pcap========
#
# <Setup-C-3-STA.pcap: TCP:465 UDP:115 ICMP:0 Other:16>
# ['.', 'captures_IoT-Sentinel', 'D-LinkSensor', 'Setup-C-4-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkSensor\Setup-C-4-STA.pcap========
#
# <Setup-C-4-STA.pcap: TCP:463 UDP:110 ICMP:0 Other:16>
# ['.', 'captures_IoT-Sentinel', 'D-LinkSensor', 'Setup-C-6-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkSensor\Setup-C-6-STA.pcap========
#
# <Setup-C-6-STA.pcap: TCP:465 UDP:108 ICMP:0 Other:17>
# ['.', 'captures_IoT-Sentinel', 'D-LinkSensor', 'Setup-C-7-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkSensor\Setup-C-7-STA.pcap========
#
# <Setup-C-7-STA.pcap: TCP:466 UDP:111 ICMP:0 Other:19>
# ['.', 'captures_IoT-Sentinel', 'D-LinkSensor', 'Setup-C-8-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkSensor\Setup-C-8-STA.pcap========
#
# <Setup-C-8-STA.pcap: TCP:461 UDP:112 ICMP:0 Other:19>
# ['.', 'captures_IoT-Sentinel', 'D-LinkSensor', 'Setup-C-9-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkSensor\Setup-C-9-STA.pcap========
#
# <Setup-C-9-STA.pcap: TCP:465 UDP:113 ICMP:0 Other:18>
# ['.', 'captures_IoT-Sentinel', 'D-LinkSiren', 'Setup-C-1-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkSiren\Setup-C-1-STA.pcap========
#
# <Setup-C-1-STA.pcap: TCP:458 UDP:101 ICMP:0 Other:21>
# ['.', 'captures_IoT-Sentinel', 'D-LinkSiren', 'Setup-C-10-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkSiren\Setup-C-10-STA.pcap========
#
# <Setup-C-10-STA.pcap: TCP:423 UDP:95 ICMP:0 Other:20>
# ['.', 'captures_IoT-Sentinel', 'D-LinkSiren', 'Setup-C-11-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkSiren\Setup-C-11-STA.pcap========
#
# <Setup-C-11-STA.pcap: TCP:433 UDP:96 ICMP:0 Other:22>
# ['.', 'captures_IoT-Sentinel', 'D-LinkSiren', 'Setup-C-12-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkSiren\Setup-C-12-STA.pcap========
#
# <Setup-C-12-STA.pcap: TCP:459 UDP:123 ICMP:0 Other:30>
# ['.', 'captures_IoT-Sentinel', 'D-LinkSiren', 'Setup-C-14-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkSiren\Setup-C-14-STA.pcap========
#
# <Setup-C-14-STA.pcap: TCP:467 UDP:111 ICMP:0 Other:28>
# ['.', 'captures_IoT-Sentinel', 'D-LinkSiren', 'Setup-C-15-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkSiren\Setup-C-15-STA.pcap========
#
# <Setup-C-15-STA.pcap: TCP:462 UDP:107 ICMP:0 Other:31>
# ['.', 'captures_IoT-Sentinel', 'D-LinkSiren', 'Setup-C-16-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkSiren\Setup-C-16-STA.pcap========
#
# <Setup-C-16-STA.pcap: TCP:466 UDP:101 ICMP:0 Other:22>
# ['.', 'captures_IoT-Sentinel', 'D-LinkSiren', 'Setup-C-17-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkSiren\Setup-C-17-STA.pcap========
#
# <Setup-C-17-STA.pcap: TCP:434 UDP:97 ICMP:0 Other:25>
# ['.', 'captures_IoT-Sentinel', 'D-LinkSiren', 'Setup-C-19-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkSiren\Setup-C-19-STA.pcap========
#
# <Setup-C-19-STA.pcap: TCP:466 UDP:128 ICMP:0 Other:32>
# ['.', 'captures_IoT-Sentinel', 'D-LinkSiren', 'Setup-C-2-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkSiren\Setup-C-2-STA.pcap========
#
# <Setup-C-2-STA.pcap: TCP:463 UDP:96 ICMP:0 Other:29>
# ['.', 'captures_IoT-Sentinel', 'D-LinkSiren', 'Setup-C-3-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkSiren\Setup-C-3-STA.pcap========
#
# <Setup-C-3-STA.pcap: TCP:464 UDP:112 ICMP:0 Other:33>
# ['.', 'captures_IoT-Sentinel', 'D-LinkSiren', 'Setup-C-4-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkSiren\Setup-C-4-STA.pcap========
#
# <Setup-C-4-STA.pcap: TCP:464 UDP:104 ICMP:0 Other:33>
# ['.', 'captures_IoT-Sentinel', 'D-LinkSiren', 'Setup-C-6-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkSiren\Setup-C-6-STA.pcap========
#
# <Setup-C-6-STA.pcap: TCP:462 UDP:115 ICMP:0 Other:28>
# ['.', 'captures_IoT-Sentinel', 'D-LinkSiren', 'Setup-C-7-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkSiren\Setup-C-7-STA.pcap========
#
# <Setup-C-7-STA.pcap: TCP:462 UDP:120 ICMP:0 Other:28>
# ['.', 'captures_IoT-Sentinel', 'D-LinkSiren', 'Setup-C-8-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkSiren\Setup-C-8-STA.pcap========
#
# <Setup-C-8-STA.pcap: TCP:460 UDP:91 ICMP:0 Other:24>
# ['.', 'captures_IoT-Sentinel', 'D-LinkSiren', 'Setup-C-9-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkSiren\Setup-C-9-STA.pcap========
#
# <Setup-C-9-STA.pcap: TCP:463 UDP:101 ICMP:0 Other:25>
# ['.', 'captures_IoT-Sentinel', 'D-LinkSwitch', 'Setup-A-2-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkSwitch\Setup-A-2-STA.pcap========
#
# <Setup-A-2-STA.pcap: TCP:591 UDP:97 ICMP:0 Other:24>
# ['.', 'captures_IoT-Sentinel', 'D-LinkSwitch', 'Setup-A-3-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkSwitch\Setup-A-3-STA.pcap========
#
# <Setup-A-3-STA.pcap: TCP:582 UDP:79 ICMP:0 Other:19>
# ['.', 'captures_IoT-Sentinel', 'D-LinkSwitch', 'Setup-A-4-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkSwitch\Setup-A-4-STA.pcap========
#
# <Setup-A-4-STA.pcap: TCP:506 UDP:91 ICMP:0 Other:29>
# ['.', 'captures_IoT-Sentinel', 'D-LinkSwitch', 'Setup-A-5-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkSwitch\Setup-A-5-STA.pcap========
#
# <Setup-A-5-STA.pcap: TCP:590 UDP:77 ICMP:0 Other:33>
# ['.', 'captures_IoT-Sentinel', 'D-LinkSwitch', 'Setup-C-10-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkSwitch\Setup-C-10-STA.pcap========
#
# <Setup-C-10-STA.pcap: TCP:522 UDP:76 ICMP:0 Other:21>
# ['.', 'captures_IoT-Sentinel', 'D-LinkSwitch', 'Setup-C-11-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkSwitch\Setup-C-11-STA.pcap========
#
# <Setup-C-11-STA.pcap: TCP:496 UDP:64 ICMP:0 Other:24>
# ['.', 'captures_IoT-Sentinel', 'D-LinkSwitch', 'Setup-C-12-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkSwitch\Setup-C-12-STA.pcap========
#
# <Setup-C-12-STA.pcap: TCP:509 UDP:83 ICMP:0 Other:29>
# ['.', 'captures_IoT-Sentinel', 'D-LinkSwitch', 'Setup-C-13-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkSwitch\Setup-C-13-STA.pcap========
#
# <Setup-C-13-STA.pcap: TCP:512 UDP:85 ICMP:0 Other:27>
# ['.', 'captures_IoT-Sentinel', 'D-LinkSwitch', 'Setup-C-15-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkSwitch\Setup-C-15-STA.pcap========
#
# <Setup-C-15-STA.pcap: TCP:498 UDP:77 ICMP:0 Other:19>
# ['.', 'captures_IoT-Sentinel', 'D-LinkSwitch', 'Setup-C-2-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkSwitch\Setup-C-2-STA.pcap========
#
# <Setup-C-2-STA.pcap: TCP:526 UDP:82 ICMP:0 Other:34>
# ['.', 'captures_IoT-Sentinel', 'D-LinkSwitch', 'Setup-C-3-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkSwitch\Setup-C-3-STA.pcap========
#
# <Setup-C-3-STA.pcap: TCP:610 UDP:83 ICMP:0 Other:22>
# ['.', 'captures_IoT-Sentinel', 'D-LinkSwitch', 'Setup-C-4-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkSwitch\Setup-C-4-STA.pcap========
#
# <Setup-C-4-STA.pcap: TCP:664 UDP:85 ICMP:0 Other:21>
# ['.', 'captures_IoT-Sentinel', 'D-LinkSwitch', 'Setup-C-6-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkSwitch\Setup-C-6-STA.pcap========
#
# <Setup-C-6-STA.pcap: TCP:509 UDP:77 ICMP:0 Other:23>
# ['.', 'captures_IoT-Sentinel', 'D-LinkSwitch', 'Setup-C-7-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkSwitch\Setup-C-7-STA.pcap========
#
# <Setup-C-7-STA.pcap: TCP:518 UDP:75 ICMP:0 Other:20>
# ['.', 'captures_IoT-Sentinel', 'D-LinkSwitch', 'Setup-C-8-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkSwitch\Setup-C-8-STA.pcap========
#
# <Setup-C-8-STA.pcap: TCP:497 UDP:93 ICMP:0 Other:26>
# ['.', 'captures_IoT-Sentinel', 'D-LinkSwitch', 'Setup-C-9-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkSwitch\Setup-C-9-STA.pcap========
#
# <Setup-C-9-STA.pcap: TCP:468 UDP:95 ICMP:0 Other:31>
# ['.', 'captures_IoT-Sentinel', 'D-LinkWaterSensor', 'Setup-C-1-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkWaterSensor\Setup-C-1-STA.pcap========
#
# <Setup-C-1-STA.pcap: TCP:466 UDP:111 ICMP:0 Other:21>
# ['.', 'captures_IoT-Sentinel', 'D-LinkWaterSensor', 'Setup-C-10-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkWaterSensor\Setup-C-10-STA.pcap========
#
# <Setup-C-10-STA.pcap: TCP:472 UDP:120 ICMP:0 Other:24>
# ['.', 'captures_IoT-Sentinel', 'D-LinkWaterSensor', 'Setup-C-11-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkWaterSensor\Setup-C-11-STA.pcap========
#
# <Setup-C-11-STA.pcap: TCP:463 UDP:111 ICMP:0 Other:18>
# ['.', 'captures_IoT-Sentinel', 'D-LinkWaterSensor', 'Setup-C-12-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkWaterSensor\Setup-C-12-STA.pcap========
#
# <Setup-C-12-STA.pcap: TCP:467 UDP:112 ICMP:0 Other:24>
# ['.', 'captures_IoT-Sentinel', 'D-LinkWaterSensor', 'Setup-C-14-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkWaterSensor\Setup-C-14-STA.pcap========
#
# <Setup-C-14-STA.pcap: TCP:463 UDP:130 ICMP:0 Other:25>
# ['.', 'captures_IoT-Sentinel', 'D-LinkWaterSensor', 'Setup-C-15-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkWaterSensor\Setup-C-15-STA.pcap========
#
# <Setup-C-15-STA.pcap: TCP:467 UDP:127 ICMP:0 Other:23>
# ['.', 'captures_IoT-Sentinel', 'D-LinkWaterSensor', 'Setup-C-16-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkWaterSensor\Setup-C-16-STA.pcap========
#
# <Setup-C-16-STA.pcap: TCP:467 UDP:148 ICMP:0 Other:26>
# ['.', 'captures_IoT-Sentinel', 'D-LinkWaterSensor', 'Setup-C-17-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkWaterSensor\Setup-C-17-STA.pcap========
#
# <Setup-C-17-STA.pcap: TCP:466 UDP:116 ICMP:0 Other:23>
# ['.', 'captures_IoT-Sentinel', 'D-LinkWaterSensor', 'Setup-C-19-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkWaterSensor\Setup-C-19-STA.pcap========
#
# <Setup-C-19-STA.pcap: TCP:463 UDP:130 ICMP:0 Other:26>
# ['.', 'captures_IoT-Sentinel', 'D-LinkWaterSensor', 'Setup-C-2-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkWaterSensor\Setup-C-2-STA.pcap========
#
# <Setup-C-2-STA.pcap: TCP:472 UDP:124 ICMP:0 Other:29>
# ['.', 'captures_IoT-Sentinel', 'D-LinkWaterSensor', 'Setup-C-3-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkWaterSensor\Setup-C-3-STA.pcap========
#
# <Setup-C-3-STA.pcap: TCP:465 UDP:106 ICMP:0 Other:14>
# ['.', 'captures_IoT-Sentinel', 'D-LinkWaterSensor', 'Setup-C-4-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkWaterSensor\Setup-C-4-STA.pcap========
#
# <Setup-C-4-STA.pcap: TCP:469 UDP:106 ICMP:0 Other:20>
# ['.', 'captures_IoT-Sentinel', 'D-LinkWaterSensor', 'Setup-C-6-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkWaterSensor\Setup-C-6-STA.pcap========
#
# <Setup-C-6-STA.pcap: TCP:468 UDP:138 ICMP:0 Other:25>
# ['.', 'captures_IoT-Sentinel', 'D-LinkWaterSensor', 'Setup-C-7-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkWaterSensor\Setup-C-7-STA.pcap========
#
# <Setup-C-7-STA.pcap: TCP:437 UDP:121 ICMP:0 Other:24>
# ['.', 'captures_IoT-Sentinel', 'D-LinkWaterSensor', 'Setup-C-8-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkWaterSensor\Setup-C-8-STA.pcap========
#
# <Setup-C-8-STA.pcap: TCP:459 UDP:103 ICMP:0 Other:17>
# ['.', 'captures_IoT-Sentinel', 'D-LinkWaterSensor', 'Setup-C-9-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkWaterSensor\Setup-C-9-STA.pcap========
#
# <Setup-C-9-STA.pcap: TCP:464 UDP:127 ICMP:0 Other:26>
# ['.', 'captures_IoT-Sentinel', 'EdimaxCam1', 'Setup-A-2-STA.pcap']
#
#
# ========es_IoT-Sentinel\EdimaxCam1\Setup-A-2-STA.pcap========
#
# <Setup-A-2-STA.pcap: TCP:0 UDP:33 ICMP:0 Other:8>
# ['.', 'captures_IoT-Sentinel', 'EdimaxCam1', 'Setup-A-3-STA.pcap']
#
#
# ========es_IoT-Sentinel\EdimaxCam1\Setup-A-3-STA.pcap========
#
# <Setup-A-3-STA.pcap: TCP:0 UDP:45 ICMP:0 Other:10>
# ['.', 'captures_IoT-Sentinel', 'EdimaxCam1', 'Setup-A-4-STA.pcap']
#
#
# ========es_IoT-Sentinel\EdimaxCam1\Setup-A-4-STA.pcap========
#
# <Setup-A-4-STA.pcap: TCP:0 UDP:38 ICMP:0 Other:7>
# ['.', 'captures_IoT-Sentinel', 'EdimaxCam1', 'Setup-A-5-STA.pcap']
#
#
# ========es_IoT-Sentinel\EdimaxCam1\Setup-A-5-STA.pcap========
#
# <Setup-A-5-STA.pcap: TCP:0 UDP:33 ICMP:0 Other:7>
# ['.', 'captures_IoT-Sentinel', 'EdimaxCam1', 'Setup-A-7-STA.pcap']
#
#
# ========es_IoT-Sentinel\EdimaxCam1\Setup-A-7-STA.pcap========
#
# <Setup-A-7-STA.pcap: TCP:0 UDP:34 ICMP:0 Other:7>
# ['.', 'captures_IoT-Sentinel', 'EdimaxCam1', 'Setup-C-1-STA.pcap']
#
#
# ========es_IoT-Sentinel\EdimaxCam1\Setup-C-1-STA.pcap========
#
# <Setup-C-1-STA.pcap: TCP:0 UDP:37 ICMP:0 Other:9>
# ['.', 'captures_IoT-Sentinel', 'EdimaxCam1', 'Setup-C-2-STA.pcap']
#
#
# ========es_IoT-Sentinel\EdimaxCam1\Setup-C-2-STA.pcap========
#
# <Setup-C-2-STA.pcap: TCP:0 UDP:33 ICMP:0 Other:7>
# ['.', 'captures_IoT-Sentinel', 'EdimaxCam1', 'Setup-C-3-STA.pcap']
#
#
# ========es_IoT-Sentinel\EdimaxCam1\Setup-C-3-STA.pcap========
#
# <Setup-C-3-STA.pcap: TCP:0 UDP:33 ICMP:0 Other:8>
# ['.', 'captures_IoT-Sentinel', 'EdimaxCam1', 'Setup-C-5-STA.pcap']
#
#
# ========es_IoT-Sentinel\EdimaxCam1\Setup-C-5-STA.pcap========
#
# <Setup-C-5-STA.pcap: TCP:0 UDP:33 ICMP:0 Other:8>
# ['.', 'captures_IoT-Sentinel', 'EdimaxCam2', 'Setup-A-1-STA.pcap']
#
#
# ========es_IoT-Sentinel\EdimaxCam2\Setup-A-1-STA.pcap========
#
# <Setup-A-1-STA.pcap: TCP:0 UDP:34 ICMP:0 Other:8>
# ['.', 'captures_IoT-Sentinel', 'EdimaxCam2', 'Setup-A-2-STA.pcap']
#
#
# ========es_IoT-Sentinel\EdimaxCam2\Setup-A-2-STA.pcap========
#
# <Setup-A-2-STA.pcap: TCP:0 UDP:34 ICMP:0 Other:8>
# ['.', 'captures_IoT-Sentinel', 'EdimaxCam2', 'Setup-A-3-STA.pcap']
#
#
# ========es_IoT-Sentinel\EdimaxCam2\Setup-A-3-STA.pcap========
#
# <Setup-A-3-STA.pcap: TCP:0 UDP:39 ICMP:0 Other:13>
# ['.', 'captures_IoT-Sentinel', 'EdimaxCam2', 'Setup-C-1-STA.pcap']
#
#
# ========es_IoT-Sentinel\EdimaxCam2\Setup-C-1-STA.pcap========
#
# <Setup-C-1-STA.pcap: TCP:0 UDP:37 ICMP:0 Other:8>
# ['.', 'captures_IoT-Sentinel', 'EdimaxCam2', 'Setup-C-2-STA.pcap']
#
#
# ========es_IoT-Sentinel\EdimaxCam2\Setup-C-2-STA.pcap========
#
# <Setup-C-2-STA.pcap: TCP:0 UDP:39 ICMP:0 Other:16>
# ['.', 'captures_IoT-Sentinel', 'EdimaxCam2', 'Setup-C-3-STA.pcap']
#
#
# ========es_IoT-Sentinel\EdimaxCam2\Setup-C-3-STA.pcap========
#
# <Setup-C-3-STA.pcap: TCP:0 UDP:33 ICMP:0 Other:9>
# ['.', 'captures_IoT-Sentinel', 'EdimaxCam2', 'Setup-C-4-STA.pcap']
#
#
# ========es_IoT-Sentinel\EdimaxCam2\Setup-C-4-STA.pcap========
#
# <Setup-C-4-STA.pcap: TCP:0 UDP:39 ICMP:0 Other:13>
# ['.', 'captures_IoT-Sentinel', 'EdimaxPlug1101W', 'Setup-A-2-STA.pcap']
#
#
# ========es_IoT-Sentinel\EdimaxPlug1101W\Setup-A-2-STA.pcap========
#
# <Setup-A-2-STA.pcap: TCP:41 UDP:40 ICMP:0 Other:10>
# ['.', 'captures_IoT-Sentinel', 'EdimaxPlug1101W', 'Setup-A-3-STA.pcap']
#
#
# ========es_IoT-Sentinel\EdimaxPlug1101W\Setup-A-3-STA.pcap========
#
# <Setup-A-3-STA.pcap: TCP:17 UDP:19 ICMP:0 Other:10>
# ['.', 'captures_IoT-Sentinel', 'EdimaxPlug1101W', 'Setup-A-4-STA.pcap']
#
#
# ========es_IoT-Sentinel\EdimaxPlug1101W\Setup-A-4-STA.pcap========
#
# <Setup-A-4-STA.pcap: TCP:41 UDP:39 ICMP:0 Other:10>
# ['.', 'captures_IoT-Sentinel', 'EdimaxPlug1101W', 'Setup-A-5-STA.pcap']
#
#
# ========es_IoT-Sentinel\EdimaxPlug1101W\Setup-A-5-STA.pcap========
#
# <Setup-A-5-STA.pcap: TCP:29 UDP:30 ICMP:0 Other:12>
# ['.', 'captures_IoT-Sentinel', 'EdimaxPlug1101W', 'Setup-C-10-STA.pcap']
#
#
# ========es_IoT-Sentinel\EdimaxPlug1101W\Setup-C-10-STA.pcap========
#
# <Setup-C-10-STA.pcap: TCP:30 UDP:34 ICMP:0 Other:10>
# ['.', 'captures_IoT-Sentinel', 'EdimaxPlug1101W', 'Setup-C-11-STA.pcap']
#
#
# ========es_IoT-Sentinel\EdimaxPlug1101W\Setup-C-11-STA.pcap========
#
# <Setup-C-11-STA.pcap: TCP:30 UDP:30 ICMP:0 Other:12>
# ['.', 'captures_IoT-Sentinel', 'EdimaxPlug1101W', 'Setup-C-12-STA.pcap']
#
#
# ========es_IoT-Sentinel\EdimaxPlug1101W\Setup-C-12-STA.pcap========
#
# <Setup-C-12-STA.pcap: TCP:29 UDP:30 ICMP:0 Other:12>
# ['.', 'captures_IoT-Sentinel', 'EdimaxPlug1101W', 'Setup-C-13-STA.pcap']
#
#
# ========es_IoT-Sentinel\EdimaxPlug1101W\Setup-C-13-STA.pcap========
#
# <Setup-C-13-STA.pcap: TCP:28 UDP:30 ICMP:0 Other:12>
# ['.', 'captures_IoT-Sentinel', 'EdimaxPlug1101W', 'Setup-C-15-STA.pcap']
#
#
# ========es_IoT-Sentinel\EdimaxPlug1101W\Setup-C-15-STA.pcap========
#
# <Setup-C-15-STA.pcap: TCP:20 UDP:20 ICMP:1 Other:15>
# ['.', 'captures_IoT-Sentinel', 'EdimaxPlug1101W', 'Setup-C-2-STA.pcap']
#
#
# ========es_IoT-Sentinel\EdimaxPlug1101W\Setup-C-2-STA.pcap========
#
# <Setup-C-2-STA.pcap: TCP:69 UDP:67 ICMP:1 Other:22>
# ['.', 'captures_IoT-Sentinel', 'EdimaxPlug1101W', 'Setup-C-3-STA.pcap']
#
#
# ========es_IoT-Sentinel\EdimaxPlug1101W\Setup-C-3-STA.pcap========
#
# <Setup-C-3-STA.pcap: TCP:57 UDP:44 ICMP:0 Other:18>
# ['.', 'captures_IoT-Sentinel', 'EdimaxPlug1101W', 'Setup-C-4-STA.pcap']
#
#
# ========es_IoT-Sentinel\EdimaxPlug1101W\Setup-C-4-STA.pcap========
#
# <Setup-C-4-STA.pcap: TCP:64 UDP:72 ICMP:0 Other:21>
# ['.', 'captures_IoT-Sentinel', 'EdimaxPlug1101W', 'Setup-C-6-STA.pcap']
#
#
# ========es_IoT-Sentinel\EdimaxPlug1101W\Setup-C-6-STA.pcap========
#
# <Setup-C-6-STA.pcap: TCP:34 UDP:32 ICMP:1 Other:10>
# ['.', 'captures_IoT-Sentinel', 'EdimaxPlug1101W', 'Setup-C-7-STA.pcap']
#
#
# ========es_IoT-Sentinel\EdimaxPlug1101W\Setup-C-7-STA.pcap========
#
# <Setup-C-7-STA.pcap: TCP:30 UDP:31 ICMP:0 Other:12>
# ['.', 'captures_IoT-Sentinel', 'EdimaxPlug1101W', 'Setup-C-8-STA.pcap']
#
#
# ========es_IoT-Sentinel\EdimaxPlug1101W\Setup-C-8-STA.pcap========
#
# <Setup-C-8-STA.pcap: TCP:31 UDP:30 ICMP:0 Other:13>
# ['.', 'captures_IoT-Sentinel', 'EdimaxPlug1101W', 'Setup-C-9-STA.pcap']
#
#
# ========es_IoT-Sentinel\EdimaxPlug1101W\Setup-C-9-STA.pcap========
#
# <Setup-C-9-STA.pcap: TCP:28 UDP:30 ICMP:0 Other:15>
# ['.', 'captures_IoT-Sentinel', 'EdimaxPlug2101W', 'Setup-A-2-STA.pcap']
#
#
# ========es_IoT-Sentinel\EdimaxPlug2101W\Setup-A-2-STA.pcap========
#
# <Setup-A-2-STA.pcap: TCP:17 UDP:24 ICMP:1 Other:17>
# ['.', 'captures_IoT-Sentinel', 'EdimaxPlug2101W', 'Setup-A-3-STA.pcap']
# ========es_IoT-Sentinel\EdimaxPlug2101W\Setup-A-3-STA.pcap========
#
# <Setup-A-3-STA.pcap: TCP:18 UDP:24 ICMP:0 Other:17>
# ['.', 'captures_IoT-Sentinel', 'EdimaxPlug2101W', 'Setup-A-4-STA.pcap']
#
#
# ========es_IoT-Sentinel\EdimaxPlug2101W\Setup-A-4-STA.pcap========
#
# <Setup-A-4-STA.pcap: TCP:18 UDP:24 ICMP:0 Other:17>
# ['.', 'captures_IoT-Sentinel', 'EdimaxPlug2101W', 'Setup-A-5-STA.pcap']
#
#
# ========es_IoT-Sentinel\EdimaxPlug2101W\Setup-A-5-STA.pcap========
#
# <Setup-A-5-STA.pcap: TCP:17 UDP:25 ICMP:0 Other:17>
# ['.', 'captures_IoT-Sentinel', 'EdimaxPlug2101W', 'Setup-C-10-STA.pcap']
#
#
# ========es_IoT-Sentinel\EdimaxPlug2101W\Setup-C-10-STA.pcap========
#
# <Setup-C-10-STA.pcap: TCP:31 UDP:30 ICMP:0 Other:16>
# ['.', 'captures_IoT-Sentinel', 'EdimaxPlug2101W', 'Setup-C-11-STA.pcap']
#
#
# ========es_IoT-Sentinel\EdimaxPlug2101W\Setup-C-11-STA.pcap========
#
# <Setup-C-11-STA.pcap: TCP:26 UDP:31 ICMP:0 Other:14>
# ['.', 'captures_IoT-Sentinel', 'EdimaxPlug2101W', 'Setup-C-12-STA.pcap']
#
#
# ========es_IoT-Sentinel\EdimaxPlug2101W\Setup-C-12-STA.pcap========
#
# <Setup-C-12-STA.pcap: TCP:31 UDP:31 ICMP:0 Other:16>
# ['.', 'captures_IoT-Sentinel', 'EdimaxPlug2101W', 'Setup-C-13-STA.pcap']
#
#
# ========es_IoT-Sentinel\EdimaxPlug2101W\Setup-C-13-STA.pcap========
#
# <Setup-C-13-STA.pcap: TCP:29 UDP:30 ICMP:0 Other:17>
# ['.', 'captures_IoT-Sentinel', 'EdimaxPlug2101W', 'Setup-C-15-STA.pcap']
#
#
# ========es_IoT-Sentinel\EdimaxPlug2101W\Setup-C-15-STA.pcap========
#
# <Setup-C-15-STA.pcap: TCP:29 UDP:30 ICMP:0 Other:16>
# ['.', 'captures_IoT-Sentinel', 'EdimaxPlug2101W', 'Setup-C-2-STA.pcap']
#
#
# ========es_IoT-Sentinel\EdimaxPlug2101W\Setup-C-2-STA.pcap========
#
# <Setup-C-2-STA.pcap: TCP:32 UDP:47 ICMP:1 Other:25>
# ['.', 'captures_IoT-Sentinel', 'EdimaxPlug2101W', 'Setup-C-3-STA.pcap']
#
#
# ========es_IoT-Sentinel\EdimaxPlug2101W\Setup-C-3-STA.pcap========
#
# <Setup-C-3-STA.pcap: TCP:46 UDP:58 ICMP:0 Other:20>
# ['.', 'captures_IoT-Sentinel', 'EdimaxPlug2101W', 'Setup-C-4-STA.pcap']
#
#
# ========es_IoT-Sentinel\EdimaxPlug2101W\Setup-C-4-STA.pcap========
#
# <Setup-C-4-STA.pcap: TCP:48 UDP:46 ICMP:0 Other:23>
# ['.', 'captures_IoT-Sentinel', 'EdimaxPlug2101W', 'Setup-C-6-STA.pcap']
#
#
# ========es_IoT-Sentinel\EdimaxPlug2101W\Setup-C-6-STA.pcap========
#
# <Setup-C-6-STA.pcap: TCP:24 UDP:30 ICMP:2 Other:14>
# ['.', 'captures_IoT-Sentinel', 'EdimaxPlug2101W', 'Setup-C-7-STA.pcap']
#
#
# ========es_IoT-Sentinel\EdimaxPlug2101W\Setup-C-7-STA.pcap========
#
# <Setup-C-7-STA.pcap: TCP:31 UDP:30 ICMP:0 Other:14>
# ['.', 'captures_IoT-Sentinel', 'EdimaxPlug2101W', 'Setup-C-8-STA.pcap']
#
#
# ========es_IoT-Sentinel\EdimaxPlug2101W\Setup-C-8-STA.pcap========
#
# <Setup-C-8-STA.pcap: TCP:33 UDP:32 ICMP:0 Other:14>
# ['.', 'captures_IoT-Sentinel', 'EdimaxPlug2101W', 'Setup-C-9-STA.pcap']
#
#
# ========es_IoT-Sentinel\EdimaxPlug2101W\Setup-C-9-STA.pcap========
#
# <Setup-C-9-STA.pcap: TCP:29 UDP:31 ICMP:0 Other:15>
# ['.', 'captures_IoT-Sentinel', 'EdnetCam1', 'Setup-C-1-STA.pcap']
#
#
# ========es_IoT-Sentinel\EdnetCam1\Setup-C-1-STA.pcap========
#
# <Setup-C-1-STA.pcap: TCP:0 UDP:12 ICMP:0 Other:7>
# ['.', 'captures_IoT-Sentinel', 'EdnetCam1', 'Setup-C-10-STA.pcap']
#
#
# ========es_IoT-Sentinel\EdnetCam1\Setup-C-10-STA.pcap========
#
# <Setup-C-10-STA.pcap: TCP:0 UDP:13 ICMP:0 Other:7>
# ['.', 'captures_IoT-Sentinel', 'EdnetCam1', 'Setup-C-2-STA.pcap']
#
#
# ========es_IoT-Sentinel\EdnetCam1\Setup-C-2-STA.pcap========
#
# <Setup-C-2-STA.pcap: TCP:0 UDP:16 ICMP:0 Other:7>
# ['.', 'captures_IoT-Sentinel', 'EdnetCam1', 'Setup-C-3-STA.pcap']
#
#
# ========es_IoT-Sentinel\EdnetCam1\Setup-C-3-STA.pcap========
#
# <Setup-C-3-STA.pcap: TCP:0 UDP:16 ICMP:0 Other:7>
# ['.', 'captures_IoT-Sentinel', 'EdnetCam1', 'Setup-C-5-STA.pcap']
#
#
# ========es_IoT-Sentinel\EdnetCam1\Setup-C-5-STA.pcap========
#
# <Setup-C-5-STA.pcap: TCP:0 UDP:16 ICMP:0 Other:10>
# ['.', 'captures_IoT-Sentinel', 'EdnetCam1', 'Setup-C-6-STA.pcap']
#
#
# ========es_IoT-Sentinel\EdnetCam1\Setup-C-6-STA.pcap========
#
# <Setup-C-6-STA.pcap: TCP:0 UDP:12 ICMP:0 Other:5>
# ['.', 'captures_IoT-Sentinel', 'EdnetCam1', 'Setup-C-7-STA.pcap']
#
#
# ========es_IoT-Sentinel\EdnetCam1\Setup-C-7-STA.pcap========
#
# <Setup-C-7-STA.pcap: TCP:0 UDP:14 ICMP:0 Other:10>
# ['.', 'captures_IoT-Sentinel', 'EdnetCam1', 'Setup-C-8-STA.pcap']
#
#
# ========es_IoT-Sentinel\EdnetCam1\Setup-C-8-STA.pcap========
#
# <Setup-C-8-STA.pcap: TCP:0 UDP:15 ICMP:0 Other:7>
# ['.', 'captures_IoT-Sentinel', 'EdnetCam2', 'Setup-A-1-STA.pcap']
#
#
# ========es_IoT-Sentinel\EdnetCam2\Setup-A-1-STA.pcap========
#
# <Setup-A-1-STA.pcap: TCP:0 UDP:15 ICMP:0 Other:7>
# ['.', 'captures_IoT-Sentinel', 'EdnetCam2', 'Setup-C-1-STA.pcap']
#
#
# ========es_IoT-Sentinel\EdnetCam2\Setup-C-1-STA.pcap========
#
# <Setup-C-1-STA.pcap: TCP:0 UDP:15 ICMP:0 Other:6>
# ['.', 'captures_IoT-Sentinel', 'EdnetCam2', 'Setup-C-2-STA.pcap']
#
#
# ========es_IoT-Sentinel\EdnetCam2\Setup-C-2-STA.pcap========
#
# <Setup-C-2-STA.pcap: TCP:0 UDP:15 ICMP:0 Other:9>
# ['.', 'captures_IoT-Sentinel', 'EdnetCam2', 'Setup-C-3-STA.pcap']
#
#
# ========es_IoT-Sentinel\EdnetCam2\Setup-C-3-STA.pcap========
#
# <Setup-C-3-STA.pcap: TCP:0 UDP:16 ICMP:0 Other:22>
# ['.', 'captures_IoT-Sentinel', 'EdnetCam2', 'Setup-C-5-STA.pcap']
#
#
# ========es_IoT-Sentinel\EdnetCam2\Setup-C-5-STA.pcap========
#
# <Setup-C-5-STA.pcap: TCP:0 UDP:16 ICMP:0 Other:9>
# ['.', 'captures_IoT-Sentinel', 'EdnetCam2', 'Setup-C-6-STA.pcap']
#
#
# ========es_IoT-Sentinel\EdnetCam2\Setup-C-6-STA.pcap========
#
# <Setup-C-6-STA.pcap: TCP:0 UDP:14 ICMP:1 Other:10>
# ['.', 'captures_IoT-Sentinel', 'EdnetCam2', 'Setup-C-7-STA.pcap']
#
#
# ========es_IoT-Sentinel\EdnetCam2\Setup-C-7-STA.pcap========
#
# <Setup-C-7-STA.pcap: TCP:0 UDP:14 ICMP:0 Other:10>
# ['.', 'captures_IoT-Sentinel', 'EdnetCam2', 'Setup-C-8-STA.pcap']
#
#
# ========es_IoT-Sentinel\EdnetCam2\Setup-C-8-STA.pcap========
#
# <Setup-C-8-STA.pcap: TCP:0 UDP:5 ICMP:0 Other:8>
# ['.', 'captures_IoT-Sentinel', 'EdnetGateway', 'Setup-A-2-STA.pcap']
#
#
# ========es_IoT-Sentinel\EdnetGateway\Setup-A-2-STA.pcap========
#
# <Setup-A-2-STA.pcap: TCP:35 UDP:24 ICMP:6 Other:18>
# ['.', 'captures_IoT-Sentinel', 'EdnetGateway', 'Setup-C-1-STA.pcap']
#
#
# ========es_IoT-Sentinel\EdnetGateway\Setup-C-1-STA.pcap========
#
# <Setup-C-1-STA.pcap: TCP:32 UDP:22 ICMP:4 Other:16>
# ['.', 'captures_IoT-Sentinel', 'EdnetGateway', 'Setup-C-10-STA.pcap']
#
#
# ========es_IoT-Sentinel\EdnetGateway\Setup-C-10-STA.pcap========
#
# <Setup-C-10-STA.pcap: TCP:31 UDP:21 ICMP:3 Other:10>
# ['.', 'captures_IoT-Sentinel', 'EdnetGateway', 'Setup-C-11-STA.pcap']
#
#
# ========es_IoT-Sentinel\EdnetGateway\Setup-C-11-STA.pcap========
#
# <Setup-C-11-STA.pcap: TCP:30 UDP:22 ICMP:3 Other:12>
# ['.', 'captures_IoT-Sentinel', 'EdnetGateway', 'Setup-C-13-STA.pcap']
#
#
# ========es_IoT-Sentinel\EdnetGateway\Setup-C-13-STA.pcap========
#
# <Setup-C-13-STA.pcap: TCP:30 UDP:23 ICMP:5 Other:10>
# ['.', 'captures_IoT-Sentinel', 'EdnetGateway', 'Setup-C-14-STA.pcap']
#
#
# ========es_IoT-Sentinel\EdnetGateway\Setup-C-14-STA.pcap========
#
# <Setup-C-14-STA.pcap: TCP:31 UDP:23 ICMP:4 Other:32>
# ['.', 'captures_IoT-Sentinel', 'EdnetGateway', 'Setup-C-15-STA.pcap']
#
#
# ========es_IoT-Sentinel\EdnetGateway\Setup-C-15-STA.pcap========
#
# <Setup-C-15-STA.pcap: TCP:29 UDP:22 ICMP:3 Other:10>
# ['.', 'captures_IoT-Sentinel', 'EdnetGateway', 'Setup-C-16-STA.pcap']
#
#
# ========es_IoT-Sentinel\EdnetGateway\Setup-C-16-STA.pcap========
#
# <Setup-C-16-STA.pcap: TCP:42 UDP:23 ICMP:4 Other:28>
# ['.', 'captures_IoT-Sentinel', 'EdnetGateway', 'Setup-C-18-STA.pcap']
#
#
# ========es_IoT-Sentinel\EdnetGateway\Setup-C-18-STA.pcap========
#
# <Setup-C-18-STA.pcap: TCP:29 UDP:23 ICMP:4 Other:10>
# ['.', 'captures_IoT-Sentinel', 'EdnetGateway', 'Setup-C-2-STA.pcap']
#
#
# ========es_IoT-Sentinel\EdnetGateway\Setup-C-2-STA.pcap========
#
# <Setup-C-2-STA.pcap: TCP:29 UDP:22 ICMP:3 Other:12>
# ['.', 'captures_IoT-Sentinel', 'EdnetGateway', 'Setup-C-3-STA.pcap']
#
#
# ========es_IoT-Sentinel\EdnetGateway\Setup-C-3-STA.pcap========
#
# <Setup-C-3-STA.pcap: TCP:29 UDP:23 ICMP:4 Other:12>
# ['.', 'captures_IoT-Sentinel', 'EdnetGateway', 'Setup-C-4-STA.pcap']
#
#
# ========es_IoT-Sentinel\EdnetGateway\Setup-C-4-STA.pcap========
#
# <Setup-C-4-STA.pcap: TCP:29 UDP:22 ICMP:1 Other:12>
# ['.', 'captures_IoT-Sentinel', 'EdnetGateway', 'Setup-C-6-STA.pcap']
#
#
# ========es_IoT-Sentinel\EdnetGateway\Setup-C-6-STA.pcap========
#
# <Setup-C-6-STA.pcap: TCP:32 UDP:23 ICMP:4 Other:15>
# ['.', 'captures_IoT-Sentinel', 'EdnetGateway', 'Setup-C-7-STA.pcap']
#
#
# ========es_IoT-Sentinel\EdnetGateway\Setup-C-7-STA.pcap========
#
# <Setup-C-7-STA.pcap: TCP:29 UDP:22 ICMP:4 Other:12>
# ['.', 'captures_IoT-Sentinel', 'EdnetGateway', 'Setup-C-8-STA.pcap']
#
#
# ========es_IoT-Sentinel\EdnetGateway\Setup-C-8-STA.pcap========
#
# <Setup-C-8-STA.pcap: TCP:27 UDP:23 ICMP:5 Other:12>
# ['.', 'captures_IoT-Sentinel', 'EdnetGateway', 'Setup-C-9-STA.pcap']
#
#
# ========es_IoT-Sentinel\EdnetGateway\Setup-C-9-STA.pcap========
#
# <Setup-C-9-STA.pcap: TCP:29 UDP:23 ICMP:4 Other:10>
# ['.', 'captures_IoT-Sentinel', 'HomeMaticPlug', 'Setup-C-10-STA.pcap']
#
#
# ========es_IoT-Sentinel\HomeMaticPlug\Setup-C-10-STA.pcap========
#
# <Setup-C-10-STA.pcap: TCP:25 UDP:0 ICMP:0 Other:0>
# ['.', 'captures_IoT-Sentinel', 'HomeMaticPlug', 'Setup-C-11-STA.pcap']
#
#
# ========es_IoT-Sentinel\HomeMaticPlug\Setup-C-11-STA.pcap========
#
# <Setup-C-11-STA.pcap: TCP:31 UDP:0 ICMP:0 Other:4>
# ['.', 'captures_IoT-Sentinel', 'HomeMaticPlug', 'Setup-C-12-STA.pcap']
#
#
# ========es_IoT-Sentinel\HomeMaticPlug\Setup-C-12-STA.pcap========
#
# <Setup-C-12-STA.pcap: TCP:34 UDP:0 ICMP:0 Other:2>
# ['.', 'captures_IoT-Sentinel', 'HomeMaticPlug', 'Setup-C-13-STA.pcap']
#
#
# ========es_IoT-Sentinel\HomeMaticPlug\Setup-C-13-STA.pcap========
#
# <Setup-C-13-STA.pcap: TCP:29 UDP:0 ICMP:0 Other:2>
# ['.', 'captures_IoT-Sentinel', 'HomeMaticPlug', 'Setup-C-15-STA.pcap']
#
#
# ========es_IoT-Sentinel\HomeMaticPlug\Setup-C-15-STA.pcap========
#
# <Setup-C-15-STA.pcap: TCP:26 UDP:0 ICMP:0 Other:1>
# ['.', 'captures_IoT-Sentinel', 'HomeMaticPlug', 'Setup-C-16-STA.pcap']
#
#
# ========es_IoT-Sentinel\HomeMaticPlug\Setup-C-16-STA.pcap========
#
# <Setup-C-16-STA.pcap: TCP:25 UDP:0 ICMP:0 Other:2>
# ['.', 'captures_IoT-Sentinel', 'HomeMaticPlug', 'Setup-C-17-STA.pcap']
#
#
# ========es_IoT-Sentinel\HomeMaticPlug\Setup-C-17-STA.pcap========
#
# <Setup-C-17-STA.pcap: TCP:30 UDP:0 ICMP:0 Other:4>
# ['.', 'captures_IoT-Sentinel', 'HomeMaticPlug', 'Setup-C-18-STA.pcap']
#
#
# ========es_IoT-Sentinel\HomeMaticPlug\Setup-C-18-STA.pcap========
#
# <Setup-C-18-STA.pcap: TCP:25 UDP:0 ICMP:0 Other:2>
# ['.', 'captures_IoT-Sentinel', 'HomeMaticPlug', 'Setup-C-2-STA.pcap']
#
#
# ========es_IoT-Sentinel\HomeMaticPlug\Setup-C-2-STA.pcap========
#
# <Setup-C-2-STA.pcap: TCP:44 UDP:0 ICMP:0 Other:8>
# ['.', 'captures_IoT-Sentinel', 'HomeMaticPlug', 'Setup-C-20-STA.pcap']
#
#
# ========es_IoT-Sentinel\HomeMaticPlug\Setup-C-20-STA.pcap========
#
# <Setup-C-20-STA.pcap: TCP:35 UDP:0 ICMP:0 Other:2>
# ['.', 'captures_IoT-Sentinel', 'HomeMaticPlug', 'Setup-C-3-STA.pcap']
#
#
# ========es_IoT-Sentinel\HomeMaticPlug\Setup-C-3-STA.pcap========
#
# <Setup-C-3-STA.pcap: TCP:83 UDP:0 ICMP:0 Other:2>
# ['.', 'captures_IoT-Sentinel', 'HomeMaticPlug', 'Setup-C-4-STA.pcap']
#
#
# ========es_IoT-Sentinel\HomeMaticPlug\Setup-C-4-STA.pcap========
#
# <Setup-C-4-STA.pcap: TCP:88 UDP:0 ICMP:0 Other:6>
# ['.', 'captures_IoT-Sentinel', 'HomeMaticPlug', 'Setup-C-6-STA.pcap']
#
#
# ========es_IoT-Sentinel\HomeMaticPlug\Setup-C-6-STA.pcap========
#
# <Setup-C-6-STA.pcap: TCP:89 UDP:0 ICMP:0 Other:4>
# ['.', 'captures_IoT-Sentinel', 'HomeMaticPlug', 'Setup-C-7-STA.pcap']
#
#
# ========es_IoT-Sentinel\HomeMaticPlug\Setup-C-7-STA.pcap========
#
# <Setup-C-7-STA.pcap: TCP:94 UDP:0 ICMP:0 Other:4>
# ['.', 'captures_IoT-Sentinel', 'HomeMaticPlug', 'Setup-C-8-STA.pcap']
#
#
# ========es_IoT-Sentinel\HomeMaticPlug\Setup-C-8-STA.pcap========
#
# <Setup-C-8-STA.pcap: TCP:105 UDP:0 ICMP:0 Other:2>
# ['.', 'captures_IoT-Sentinel', 'HomeMaticPlug', 'Setup-C-9-STA.pcap']
#
#
# ========es_IoT-Sentinel\HomeMaticPlug\Setup-C-9-STA.pcap========
#
# <Setup-C-9-STA.pcap: TCP:87 UDP:0 ICMP:0 Other:2>
# ['.', 'captures_IoT-Sentinel', 'HueBridge', 'Setup-A-2-STA.pcap']
#
#
# ========es_IoT-Sentinel\HueBridge\Setup-A-2-STA.pcap========
#
# <Setup-A-2-STA.pcap: TCP:1264 UDP:260 ICMP:3 Other:30>
# ['.', 'captures_IoT-Sentinel', 'HueBridge', 'Setup-A-3-STA.pcap']
#
#
# ========es_IoT-Sentinel\HueBridge\Setup-A-3-STA.pcap========
#
# <Setup-A-3-STA.pcap: TCP:1155 UDP:224 ICMP:3 Other:41>
# ['.', 'captures_IoT-Sentinel', 'HueBridge', 'Setup-A-4-STA.pcap']
#
#
# ========es_IoT-Sentinel\HueBridge\Setup-A-4-STA.pcap========
#
# <Setup-A-4-STA.pcap: TCP:1111 UDP:218 ICMP:3 Other:36>
# ['.', 'captures_IoT-Sentinel', 'HueBridge', 'Setup-A-5-STA.pcap']
#
#
# ========es_IoT-Sentinel\HueBridge\Setup-A-5-STA.pcap========
#
# <Setup-A-5-STA.pcap: TCP:1083 UDP:220 ICMP:3 Other:37>
# ['.', 'captures_IoT-Sentinel', 'HueBridge', 'Setup-C-10-STA.pcap']
#
#
# ========es_IoT-Sentinel\HueBridge\Setup-C-10-STA.pcap========
#
# <Setup-C-10-STA.pcap: TCP:1101 UDP:212 ICMP:3 Other:35>
# ['.', 'captures_IoT-Sentinel', 'HueBridge', 'Setup-C-11-STA.pcap']
#
#
# ========es_IoT-Sentinel\HueBridge\Setup-C-11-STA.pcap========
#
# <Setup-C-11-STA.pcap: TCP:1095 UDP:204 ICMP:3 Other:31>
# ['.', 'captures_IoT-Sentinel', 'HueBridge', 'Setup-C-12-STA.pcap']
#
#
# ========es_IoT-Sentinel\HueBridge\Setup-C-12-STA.pcap========
#
# <Setup-C-12-STA.pcap: TCP:989 UDP:212 ICMP:3 Other:33>
# ['.', 'captures_IoT-Sentinel', 'HueBridge', 'Setup-C-13-STA.pcap']
#
#
# ========es_IoT-Sentinel\HueBridge\Setup-C-13-STA.pcap========
#
# <Setup-C-13-STA.pcap: TCP:1072 UDP:212 ICMP:3 Other:29>
# ['.', 'captures_IoT-Sentinel', 'HueBridge', 'Setup-C-15-STA.pcap']
#
#
# ========es_IoT-Sentinel\HueBridge\Setup-C-15-STA.pcap========
#
# <Setup-C-15-STA.pcap: TCP:1046 UDP:208 ICMP:3 Other:28>
# ['.', 'captures_IoT-Sentinel', 'HueBridge', 'Setup-C-2-STA.pcap']
#
#
# ========es_IoT-Sentinel\HueBridge\Setup-C-2-STA.pcap========
#
# <Setup-C-2-STA.pcap: TCP:1030 UDP:204 ICMP:3 Other:29>
# ['.', 'captures_IoT-Sentinel', 'HueBridge', 'Setup-C-3-STA.pcap']
#
#
# ========es_IoT-Sentinel\HueBridge\Setup-C-3-STA.pcap========
#
# <Setup-C-3-STA.pcap: TCP:1072 UDP:214 ICMP:4 Other:29>
# ['.', 'captures_IoT-Sentinel', 'HueBridge', 'Setup-C-4-STA.pcap']
#
#
# ========es_IoT-Sentinel\HueBridge\Setup-C-4-STA.pcap========
#
# <Setup-C-4-STA.pcap: TCP:1108 UDP:224 ICMP:3 Other:31>
# ['.', 'captures_IoT-Sentinel', 'HueBridge', 'Setup-C-6-STA.pcap']
#
#
# ========es_IoT-Sentinel\HueBridge\Setup-C-6-STA.pcap========
#
# <Setup-C-6-STA.pcap: TCP:1073 UDP:212 ICMP:3 Other:31>
# ['.', 'captures_IoT-Sentinel', 'HueBridge', 'Setup-C-7-STA.pcap']
#
#
# ========es_IoT-Sentinel\HueBridge\Setup-C-7-STA.pcap========
#
# <Setup-C-7-STA.pcap: TCP:1096 UDP:212 ICMP:3 Other:27>
# ...
# ['.', 'captures_IoT-Sentinel', 'D-LinkSiren', 'Setup-C-13-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkSiren\Setup-C-13-STA.pcap========
#
# <Setup-C-13-STA.pcap: TCP:470 UDP:105 ICMP:0 Other:30>
# ['.', 'captures_IoT-Sentinel', 'D-LinkSiren', 'Setup-C-18-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkSiren\Setup-C-18-STA.pcap========
#
# <Setup-C-18-STA.pcap: TCP:465 UDP:96 ICMP:0 Other:23>
# ['.', 'captures_IoT-Sentinel', 'D-LinkSiren', 'Setup-C-5-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkSiren\Setup-C-5-STA.pcap========
#
# <Setup-C-5-STA.pcap: TCP:465 UDP:102 ICMP:0 Other:31>
# ['.', 'captures_IoT-Sentinel', 'D-LinkSwitch', 'Setup-A-1-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkSwitch\Setup-A-1-STA.pcap========
#
# <Setup-A-1-STA.pcap: TCP:534 UDP:83 ICMP:0 Other:20>
# ['.', 'captures_IoT-Sentinel', 'D-LinkSwitch', 'Setup-C-1-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkSwitch\Setup-C-1-STA.pcap========
#
# <Setup-C-1-STA.pcap: TCP:552 UDP:99 ICMP:0 Other:36>
# ['.', 'captures_IoT-Sentinel', 'D-LinkSwitch', 'Setup-C-14-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkSwitch\Setup-C-14-STA.pcap========
#
# <Setup-C-14-STA.pcap: TCP:472 UDP:80 ICMP:0 Other:29>
# ['.', 'captures_IoT-Sentinel', 'D-LinkSwitch', 'Setup-C-5-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkSwitch\Setup-C-5-STA.pcap========
#
# <Setup-C-5-STA.pcap: TCP:627 UDP:76 ICMP:0 Other:23>
# ['.', 'captures_IoT-Sentinel', 'D-LinkWaterSensor', 'Setup-A-1-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkWaterSensor\Setup-A-1-STA.pcap========
#
# <Setup-A-1-STA.pcap: TCP:444 UDP:120 ICMP:0 Other:29>
# ['.', 'captures_IoT-Sentinel', 'D-LinkWaterSensor', 'Setup-C-13-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkWaterSensor\Setup-C-13-STA.pcap========
#
# <Setup-C-13-STA.pcap: TCP:464 UDP:110 ICMP:0 Other:30>
# ['.', 'captures_IoT-Sentinel', 'D-LinkWaterSensor', 'Setup-C-18-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkWaterSensor\Setup-C-18-STA.pcap========
#
# <Setup-C-18-STA.pcap: TCP:464 UDP:107 ICMP:0 Other:20>
# ['.', 'captures_IoT-Sentinel', 'D-LinkWaterSensor', 'Setup-C-5-STA.pcap']
#
#
# ========es_IoT-Sentinel\D-LinkWaterSensor\Setup-C-5-STA.pcap========
#
# <Setup-C-5-STA.pcap: TCP:460 UDP:110 ICMP:0 Other:17>
# ['.', 'captures_IoT-Sentinel', 'EdimaxCam1', 'Setup-A-1-STA.pcap']
#
#
# ========es_IoT-Sentinel\EdimaxCam1\Setup-A-1-STA.pcap========
#
# <Setup-A-1-STA.pcap: TCP:0 UDP:41 ICMP:0 Other:8>
# ['.', 'captures_IoT-Sentinel', 'EdimaxCam1', 'Setup-A-6-STA.pcap']
#
#
# ========es_IoT-Sentinel\EdimaxCam1\Setup-A-6-STA.pcap========
#
# <Setup-A-6-STA.pcap: TCP:0 UDP:33 ICMP:0 Other:7>
# ['.', 'captures_IoT-Sentinel', 'EdimaxCam1', 'Setup-C-4-STA.pcap']
#
#
# ========es_IoT-Sentinel\EdimaxCam1\Setup-C-4-STA.pcap========
#
# <Setup-C-4-STA.pcap: TCP:0 UDP:38 ICMP:0 Other:8>
# ['.', 'captures_IoT-Sentinel', 'EdimaxCam2', 'Setup-A-4-STA.pcap']
#
#
# ========es_IoT-Sentinel\EdimaxCam2\Setup-A-4-STA.pcap========
#
# <Setup-A-4-STA.pcap: TCP:0 UDP:33 ICMP:0 Other:8>
# ['.', 'captures_IoT-Sentinel', 'EdimaxPlug1101W', 'Setup-A-1-STA.pcap']
#
#
# ========es_IoT-Sentinel\EdimaxPlug1101W\Setup-A-1-STA.pcap========
#
# <Setup-A-1-STA.pcap: TCP:41 UDP:41 ICMP:0 Other:10>
# ['.', 'captures_IoT-Sentinel', 'EdimaxPlug1101W', 'Setup-C-1-STA.pcap']
#
#
# ========es_IoT-Sentinel\EdimaxPlug1101W\Setup-C-1-STA.pcap========
#
# <Setup-C-1-STA.pcap: TCP:37 UDP:33 ICMP:0 Other:14>
# ['.', 'captures_IoT-Sentinel', 'EdimaxPlug1101W', 'Setup-C-14-STA.pcap']
#
#
# ========es_IoT-Sentinel\EdimaxPlug1101W\Setup-C-14-STA.pcap========
#
# <Setup-C-14-STA.pcap: TCP:33 UDP:30 ICMP:0 Other:9>
# ['.', 'captures_IoT-Sentinel', 'EdimaxPlug1101W', 'Setup-C-5-STA.pcap']
#
#
# ========es_IoT-Sentinel\EdimaxPlug1101W\Setup-C-5-STA.pcap========
#
# <Setup-C-5-STA.pcap: TCP:62 UDP:72 ICMP:0 Other:21>
# ['.', 'captures_IoT-Sentinel', 'EdimaxPlug2101W', 'Setup-A-1-STA.pcap']
#
#
# ========es_IoT-Sentinel\EdimaxPlug2101W\Setup-A-1-STA.pcap========
#
# <Setup-A-1-STA.pcap: TCP:24 UDP:23 ICMP:0 Other:18>
# ['.', 'captures_IoT-Sentinel', 'EdimaxPlug2101W', 'Setup-C-1-STA.pcap']
#
#
# ========es_IoT-Sentinel\EdimaxPlug2101W\Setup-C-1-STA.pcap========
#
# <Setup-C-1-STA.pcap: TCP:66 UDP:44 ICMP:0 Other:22>
# ['.', 'captures_IoT-Sentinel', 'EdimaxPlug2101W', 'Setup-C-14-STA.pcap']
#
#
# ========es_IoT-Sentinel\EdimaxPlug2101W\Setup-C-14-STA.pcap========
#
# <Setup-C-14-STA.pcap: TCP:29 UDP:30 ICMP:0 Other:13>
# ['.', 'captures_IoT-Sentinel', 'EdimaxPlug2101W', 'Setup-C-5-STA.pcap']
#
#
# ========es_IoT-Sentinel\EdimaxPlug2101W\Setup-C-5-STA.pcap========
#
# <Setup-C-5-STA.pcap: TCP:50 UDP:58 ICMP:0 Other:22>
# ['.', 'captures_IoT-Sentinel', 'EdnetCam1', 'Setup-A-1-STA.pcap']
#
#
# ========es_IoT-Sentinel\EdnetCam1\Setup-A-1-STA.pcap========
#
# <Setup-A-1-STA.pcap: TCP:0 UDP:14 ICMP:0 Other:7>
# ['.', 'captures_IoT-Sentinel', 'EdnetCam1', 'Setup-C-4-STA.pcap']
#
#
# ========es_IoT-Sentinel\EdnetCam1\Setup-C-4-STA.pcap========
#
# <Setup-C-4-STA.pcap: TCP:0 UDP:16 ICMP:0 Other:7>
# ['.', 'captures_IoT-Sentinel', 'EdnetCam1', 'Setup-C-9-STA.pcap']
#
#
# ========es_IoT-Sentinel\EdnetCam1\Setup-C-9-STA.pcap========
#
# <Setup-C-9-STA.pcap: TCP:0 UDP:13 ICMP:0 Other:10>
# ['.', 'captures_IoT-Sentinel', 'EdnetCam2', 'Setup-C-4-STA.pcap']
#
#
# ========es_IoT-Sentinel\EdnetCam2\Setup-C-4-STA.pcap========
#
# <Setup-C-4-STA.pcap: TCP:0 UDP:14 ICMP:0 Other:6>
# ['.', 'captures_IoT-Sentinel', 'EdnetGateway', 'Setup-A-1-STA.pcap']
#
#
# ========es_IoT-Sentinel\EdnetGateway\Setup-A-1-STA.pcap========
#
# <Setup-A-1-STA.pcap: TCP:30 UDP:23 ICMP:5 Other:12>
# ['.', 'captures_IoT-Sentinel', 'EdnetGateway', 'Setup-C-12-STA.pcap']
# ========es_IoT-Sentinel\EdnetGateway\Setup-C-12-STA.pcap========
#
# <Setup-C-12-STA.pcap: TCP:29 UDP:22 ICMP:4 Other:16>
# ['.', 'captures_IoT-Sentinel', 'EdnetGateway', 'Setup-C-17-STA.pcap']
#
#
# ========es_IoT-Sentinel\EdnetGateway\Setup-C-17-STA.pcap========
#
# <Setup-C-17-STA.pcap: TCP:27 UDP:23 ICMP:4 Other:16>
# ['.', 'captures_IoT-Sentinel', 'EdnetGateway', 'Setup-C-5-STA.pcap']
#
#
# ========es_IoT-Sentinel\EdnetGateway\Setup-C-5-STA.pcap========
#
# <Setup-C-5-STA.pcap: TCP:29 UDP:23 ICMP:4 Other:12>
# ['.', 'captures_IoT-Sentinel', 'HomeMaticPlug', 'Setup-C-1-STA.pcap']
#
#
# ========es_IoT-Sentinel\HomeMaticPlug\Setup-C-1-STA.pcap========
#
# <Setup-C-1-STA.pcap: TCP:34 UDP:0 ICMP:0 Other:4>
# ['.', 'captures_IoT-Sentinel', 'HomeMaticPlug', 'Setup-C-14-STA.pcap']
#
#
# ========es_IoT-Sentinel\HomeMaticPlug\Setup-C-14-STA.pcap========
#
# <Setup-C-14-STA.pcap: TCP:27 UDP:0 ICMP:0 Other:2>
# ['.', 'captures_IoT-Sentinel', 'HomeMaticPlug', 'Setup-C-19-STA.pcap']
#
#
# ========es_IoT-Sentinel\HomeMaticPlug\Setup-C-19-STA.pcap========
#
# <Setup-C-19-STA.pcap: TCP:25 UDP:0 ICMP:0 Other:0>
# ['.', 'captures_IoT-Sentinel', 'HomeMaticPlug', 'Setup-C-5-STA.pcap']
#
#
# ========es_IoT-Sentinel\HomeMaticPlug\Setup-C-5-STA.pcap========
#
# <Setup-C-5-STA.pcap: TCP:88 UDP:0 ICMP:0 Other:4>
# ['.', 'captures_IoT-Sentinel', 'HueBridge', 'Setup-A-1-STA.pcap']
#
#
# ========es_IoT-Sentinel\HueBridge\Setup-A-1-STA.pcap========
#
# <Setup-A-1-STA.pcap: TCP:1244 UDP:228 ICMP:3 Other:38>
# ['.', 'captures_IoT-Sentinel', 'HueBridge', 'Setup-C-1-STA.pcap']
#
#
# ========es_IoT-Sentinel\HueBridge\Setup-C-1-STA.pcap========
#
# <Setup-C-1-STA.pcap: TCP:1082 UDP:216 ICMP:3 Other:29>
# ['.', 'captures_IoT-Sentinel', 'HueBridge', 'Setup-C-14-STA.pcap']
#
#
# ========es_IoT-Sentinel\HueBridge\Setup-C-14-STA.pcap========
#
# <Setup-C-14-STA.pcap: TCP:1060 UDP:214 ICMP:3 Other:32>
# ['.', 'captures_IoT-Sentinel', 'HueBridge', 'Setup-C-5-STA.pcap']
#
#
# ========es_IoT-Sentinel\HueBridge\Setup-C-5-STA.pcap========
#
# <Setup-C-5-STA.pcap: TCP:1201 UDP:212 ICMP:3 Other:31>
# ['.', 'captures_IoT-Sentinel', 'HueSwitch', 'Setup-A-1-STA.pcap']
#
#
# ========es_IoT-Sentinel\HueSwitch\Setup-A-1-STA.pcap========
#
# <Setup-A-1-STA.pcap: TCP:2353 UDP:40 ICMP:0 Other:4>
# ['.', 'captures_IoT-Sentinel', 'HueSwitch', 'Setup-A-5-STA.pcap']
#
#
# ========es_IoT-Sentinel\HueSwitch\Setup-A-5-STA.pcap========
#
# <Setup-A-5-STA.pcap: TCP:1314 UDP:42 ICMP:0 Other:4>
# ['.', 'captures_IoT-Sentinel', 'HueSwitch', 'Setup-C-1-STA.pcap']
#
#
# ========es_IoT-Sentinel\HueSwitch\Setup-C-1-STA.pcap========
#
# <Setup-C-1-STA.pcap: TCP:2206 UDP:24 ICMP:0 Other:0>
# ['.', 'captures_IoT-Sentinel', 'HueSwitch', 'Setup-C-5-STA.pcap']
#
#
# ========es_IoT-Sentinel\HueSwitch\Setup-C-5-STA.pcap========
#
# <Setup-C-5-STA.pcap: TCP:1993 UDP:12 ICMP:0 Other:0>
# ['.', 'captures_IoT-Sentinel', 'iKettle2', 'Setup-A-1-STA.pcap']
#
#
# ========es_IoT-Sentinel\iKettle2\Setup-A-1-STA.pcap========
#
# <Setup-A-1-STA.pcap: TCP:0 UDP:4 ICMP:0 Other:7>
# ['.', 'captures_IoT-Sentinel', 'iKettle2', 'Setup-A-14-STA.pcap']
#
#
# ========es_IoT-Sentinel\iKettle2\Setup-A-14-STA.pcap========
#
# <Setup-A-14-STA.pcap: TCP:0 UDP:4 ICMP:0 Other:8>
# ['.', 'captures_IoT-Sentinel', 'iKettle2', 'Setup-A-5-STA.pcap']
#
#
# ========es_IoT-Sentinel\iKettle2\Setup-A-5-STA.pcap========
#
# <Setup-A-5-STA.pcap: TCP:0 UDP:4 ICMP:0 Other:7>
# ['.', 'captures_IoT-Sentinel', 'iKettle2', 'Setup-C-1-STA.pcap']
#
#
# ========es_IoT-Sentinel\iKettle2\Setup-C-1-STA.pcap========
#
# <Setup-C-1-STA.pcap: TCP:0 UDP:4 ICMP:0 Other:7>
# ['.', 'captures_IoT-Sentinel', 'Lightify', 'Setup-C-1-STA.pcap']
#
#
# ========es_IoT-Sentinel\Lightify\Setup-C-1-STA.pcap========
#
# <Setup-C-1-STA.pcap: TCP:0 UDP:274 ICMP:0 Other:16>
# ['.', 'captures_IoT-Sentinel', 'Lightify', 'Setup-C-14-STA.pcap']
#
#
# ========es_IoT-Sentinel\Lightify\Setup-C-14-STA.pcap========
#
# <Setup-C-14-STA.pcap: TCP:0 UDP:359 ICMP:0 Other:29>
# ['.', 'captures_IoT-Sentinel', 'Lightify', 'Setup-C-19-STA.pcap']
#
#
# ========es_IoT-Sentinel\Lightify\Setup-C-19-STA.pcap========
#
# <Setup-C-19-STA.pcap: TCP:0 UDP:309 ICMP:0 Other:27>
# ['.', 'captures_IoT-Sentinel', 'Lightify', 'Setup-C-5-STA.pcap']
#
#
# ========es_IoT-Sentinel\Lightify\Setup-C-5-STA.pcap========
#
# <Setup-C-5-STA.pcap: TCP:0 UDP:358 ICMP:0 Other:27>
# ['.', 'captures_IoT-Sentinel', 'MAXGateway', 'Setup-A-1-STA.pcap']
#
#
# ========es_IoT-Sentinel\MAXGateway\Setup-A-1-STA.pcap========
#
# <Setup-A-1-STA.pcap: TCP:44 UDP:5 ICMP:0 Other:7>
# ['.', 'captures_IoT-Sentinel', 'MAXGateway', 'Setup-A-6-STA.pcap']
#
#
# ========es_IoT-Sentinel\MAXGateway\Setup-A-6-STA.pcap========
#
# <Setup-A-6-STA.pcap: TCP:60 UDP:6 ICMP:1 Other:10>
# ['.', 'captures_IoT-Sentinel', 'MAXGateway', 'Setup-C-10-STA.pcap']
#
#
# ========es_IoT-Sentinel\MAXGateway\Setup-C-10-STA.pcap========
#
# <Setup-C-10-STA.pcap: TCP:40 UDP:5 ICMP:0 Other:7>
# ['.', 'captures_IoT-Sentinel', 'MAXGateway', 'Setup-C-5-STA.pcap']
#
#
# ========es_IoT-Sentinel\MAXGateway\Setup-C-5-STA.pcap========
#
# <Setup-C-5-STA.pcap: TCP:40 UDP:9 ICMP:0 Other:7>
# ['.', 'captures_IoT-Sentinel', 'SmarterCoffee', 'Setup-A-1-STA.pcap']
#
#
# ========es_IoT-Sentinel\SmarterCoffee\Setup-A-1-STA.pcap========
#
# <Setup-A-1-STA.pcap: TCP:0 UDP:4 ICMP:0 Other:7>
# ['.', 'captures_IoT-Sentinel', 'SmarterCoffee', 'Setup-A-14-STA.pcap']
#
#
# ========es_IoT-Sentinel\SmarterCoffee\Setup-A-14-STA.pcap========
#
# <Setup-A-14-STA.pcap: TCP:0 UDP:4 ICMP:0 Other:7>
# ['.', 'captures_IoT-Sentinel', 'SmarterCoffee', 'Setup-A-5-STA.pcap']
#
#
# ========es_IoT-Sentinel\SmarterCoffee\Setup-A-5-STA.pcap========
#
# <Setup-A-5-STA.pcap: TCP:0 UDP:4 ICMP:0 Other:7>
# ['.', 'captures_IoT-Sentinel', 'SmarterCoffee', 'Setup-C-1-STA.pcap']
#
#
# ========es_IoT-Sentinel\SmarterCoffee\Setup-C-1-STA.pcap========
#
# <Setup-C-1-STA.pcap: TCP:0 UDP:4 ICMP:0 Other:7>
# ['.', 'captures_IoT-Sentinel', 'TP-LinkPlugHS100', 'Setup-A-1-STA.pcap']
#
#
# ========es_IoT-Sentinel\TP-LinkPlugHS100\Setup-A-1-STA.pcap========
#
# <Setup-A-1-STA.pcap: TCP:60 UDP:12 ICMP:1 Other:9>
# ['.', 'captures_IoT-Sentinel', 'TP-LinkPlugHS100', 'Setup-C-1-STA.pcap']
#
#
# ========es_IoT-Sentinel\TP-LinkPlugHS100\Setup-C-1-STA.pcap========
#
# <Setup-C-1-STA.pcap: TCP:54 UDP:10 ICMP:0 Other:10>
# ['.', 'captures_IoT-Sentinel', 'TP-LinkPlugHS100', 'Setup-C-14-STA.pcap']
#
#
# ========es_IoT-Sentinel\TP-LinkPlugHS100\Setup-C-14-STA.pcap========
#
# <Setup-C-14-STA.pcap: TCP:66 UDP:12 ICMP:0 Other:10>
# ['.', 'captures_IoT-Sentinel', 'TP-LinkPlugHS100', 'Setup-C-5-STA.pcap']
#
#
# ========es_IoT-Sentinel\TP-LinkPlugHS100\Setup-C-5-STA.pcap========
#
# <Setup-C-5-STA.pcap: TCP:43 UDP:10 ICMP:0 Other:7>
# ['.', 'captures_IoT-Sentinel', 'TP-LinkPlugHS110', 'Setup-A-1-STA.pcap']
#
#
# ========es_IoT-Sentinel\TP-LinkPlugHS110\Setup-A-1-STA.pcap========
#
# <Setup-A-1-STA.pcap: TCP:32 UDP:12 ICMP:1 Other:7>
# ['.', 'captures_IoT-Sentinel', 'TP-LinkPlugHS110', 'Setup-A-5-STA.pcap']
#
#
# ========es_IoT-Sentinel\TP-LinkPlugHS110\Setup-A-5-STA.pcap========
#
# <Setup-A-5-STA.pcap: TCP:44 UDP:20 ICMP:0 Other:9>
# ['.', 'captures_IoT-Sentinel', 'TP-LinkPlugHS110', 'Setup-C-1-STA.pcap']
#
#
# ========es_IoT-Sentinel\TP-LinkPlugHS110\Setup-C-1-STA.pcap========
#
# <Setup-C-1-STA.pcap: TCP:42 UDP:12 ICMP:1 Other:7>
# ['.', 'captures_IoT-Sentinel', 'TP-LinkPlugHS110', 'Setup-C-5-STA.pcap']
#
#
# ========es_IoT-Sentinel\TP-LinkPlugHS110\Setup-C-5-STA.pcap========
#
# <Setup-C-5-STA.pcap: TCP:40 UDP:10 ICMP:0 Other:7>
# ['.', 'captures_IoT-Sentinel', 'WeMoInsightSwitch', 'Setup-A-1-STA.pcap']
#
#
# ========es_IoT-Sentinel\WeMoInsightSwitch\Setup-A-1-STA.pcap========
#
# <Setup-A-1-STA.pcap: TCP:206 UDP:93 ICMP:7 Other:20>
# ['.', 'captures_IoT-Sentinel', 'WeMoInsightSwitch', 'Setup-A-4-STA.pcap']
#
#
# ========es_IoT-Sentinel\WeMoInsightSwitch\Setup-A-4-STA.pcap========
#
# <Setup-A-4-STA.pcap: TCP:174 UDP:91 ICMP:9 Other:24>
# ['.', 'captures_IoT-Sentinel', 'WeMoInsightSwitch', 'Setup-A-9-STA.pcap']
#
#
# ========es_IoT-Sentinel\WeMoInsightSwitch\Setup-A-9-STA.pcap========
#
# <Setup-A-9-STA.pcap: TCP:400 UDP:107 ICMP:6 Other:20>
# ['.', 'captures_IoT-Sentinel', 'WeMoInsightSwitch', 'Setup-C-5-STA.pcap']
#
#
# ========es_IoT-Sentinel\WeMoInsightSwitch\Setup-C-5-STA.pcap========
#
# <Setup-C-5-STA.pcap: TCP:174 UDP:85 ICMP:8 Other:21>
# ['.', 'captures_IoT-Sentinel', 'WeMoInsightSwitch2', 'Setup-C-1-STA.pcap']
#
#
# ========es_IoT-Sentinel\WeMoInsightSwitch2\Setup-C-1-STA.pcap========
#
# <Setup-C-1-STA.pcap: TCP:507 UDP:51 ICMP:5 Other:11>
# ['.', 'captures_IoT-Sentinel', 'WeMoLink', 'Setup-A-1-STA.pcap']
#
#
# ========es_IoT-Sentinel\WeMoLink\Setup-A-1-STA.pcap========
#
# <Setup-A-1-STA.pcap: TCP:415 UDP:66 ICMP:16 Other:17>
# ['.', 'captures_IoT-Sentinel', 'WeMoLink', 'Setup-A-14-STA.pcap']
#
#
# ========es_IoT-Sentinel\WeMoLink\Setup-A-14-STA.pcap========
#
# <Setup-A-14-STA.pcap: TCP:459 UDP:64 ICMP:16 Other:12>
# ['.', 'captures_IoT-Sentinel', 'WeMoLink', 'Setup-A-5-STA.pcap']
#
#
# ========es_IoT-Sentinel\WeMoLink\Setup-A-5-STA.pcap========
#
# <Setup-A-5-STA.pcap: TCP:418 UDP:62 ICMP:16 Other:14>
# ['.', 'captures_IoT-Sentinel', 'WeMoLink', 'Setup-C-1-STA.pcap']
#
#
# ========es_IoT-Sentinel\WeMoLink\Setup-C-1-STA.pcap========
#
# <Setup-C-1-STA.pcap: TCP:631 UDP:89 ICMP:24 Other:19>
# ['.', 'captures_IoT-Sentinel', 'WeMoSwitch', 'Setup-A-1-STA.pcap']
#
#
# ========es_IoT-Sentinel\WeMoSwitch\Setup-A-1-STA.pcap========
#
# <Setup-A-1-STA.pcap: TCP:242 UDP:24 ICMP:10 Other:14>
# ['.', 'captures_IoT-Sentinel', 'WeMoSwitch', 'Setup-A-5-STA.pcap']
#
#
# ========es_IoT-Sentinel\WeMoSwitch\Setup-A-5-STA.pcap========
#
# <Setup-A-5-STA.pcap: TCP:249 UDP:24 ICMP:10 Other:10>
# ['.', 'captures_IoT-Sentinel', 'WeMoSwitch', 'Setup-C-1-STA.pcap']
#
#
# ========es_IoT-Sentinel\WeMoSwitch\Setup-C-1-STA.pcap========
#
# <Setup-C-1-STA.pcap: TCP:235 UDP:24 ICMP:10 Other:15>
# ['.', 'captures_IoT-Sentinel', 'WeMoSwitch', 'Setup-C-5-STA.pcap']
#
#
# ========es_IoT-Sentinel\WeMoSwitch\Setup-C-5-STA.pcap========
#
# <Setup-C-5-STA.pcap: TCP:241 UDP:24 ICMP:10 Other:15>
# ['.', 'captures_IoT-Sentinel', 'WeMoSwitch2', 'Setup-C-1-STA.pcap']
#
#
# ========es_IoT-Sentinel\WeMoSwitch2\Setup-C-1-STA.pcap========
#
# <Setup-C-1-STA.pcap: TCP:93 UDP:94 ICMP:7 Other:23>
# ['.', 'captures_IoT-Sentinel', 'Withings', 'Setup-A-1-STA.pcap']
#
#
# ========es_IoT-Sentinel\Withings\Setup-A-1-STA.pcap========
#
# <Setup-A-1-STA.pcap: TCP:49 UDP:7 ICMP:0 Other:10>
# ['.', 'captures_IoT-Sentinel', 'Withings', 'Setup-C-13-STA.pcap']
#
#
# ========es_IoT-Sentinel\Withings\Setup-C-13-STA.pcap========
#
# <Setup-C-13-STA.pcap: TCP:52 UDP:8 ICMP:0 Other:9>
# ['.', 'captures_IoT-Sentinel', 'Withings', 'Setup-C-18-STA.pcap']
#
#
# ========es_IoT-Sentinel\Withings\Setup-C-18-STA.pcap========
#
# <Setup-C-18-STA.pcap: TCP:50 UDP:6 ICMP:0 Other:10>
# ['.', 'captures_IoT-Sentinel', 'Withings', 'Setup-C-5-STA.pcap']
#
#
# ========es_IoT-Sentinel\Withings\Setup-C-5-STA.pcap========
#
# <Setup-C-5-STA.pcap: TCP:52 UDP:9 ICMP:0 Other:9>

# %% [markdown]
# # Creation of three different feature sets

# %% [markdown]
# ### Generates  IoTSentinel, IoTSense feature sets

# %%
Folder= {'Aria': 'Aria', 'D-LinkCam': 'D-LinkCam', 'D-LinkDayCam': 'D-LinkDayCam', 'D-LinkDoorSensor': 'D-LinkDoorSensor', 'D-LinkHomeHub': 'D-LinkHomeHub', 'D-LinkSensor': 'D-LinkSensor', 'D-LinkSiren': 'D-LinkSiren', 'D-LinkSwitch': 'D-LinkSwitch', 'D-LinkWaterSensor': 'D-LinkWaterSensor', 'EdimaxCam1': 'EdimaxCam', 'EdimaxCam2': 'EdimaxCam', 'EdimaxPlug1101W': 'EdimaxPlug1101W', 'EdimaxPlug2101W': 'EdimaxPlug2101W', 'EdnetCam1': 'EdnetCam', 'EdnetCam2': 'EdnetCam', 'EdnetGateway': 'EdnetGateway', 'HomeMaticPlug': 'HomeMaticPlug', 'HueBridge': 'HueBridge', 'HueSwitch': 'HueSwitch', 'iKettle2': 'iKettle2', 'Lightify': 'Lightify', 'MAXGateway': 'MAXGateway', 'SmarterCoffee': 'SmarterCoffee', 'TP-LinkPlugHS100': 'TP-LinkPlugHS100', 'TP-LinkPlugHS110': 'TP-LinkPlugHS110', 'WeMoInsightSwitch': 'WeMoInsightSwitch', 'WeMoInsightSwitch2': 'WeMoInsightSwitch', 'WeMoLink': 'WeMoLink', 'WeMoSwitch': 'WeMoSwitch', 'WeMoSwitch2': 'WeMoSwitch', 'Withings': 'Withings'}

# %%
for i in dataset_name:
    df=pd.read_csv(i)
    df=df.replace({"Folder": Folder})
    del df["Label"]
    df["Label"]=df["Folder"]
    del df["Folder"]
    del df["Session"]
    
    
    
    deleted=["payload_l","TCP_w_size","Entropy"]
    temp=df
    name="IoTSentinel_"+i
    temp=temp.drop(columns=deleted)
    temp.to_csv(name, index=False)


    deleted=["LLC","Pck_rawdata","Pck_size","Portcl_src","Portcl_dst","IP_add_count"]
    temp=df
    name="IoTSense_"+i
    temp=temp.drop(columns=deleted)
    temp.to_csv(name, index=False)   
    
os.remove("Train.csv")
os.remove("Test.csv")
